# %% [markdown]
# # 🔍 Article Selection Analysis for TTD Newsletter
#
# This notebook is an interactive replica of the article selection flow using [Metaflow](https://metaflow.org/).
#
# You can run the complete flow using the following command:
#
# ```bash
# python -m ttd.flows.article_selection.flow
# ```
#
# To learn more about how Metaflow works, see the [official documentation](https://docs.metaflow.org/).
#
# It consists of five main steps :
#
# <img src="images/article_selection_flow.png" width="400">
#
#
# Use this notebook to **find, test, and evaluate** the flow with dummy data.
#
# > ⚠️ **Make sure to execute all steps in order** to obtain valid results.
# > 🔎 **Inspect the flow state at each step** to better understand the process.

# %%
from metaflow import FlowSpec, step, Parameter
from pydantic import BaseModel, Field
from datetime import datetime

from ttd.utils.print import safe_pretty_print
from ttd.utils.date import parse_date

class FlowParametersSchema(BaseModel):
    """Schema for flow parameters."""
    articles_table: str = Field(
        'articles', description="Table to load articles from"
    )
    articles_limit: int = Field(
        2, description="Maximum number of articles to select"
    )
    date_threshold: datetime = Field(
        'Thu, 03 Apr 2025 18:00:00 +0000',
        description="Select articles published after this date"
    )
    cluster_date_threshold: datetime = Field(
        'Thu, 03 Apr 2025 18:00:00 +0000',
        description="articles published after this date are used to compute clusters scores"
    )
    clean_tables: bool = Field(
        False, description="Clean tables (selections, selected_articles)"
    )
    selected_articles_table: str = Field(
        'selected_articles_dummy_table',
        description='Table to register selected articles'
    )
    class Config:
        extra = 'allow'
    pass

flow = FlowParametersSchema(
    articles_table='replicated_articles',
    date_threshold=parse_date('Thu, 05 Jun 2025 12:00:00 +0000'),
    cluster_date_threshold=parse_date('Thu, 05 Jun 2025 12:00:00 +0000'),
    articles_limit=2,
    clean_tables=True
)
safe_pretty_print(flow.model_dump())
# Out:
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 2,
#     'date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'clean_tables': True,
#     'selected_articles_table': 'selected_articles_dummy_table'
# }

# %% [markdown]
# ### **1. Start step**
# Init, config, parameters, tracks versioning...

# %%
from ttd.flows.article_selection.steps.start import execute as start_step

start_step(flow)
safe_pretty_print(flow.model_dump())
# Out:
# 2025-06-05 23:12:05,649 - ttd.flows.article_selection.steps.start - INFO - ✅ Database first connection established.
# 2025-06-05 23:12:05,787 - ttd.flows.article_selection.steps.start - INFO - ✅ Database cleaned.
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 2,
#     'date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'clean_tables': True,
#     'selected_articles_table': 'selected_articles_dummy_table',
#     'config': {
#         'data_dir': '/Users/mathieucrilout/Repos/train_tune_deploy/data',
#         'db_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/ttd_tinydb.json',
#         'feeds_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds.txt',
#         'feeds_stealth_path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds_stealth.txt'
#     },
#     'git_metadata': {
#         'git_commit': 'ee0c0203d8a557b45618bda4e16e9a3fe11c1c5a',
#         'git_branch': 'dev',
#         'git_repo': 'git@github.com:mcrilo33/train-tune-deploy.git'
#     },
#     'parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'parsed_cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'min_parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'metrics': {},
#     'errors': {}
# }

# %% [markdown]
# ### **2. Load articles step**

# %%
from ttd.flows.article_selection.steps.load_articles \
    import execute as load_articles_step

load_articles_step(flow)
safe_pretty_print(flow.model_dump())
# Out:
# 2025-06-05 23:12:05,794 - ttd.flows.article_selection.steps.load_articles - INFO - Loading articles...
# /Users/mathieucrilout/.miniconda3/envs/ttd/lib/python3.10/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# 2025-06-05 23:12:05,966 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ Loaded 5 articles from 'replicated_articles': len(articles)=5, date_threshold='2025-06-05 12:00:00+00:00'
# 2025-06-05 23:12:05,967 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ Filtering out already replicated articles...
# 2025-06-05 23:12:06,021 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ There are 0 already selected articles
# 2025-06-05 23:12:06,021 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ Filtered out 0 already selected articles from 'selected_articles_dummy_table'
# 2025-06-05 23:12:06,021 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ Loaded 5 articles...
# 2025-06-05 23:12:06,021 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ Step load_articles done in 0.23s
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 2,
#     'date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'clean_tables': True,
#     'selected_articles_table': 'selected_articles_dummy_table',
#     'config': {
#         'data_dir': '/Users/mathieucrilout/Repos/train_tune_deploy/data',
#         'db_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/ttd_tinydb.json',
#         'feeds_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds.txt',
#         'feeds_stealth_path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds_stealth.txt'
#     },
#     'git_metadata': {
#         'git_commit': 'ee0c0203d8a557b45618bda4e16e9a3fe11c1c5a',
#         'git_branch': 'dev',
#         'git_repo': 'git@github.com:mcrilo33/train-tune-deploy.git'
#     },
#     'parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'parsed_cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'min_parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'metrics': {
#         'step_start_times': {
#             'load_articles': 1749157925.7950232
#         },
#         'step_duration': {
#             'load_articles': 0.22680878639221191
#         }
#     },
#     'errors': {},
#     'articles': [
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Top 5 Alternative Data Career Paths and How to Learn Them for Free',
#             'author': 'Nate Rosidi',
#             'published_date': 'Thu, 05 Jun 2025 12:00:02 +0000',
#             'url_domain': 'kdnuggets.com',
#             'url':
# 'https://www.kdnuggets.com/top-5-alternative-data-career-paths-and-how-to-learn-t...',
#             'summary': 'How about some alternative options for a data career? Learn about
# five non-stand...',
#             'tags': [],
#             'html_content_length': 201344,
#             'text_content_length': 10758,
#             'summary_length': 146,
#             'summary_text_ratio': 0.013571295779884737,
#             'metadata': {
#                 'error': None,
#                 'duration': 5
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:06.750408',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3622',
#             'is_ai_added': True,
#             'dense_summary_added': 'Alternative data career paths include Data Product
# Manager, Data Journalist, Ana...',
#             'dense_summary_length_added': 1763,
#             'core_line_summary_added': 'The field of data offers diverse career paths
# beyond traditional data science, i...',
#             'core_line_summary_length_added': 238,
#             'tags_pred_added': [
#                 'Data analysis',
#                 'Data product management',
#                 'Analytics engineering',
#                 'Data journalism',
#                 'Data ethics'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'data analysis',
#                 'data management',
#                 'cloud computing',
#                 'Data journalism',
#                 'data ethics'
#             ],
#             'title_vs_core_rouge_eval': 0.049792531120331954,
#             'tag_similarity_eval': 0.0,
#             'doc_id': '3644'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'OnePlus Looks to Undercut Apple and Samsung With New $700 Tablet',
#             'author': 'Chris Welch',
#             'published_date': 'Thu, 05 Jun 2025 12:00:38 GMT',
#             'url_domain': 'bloomberg.com',
#             'url':
# 'https://www.bloomberg.com/news/articles/2025-06-05/oneplus-announces-700-oneplus...',
#             'summary': 'Three generations into its Pad lineup, OnePlus is still trying to
# stand out in a...',
#             'tags': [
#                 'NMS:AAPL'
#             ],
#             'html_content_length': 14073,
#             'text_content_length': 464,
#             'summary_length': 115,
#             'summary_text_ratio': 0.2478448275862069,
#             'metadata': {
#                 'error': None,
#                 'duration': 3
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:10.324951',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3625',
#             'is_ai_added': False,
#             'doc_id': '3647'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'How to handle the tech challenges of moving overseas',
#             'author': 'Tom Hawking',
#             'published_date': '2025-06-05T08:00:00-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/tech/676306/moving-tech-overseas-how-to-tips',
#             'summary': 'Moving is stressful at the best of times, and while moving to a
# new country is e...',
#             'tags': [
#                 'Gadgets',
#                 'How to',
#                 'Tech'
#             ],
#             'html_content_length': 494295,
#             'text_content_length': 10290,
#             'summary_length': 320,
#             'summary_text_ratio': 0.031098153547133137,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:17.795847',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3631',
#             'is_ai_added': False,
#             'doc_id': '3653'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'The cursed world of AI kiss and hug apps',
#             'author': 'Victoria Song',
#             'published_date': '2025-06-05T08:00:00-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/ai-artificial-intelligence/679295/ai-hug-kiss-video-app...',
#             'summary': "Doomscroll on TikTok long enough, and you'll come across an ad for
# AI video apps...",
#             'tags': [
#                 'AI',
#                 'Analysis',
#                 'Hands-on',
#                 'Reviews',
#                 'Tech'
#             ],
#             'html_content_length': 472554,
#             'text_content_length': 14796,
#             'summary_length': 314,
#             'summary_text_ratio': 0.021221951878886185,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:20.556450',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3632',
#             'is_ai_added': True,
#             'dense_summary_added': 'AI video apps offer benign and disturbing video
# templates, including kissing, hu...',
#             'dense_summary_length_added': 1324,
#             'core_line_summary_added': 'AI video apps offering deepfake templates,
# including sexualized content, raise e...',
#             'core_line_summary_length_added': 207,
#             'tags_pred_added': [
#                 'Generative AI',
#                 'deepfakes',
#                 'AI ethics',
#                 'mobile applications',
#                 'content moderation'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'Generative AI',
#                 'deepfakes',
#                 'AI ethics',
#                 'software development',
#                 'content moderation'
#             ],
#             'title_vs_core_rouge_eval': 0.028436018957345967,
#             'tag_similarity_eval': 0.38524137017476817,
#             'doc_id': '3654'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Forget Otter.ai: ChatGPT just entered the meeting room',
#             'author': '',
#             'published_date': 'Thu, 05 Jun 2025 12:05:00 GMT',
#             'url_domain': 'zdnet.com',
#             'url':
# 'https://www.zdnet.com/article/forget-otter-ai-chatgpt-just-entered-the-meeting-r...',
#             'summary': 'ChatGPT just got two major upgrades that could make your work life
# easier.',
#             'tags': [],
#             'html_content_length': 581226,
#             'text_content_length': 6965,
#             'summary_length': 74,
#             'summary_text_ratio': 0.010624551328068915,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:19:07.924772',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3650',
#             'is_ai_added': True,
#             'dense_summary_added': 'OpenAI has introduced Connectors and Record Mode to
# ChatGPT, enhancing its utili...',
#             'dense_summary_length_added': 1247,
#             'core_line_summary_added': "OpenAI's new Connectors and Record Mode enhance
# ChatGPT's professional utility b...",
#             'core_line_summary_length_added': 232,
#             'tags_pred_added': [
#                 'Large language models',
#                 'OpenAI',
#                 'ChatGPT',
#                 'Data privacy',
#                 'Copyright infringement'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'large language models',
#                 'OpenAI',
#                 'ChatGPT',
#                 'data privacy',
#                 'copyright infringement'
#             ],
#             'title_vs_core_rouge_eval': 0.020618556701030927,
#             'tag_similarity_eval': 0.0,
#             'doc_id': '3672'
#         }
#     ]
# }

# %% [markdown]
# ### **3. Article Selection step**
#
# Propose multiple selection based on various unsupervised strategies.

# %%
from ttd.flows.article_selection.steps.select_articles \
    import execute as select_articles_step

select_articles_step(flow)
safe_pretty_print(flow.model_dump())
# Out:
# 2025-06-05 23:12:06,051 - ttd.flows.article_selection.steps.select_articles - INFO - Selecting articles...
# 2025-06-05 23:12:06,052 - ttd.flows.article_selection.steps.select_articles - INFO - ✅ Scoring clusters...
# 2025-06-05 23:12:06,574 - ttd.flows.article_selection.steps.select_articles - INFO - ✅ Step select_articles done in 0.52s
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 2,
#     'date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'clean_tables': True,
#     'selected_articles_table': 'selected_articles_dummy_table',
#     'config': {
#         'data_dir': '/Users/mathieucrilout/Repos/train_tune_deploy/data',
#         'db_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/ttd_tinydb.json',
#         'feeds_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds.txt',
#         'feeds_stealth_path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds_stealth.txt'
#     },
#     'git_metadata': {
#         'git_commit': 'ee0c0203d8a557b45618bda4e16e9a3fe11c1c5a',
#         'git_branch': 'dev',
#         'git_repo': 'git@github.com:mcrilo33/train-tune-deploy.git'
#     },
#     'parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'parsed_cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'min_parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'metrics': {
#         'step_start_times': {
#             'load_articles': 1749157925.7950232,
#             'select_articles': 1749157926.052008
#         },
#         'step_duration': {
#             'load_articles': 0.22680878639221191,
#             'select_articles': 0.5225369930267334
#         }
#     },
#     'errors': {},
#     'articles': [
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Top 5 Alternative Data Career Paths and How to Learn Them for Free',
#             'author': 'Nate Rosidi',
#             'published_date': 'Thu, 05 Jun 2025 12:00:02 +0000',
#             'url_domain': 'kdnuggets.com',
#             'url':
# 'https://www.kdnuggets.com/top-5-alternative-data-career-paths-and-how-to-learn-t...',
#             'summary': 'How about some alternative options for a data career? Learn about
# five non-stand...',
#             'tags': [],
#             'html_content_length': 201344,
#             'text_content_length': 10758,
#             'summary_length': 146,
#             'summary_text_ratio': 0.013571295779884737,
#             'metadata': {
#                 'error': None,
#                 'duration': 5
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:06.750408',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3622',
#             'is_ai_added': True,
#             'dense_summary_added': 'Alternative data career paths include Data Product
# Manager, Data Journalist, Ana...',
#             'dense_summary_length_added': 1763,
#             'core_line_summary_added': 'The field of data offers diverse career paths
# beyond traditional data science, i...',
#             'core_line_summary_length_added': 238,
#             'tags_pred_added': [
#                 'Data analysis',
#                 'Data product management',
#                 'Analytics engineering',
#                 'Data journalism',
#                 'Data ethics'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'data analysis',
#                 'data management',
#                 'cloud computing',
#                 'Data journalism',
#                 'data ethics'
#             ],
#             'title_vs_core_rouge_eval': 0.049792531120331954,
#             'tag_similarity_eval': 0.0,
#             'doc_id': '3644'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'OnePlus Looks to Undercut Apple and Samsung With New $700 Tablet',
#             'author': 'Chris Welch',
#             'published_date': 'Thu, 05 Jun 2025 12:00:38 GMT',
#             'url_domain': 'bloomberg.com',
#             'url':
# 'https://www.bloomberg.com/news/articles/2025-06-05/oneplus-announces-700-oneplus...',
#             'summary': 'Three generations into its Pad lineup, OnePlus is still trying to
# stand out in a...',
#             'tags': [
#                 'NMS:AAPL'
#             ],
#             'html_content_length': 14073,
#             'text_content_length': 464,
#             'summary_length': 115,
#             'summary_text_ratio': 0.2478448275862069,
#             'metadata': {
#                 'error': None,
#                 'duration': 3
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:10.324951',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3625',
#             'is_ai_added': False,
#             'doc_id': '3647'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'How to handle the tech challenges of moving overseas',
#             'author': 'Tom Hawking',
#             'published_date': '2025-06-05T08:00:00-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/tech/676306/moving-tech-overseas-how-to-tips',
#             'summary': 'Moving is stressful at the best of times, and while moving to a
# new country is e...',
#             'tags': [
#                 'Gadgets',
#                 'How to',
#                 'Tech'
#             ],
#             'html_content_length': 494295,
#             'text_content_length': 10290,
#             'summary_length': 320,
#             'summary_text_ratio': 0.031098153547133137,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:17.795847',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3631',
#             'is_ai_added': False,
#             'doc_id': '3653'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'The cursed world of AI kiss and hug apps',
#             'author': 'Victoria Song',
#             'published_date': '2025-06-05T08:00:00-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/ai-artificial-intelligence/679295/ai-hug-kiss-video-app...',
#             'summary': "Doomscroll on TikTok long enough, and you'll come across an ad for
# AI video apps...",
#             'tags': [
#                 'AI',
#                 'Analysis',
#                 'Hands-on',
#                 'Reviews',
#                 'Tech'
#             ],
#             'html_content_length': 472554,
#             'text_content_length': 14796,
#             'summary_length': 314,
#             'summary_text_ratio': 0.021221951878886185,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:20.556450',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3632',
#             'is_ai_added': True,
#             'dense_summary_added': 'AI video apps offer benign and disturbing video
# templates, including kissing, hu...',
#             'dense_summary_length_added': 1324,
#             'core_line_summary_added': 'AI video apps offering deepfake templates,
# including sexualized content, raise e...',
#             'core_line_summary_length_added': 207,
#             'tags_pred_added': [
#                 'Generative AI',
#                 'deepfakes',
#                 'AI ethics',
#                 'mobile applications',
#                 'content moderation'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'Generative AI',
#                 'deepfakes',
#                 'AI ethics',
#                 'software development',
#                 'content moderation'
#             ],
#             'title_vs_core_rouge_eval': 0.028436018957345967,
#             'tag_similarity_eval': 0.38524137017476817,
#             'doc_id': '3654'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Forget Otter.ai: ChatGPT just entered the meeting room',
#             'author': '',
#             'published_date': 'Thu, 05 Jun 2025 12:05:00 GMT',
#             'url_domain': 'zdnet.com',
#             'url':
# 'https://www.zdnet.com/article/forget-otter-ai-chatgpt-just-entered-the-meeting-r...',
#             'summary': 'ChatGPT just got two major upgrades that could make your work life
# easier.',
#             'tags': [],
#             'html_content_length': 581226,
#             'text_content_length': 6965,
#             'summary_length': 74,
#             'summary_text_ratio': 0.010624551328068915,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:19:07.924772',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3650',
#             'is_ai_added': True,
#             'dense_summary_added': 'OpenAI has introduced Connectors and Record Mode to
# ChatGPT, enhancing its utili...',
#             'dense_summary_length_added': 1247,
#             'core_line_summary_added': "OpenAI's new Connectors and Record Mode enhance
# ChatGPT's professional utility b...",
#             'core_line_summary_length_added': 232,
#             'tags_pred_added': [
#                 'Large language models',
#                 'OpenAI',
#                 'ChatGPT',
#                 'Data privacy',
#                 'Copyright infringement'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'large language models',
#                 'OpenAI',
#                 'ChatGPT',
#                 'data privacy',
#                 'copyright infringement'
#             ],
#             'title_vs_core_rouge_eval': 0.020618556701030927,
#             'tag_similarity_eval': 0.0,
#             'doc_id': '3672'
#         }
#     ],
#     'selection': {
#         'selection_time': '2025-06-05 21:12:06.053434+00:00',
#         'linearly_selected_articles_with_diversity': [
#             {
#                 'table_name': 'replicated_articles',
#                 'title': 'Top 5 Alternative Data Career Paths and How to Learn Them for
# Free',
#                 'author': 'Nate Rosidi',
#                 'published_date': 'Thu, 05 Jun 2025 12:00:02 +0000',
#                 'url_domain': 'kdnuggets.com',
#                 'url':
# 'https://www.kdnuggets.com/top-5-alternative-data-career-paths-and-how-to-learn-t...',
#                 'summary': 'How about some alternative options for a data career? Learn
# about five non-stand...',
#                 'tags': [],
#                 'html_content_length': 201344,
#                 'text_content_length': 10758,
#                 'summary_length': 146,
#                 'summary_text_ratio': 0.013571295779884737,
#                 'metadata': {
#                     'error': None,
#                     'duration': 5
#                 },
#                 'original_table_name': 'articles',
#                 'created_at': '2025-06-05T12:18:06.750408',
#                 'html_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'text_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'original_doc_id': '3622',
#                 'is_ai_added': True,
#                 'dense_summary_added': 'Alternative data career paths include Data Product
# Manager, Data Journalist, Ana...',
#                 'dense_summary_length_added': 1763,
#                 'core_line_summary_added': 'The field of data offers diverse career paths
# beyond traditional data science, i...',
#                 'core_line_summary_length_added': 238,
#                 'tags_pred_added': [
#                     'Data analysis',
#                     'Data product management',
#                     'Analytics engineering',
#                     'Data journalism',
#                     'Data ethics'
#                 ],
#                 'tags_pred_length_added': 5,
#                 'clusters_names_in_order_added': [
#                     'data analysis',
#                     'data management',
#                     'cloud computing',
#                     'Data journalism',
#                     'data ethics'
#                 ],
#                 'title_vs_core_rouge_eval': 0.049792531120331954,
#                 'tag_similarity_eval': 0.0,
#                 'doc_id': '3644',
#                 'clusters_score': 0
#             },
#             {
#                 'table_name': 'replicated_articles',
#                 'title': 'The cursed world of AI kiss and hug apps',
#                 'author': 'Victoria Song',
#                 'published_date': '2025-06-05T08:00:00-04:00',
#                 'url_domain': 'theverge.com',
#                 'url':
# 'https://www.theverge.com/ai-artificial-intelligence/679295/ai-hug-kiss-video-app...',
#                 'summary': "Doomscroll on TikTok long enough, and you'll come across an ad
# for AI video apps...",
#                 'tags': [
#                     'AI',
#                     'Analysis',
#                     'Hands-on',
#                     'Reviews',
#                     'Tech'
#                 ],
#                 'html_content_length': 472554,
#                 'text_content_length': 14796,
#                 'summary_length': 314,
#                 'summary_text_ratio': 0.021221951878886185,
#                 'metadata': {
#                     'error': None,
#                     'duration': 0
#                 },
#                 'original_table_name': 'articles',
#                 'created_at': '2025-06-05T12:18:20.556450',
#                 'html_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'text_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'original_doc_id': '3632',
#                 'is_ai_added': True,
#                 'dense_summary_added': 'AI video apps offer benign and disturbing video
# templates, including kissing, hu...',
#                 'dense_summary_length_added': 1324,
#                 'core_line_summary_added': 'AI video apps offering deepfake templates,
# including sexualized content, raise e...',
#                 'core_line_summary_length_added': 207,
#                 'tags_pred_added': [
#                     'Generative AI',
#                     'deepfakes',
#                     'AI ethics',
#                     'mobile applications',
#                     'content moderation'
#                 ],
#                 'tags_pred_length_added': 5,
#                 'clusters_names_in_order_added': [
#                     'Generative AI',
#                     'deepfakes',
#                     'AI ethics',
#                     'software development',
#                     'content moderation'
#                 ],
#                 'title_vs_core_rouge_eval': 0.028436018957345967,
#                 'tag_similarity_eval': 0.38524137017476817,
#                 'doc_id': '3654',
#                 'clusters_score': 0
#             }
#         ],
#         'table_name': 'selections',
#         'created_at': '2025-06-05T21:12:06.363046'
#     }
# }

# %% [markdown]
# ### **4. Prepare Report**
#
# Generate a detailed report from the selected articles.
#
# Once the flow has been executed, you can retrieve the report using the following command :
#
# ```bash # python -m ttd.flows.article_selection.flow card get prepare_report article_enrichment_report_example.html```
#
# Here is an example output :
#
# <img src="images/article_selection_report_example.png" width="800">

# %% [markdown]
# ## Quick Analysis

# %%
db_path = flow.config.get("db_path"):while
db_path = '/Users/mathieucrilout/Repos/train_tune_deploy/data/ttd_tinydb.json'

# %%
from ttd.flows.analysis import get_articles_with_no_error, get_oldest_and_latest_dates
from ttd.storage.ttd_storage import TTDStorage

# Get articles from first ingestion
storage = TTDStorage(db_path)
articles = storage.get_obj_in_range("replicated_articles", first_id=2000)
articles_with_no_error = get_articles_with_no_error(articles)
oldest_date, latest_date = get_oldest_and_latest_dates(articles_with_no_error)
if oldest_date and latest_date:
    print(f"Oldest date: {oldest_date}")
    print(f"Latest date: {latest_date}")
# Out:
# 2025-06-05 23:12:06,847 - numexpr.utils - INFO - NumExpr defaulting to 10 threads.
# Oldest date: Tue, 13 May 2025 13:31:57 +0000
# Latest date: Thu, 05 Jun 2025 12:05:00 +0000

# %%
from ttd.flows.analysis import filter_articles_by_clusters
articles = filter_articles_by_clusters(articles_with_no_error, ["artificial intelligence", "large language models", "India"])

# %% [markdown]
# ### Look at linear vs sub exponential vs sup exponential orders

# %%
from ttd.flows.article_selection.steps.select_articles import compute_cluster_scores
from ttd.flows.article_selection.steps.select_articles import linear_order_metric
from ttd.flows.article_selection.steps.select_articles import exponential_order_metric
linear_cluster_scores = compute_cluster_scores(
    articles,
    order_metric=linear_order_metric
)
sub_exponential_cluster_scores = compute_cluster_scores(
    articles,
    order_metric=exponential_order_metric(0.1)
)
sup_exponential_cluster_scores = compute_cluster_scores(
    articles,
    order_metric=exponential_order_metric(0.9)
)
linear_ordered_by_value = dict(sorted(linear_cluster_scores.items(), key=lambda x: x[1], reverse=True))
sub_exponential_ordered_by_value = dict(sorted(sub_exponential_cluster_scores.items(), key=lambda x: x[1], reverse=True))
sup_exponential_ordered_by_value = dict(sorted(sup_exponential_cluster_scores.items(), key=lambda x: x[1], reverse=True))
print("Linear cluster scores, Sub-exp cluster scores, Sup-exp cluster scores")
for key, value, key_2, value_2, key_3, value_3 in zip(linear_ordered_by_value.keys(), linear_ordered_by_value.values(), sub_exponential_ordered_by_value.keys(), sub_exponential_ordered_by_value.values(), sup_exponential_ordered_by_value.keys(), sup_exponential_ordered_by_value.values()):
    print(f"{key}: {value:0.2f}, {key_2}: {value_2:0.2f}, {key_3}: {value_3:0.2f}")
# Out:
# Linear cluster scores, Sub-exp cluster scores, Sup-exp cluster scores
# NVIDIA: 59.32, NVIDIA: 36.66, data science: 94.90
# data science: 58.03, software development: 32.72, NVIDIA: 88.39
# automation: 52.13, data science: 32.47, automation: 80.93
# software development: 50.43, Cloud computing: 30.50, software development: 73.62
# Cloud computing: 44.23, automation: 29.57, data privacy: 66.20
# data privacy: 40.82, data privacy: 22.32, Cloud computing: 63.23
# OpenAI: 27.32, OpenAI: 20.25, open source software: 40.19
# AI training: 24.83, digital transformation: 18.81, search engines: 36.67
# search engines: 24.60, AI training: 18.14, OpenAI: 35.89
# digital transformation: 23.03, search engines: 16.00, AI training: 33.06
# open source software: 20.07, Android: 15.61, data governance: 30.47
# Android: 18.33, healthcare: 12.52, digital transformation: 28.12
# data governance: 17.52, reinforcement learning: 11.56, data management: 28.12
# data management: 17.48, drug discovery: 11.54, reliability: 26.84
# reliability: 17.10, quantum computing: 11.40, employment: 26.65
# employment: 17.00, GitHub Copilot: 11.30, machine learning: 21.91
# reinforcement learning: 16.00, Copyright: 11.11, reinforcement learning: 21.82
# healthcare: 15.64, data management: 10.51, Android: 21.21
# drug discovery: 15.48, reliability: 9.96, drug discovery: 20.78
# customer service: 13.58, retrieval-augmented generation: 9.62, healthcare: 19.83
# quantum computing: 13.25, Microsoft: 9.51, customer service: 19.63
# retrieval-augmented generation: 13.12, customer service: 9.30, cloud computing: 17.91
# Copyright: 12.78, venture capital: 9.24, retrieval-augmented generation: 17.41
# GitHub Copilot: 12.67, Amazon Bedrock: 9.23, Startups: 17.32
# Microsoft: 12.08, employment: 9.19, Anthropic: 17.28
# machine learning: 12.08, Robotics: 8.21, computer vision: 17.24
# venture capital: 11.98, data governance: 8.12, economic impact: 16.49
# Amazon Bedrock: 11.25, Generative AI: 8.11, content moderation: 16.35
# natural language processing: 11.03, natural language processing: 7.44, venture capital: 16.08
# energy efficiency: 10.78, advertising: 7.34, energy efficiency: 16.03
# content moderation: 10.57, cybersecurity: 7.23, natural language processing: 15.95
# Anthropic: 10.53, ChatGPT: 7.22, Copyright: 15.55
# cloud computing: 10.25, energy efficiency: 6.64, benchmarking: 15.37
# advertising: 10.08, content moderation: 6.52, quantum computing: 15.33
# Robotics: 10.08, Google: 6.43, Microsoft: 15.04
# computer vision: 10.05, prompt engineering: 6.42, risk assessment: 14.71
# Google: 9.75, labor market: 6.32, GitHub Copilot: 14.29
# cybersecurity: 9.45, Vision language models: 6.00, Google: 14.22
# Generative AI: 9.25, open source software: 5.68, neural networks: 14.02
# prompt engineering: 9.17, machine learning: 5.66, Amazon Bedrock: 13.96
# risk assessment: 9.12, GitHub: 5.60, advertising: 13.67
# data centers: 9.08, Anthropic: 5.57, data centers: 13.47
# Startups: 8.87, data centers: 5.54, Robotics: 12.80
# ChatGPT: 8.67, computer vision: 5.44, prompt engineering: 12.68
# benchmarking: 8.67, digital twins: 5.30, cybersecurity: 12.62
# labor market: 8.42, Web3: 5.20, business: 12.02
# neural networks: 8.15, medical imaging: 5.11, regulation: 11.06
# GitHub: 8.00, data quality: 5.11, labor market: 11.05
# economic impact: 7.22, non-profit organizations: 5.10, Generative AI: 11.03
# education: 7.08, Data scraping: 5.10, Immigration policy: 10.97
# Fraud detection: 7.00, Nuclear energy: 5.00, application programming interfaces: 10.81
# business: 6.75, risk assessment: 4.73, China: 10.68
# regulation: 6.62, cloud computing: 4.67, education: 10.67
# genomics: 6.58, Fraud detection: 4.60, ChatGPT: 10.42
# digital twins: 6.50, genomics: 4.41, GitHub: 10.40
# Immigration policy: 6.40, neural networks: 4.41, market trends: 10.20
# Vision language models: 6.25, education: 4.34, model compression: 10.00
# China: 6.23, context learning: 4.32, model evaluation: 9.90
# context learning: 6.17, Blockchain: 4.31, hardware acceleration: 9.58
# Manufacturing: 6.08, Error handling: 4.22, Fraud detection: 9.40
# Blockchain: 6.03, knowledge graphs: 4.21, genomics: 9.14
# Web3: 6.00, MLOps: 4.21, Manufacturing: 9.04
# application programming interfaces: 5.92, mixture of experts: 4.21, vector databases: 8.98
# data quality: 5.83, Image segmentation: 4.20, Meta: 8.95
# medical imaging: 5.83, disinformation: 4.12, reasoning: 8.61
# knowledge graphs: 5.83, Website accessibility: 4.12, productivity: 8.55
# non-profit organizations: 5.75, Export controls: 4.01, mobile applications: 8.43
# model evaluation: 5.70, Speech synthesis: 4.01, United Kingdom: 8.39
# Error handling: 5.67, Supply chain management: 4.00, mental health: 8.35
# market trends: 5.58, atrial fibrillation: 4.00, context learning: 8.32
# Data scraping: 5.50, note-taking: 4.00, fine-tuning: 8.17
# reasoning: 5.42, benchmarking: 3.65, Blockchain: 8.17
# disinformation: 5.42, Manufacturing: 3.51, Data orchestration: 8.11
# mixture of experts: 5.33, regulation: 3.42, knowledge graphs: 8.07
# MLOps: 5.33, China: 3.32, investment: 8.04
# Snowflake: 5.33, Snowflake: 3.31, Snowflake: 7.97
# Nuclear energy: 5.20, Immigration policy: 3.26, software subscriptions: 7.80
# Website accessibility: 5.17, reasoning: 3.22, digital twins: 7.70
# investment: 5.08, Virtual worlds: 3.20, AI ethics: 7.65
# hardware acceleration: 5.02, Podcasts: 3.20, Renewable energy: 7.51
# Client-side: 5.00, model evaluation: 3.13, United States: 7.44
# Image segmentation: 5.00, quantization: 3.12, Error handling: 7.42
# Supply chain management: 4.90, Scientific research: 3.11, Client-side: 7.40
# mobile applications: 4.87, Electric vehicles: 3.11, disinformation: 7.25
# Export controls: 4.83, code generation: 3.10, data engineering: 7.24
# mental health: 4.78, Salesforce: 3.10, Databricks: 7.16
# software subscriptions: 4.78, Music streaming: 3.10, e-commerce: 7.07
# quantization: 4.62, Unreal Engine: 3.10, quantization: 6.91
# model compression: 4.58, interoperability: 3.02, synthetic data: 6.89
# Scientific research: 4.53, web scraping: 3.01, Model Context Protocol: 6.84
# e-commerce: 4.53, Automotive technology: 3.01, Scientific research: 6.82
# fine-tuning: 4.45, web browsers: 3.01, data: 6.81
# Speech synthesis: 4.33, legal technology: 3.01, Web3: 6.80
# vector databases: 4.23, text-to-video: 3.01, semantic search: 6.78
# synthetic data: 4.20, Workday: 3.01, Supply chain management: 6.77
# Data orchestration: 4.20, Text-to-SQL: 3.00, Vision language models: 6.73
# data: 4.12, study tools: 3.00, medical imaging: 6.71
# Meta: 4.03, Mathematics: 3.00, data quality: 6.71
# atrial fibrillation: 4.00, AI safety: 3.00, non-profit organizations: 6.63
# Virtual worlds: 4.00, telecommunications: 3.00, mixture of experts: 6.61
# Ransomware: 4.00, Video modeling: 3.00, MLOps: 6.61
# Podcasts: 4.00, Parkinson's disease: 3.00, Website accessibility: 6.52
# note-taking: 4.00, Nintendo Switch: 3.00, future of work: 6.43
# Renewable energy: 3.92, PostgreSQL: 3.00, data analysis: 6.33
# interoperability: 3.87, Microsoft Bing: 3.00, SQL: 6.29
# Electric vehicles: 3.83, Startups: 2.76, Export controls: 6.27
# algorithmic bias: 3.83, business: 2.63, public health: 6.18
# Scientific integrity: 3.83, Client-side: 2.60, copyright infringement: 6.18
# productivity: 3.82, investment: 2.51, developer tools: 6.13
# web scraping: 3.78, application programming interfaces: 2.43, algorithmic bias: 6.07
# Diffusion models: 3.75, software subscriptions: 2.41, Claude: 6.04
# code generation: 3.75, e-commerce: 2.41, information retrieval: 6.03
# Databricks: 3.70, Ransomware: 2.40, Diffusion models: 5.99
# Space technology: 3.67, mobile applications: 2.32, Data scraping: 5.90
# semantic search: 3.67, mental health: 2.31, Amazon SageMaker: 5.81
# data analysis: 3.63, Scientific integrity: 2.31, Image segmentation: 5.80
# Automotive technology: 3.58, server architecture: 2.30, Nuclear energy: 5.66
# web browsers: 3.53, deepfakes: 2.30, Performance management: 5.63
# Salesforce: 3.50, market trends: 2.27, Ransomware: 5.60
# server architecture: 3.50, synthetic data: 2.23, PyTorch: 5.53
# developer tools: 3.50, hardware acceleration: 2.22, Scientific integrity: 5.51
# Music streaming: 3.50, data: 2.22, data integration: 5.50
# deepfakes: 3.50, Space technology: 2.22, Space technology: 5.42
# Unreal Engine: 3.50, algorithmic bias: 2.21, Materials science: 5.32
# Autonomous vehicles: 3.42, Diffusion models: 2.20, interoperability: 5.28
# human creativity: 3.42, partnerships: 2.20, Autonomous vehicles: 5.25
# United Kingdom: 3.35, central processing units: 2.20, human creativity: 5.25
# Claude: 3.33, networking: 2.20, semiconductors: 5.23
# text-to-video: 3.33, Windows 11: 2.20, data sharing: 5.23
# Workday: 3.33, Distributed databases: 2.20, web scraping: 5.20
# Model Context Protocol: 3.33, fine-tuning: 2.13, Malware: 5.13
# legal technology: 3.33, Autonomous vehicles: 2.12, vision language models: 5.10
# vision language models: 3.28, human creativity: 2.12, Genomics: 5.09
# Text-to-SQL: 3.25, vision language models: 2.11, transparency: 4.96
# study tools: 3.25, data analysis: 2.11, Causal inference: 4.92
# Mathematics: 3.25, Charging infrastructure: 2.11, collaboration: 4.91
# United States: 3.23, Law enforcement: 2.11, Business process: 4.91
# partnerships: 3.20, drone technology: 2.11, Financial services: 4.89
# AI safety: 3.20, Wearable technology: 2.11, Sam Altman: 4.88
# Materials science: 3.17, labor disputes: 2.11, Speech synthesis: 4.81
# Amazon SageMaker: 3.12, uncertainty quantification: 2.10, intellectual property: 4.81
# data engineering: 3.12, Weather forecasting: 2.10, Virtual worlds: 4.80
# SQL: 3.07, defense technology: 2.10, Podcasts: 4.80
# AI ethics: 3.02, chain of thought: 2.10, inference: 4.80
# telecommunications: 3.00, United Arab Emirates: 2.10, decision making: 4.77
# central processing units: 3.00, Relationships: 2.10, Electric vehicles: 4.71
# Video modeling: 3.00, email: 2.10, Phishing: 4.71
# information retrieval: 3.00, cognitive science: 2.10, server architecture: 4.70
# networking: 3.00, Anomaly detection: 2.02, deepfakes: 4.70
# Windows 11: 3.00, AI watermarking: 2.02, cookies: 4.70
# semiconductors: 3.00, PC market: 2.02, code generation: 4.63
# Parkinson's disease: 3.00, coding assistants: 2.01, business strategy: 4.62
# uncertainty quantification: 3.00, Climate modeling: 2.01, document processing: 4.60
# document processing: 3.00, IBM: 2.01, Automotive technology: 4.54
# Distributed databases: 3.00, human resources: 2.01, web browsers: 4.47
# Nintendo Switch: 3.00, cross-region inference: 2.01, partnerships: 4.46
# data sharing: 3.00, science fiction: 2.01, educational technology: 4.42
# PostgreSQL: 3.00, no-code development: 2.01, Graph neural networks: 4.42
# Microsoft Bing: 3.00, Online scams: 2.01, feature engineering: 4.39
# Genomics: 2.95, International relations: 2.00, uncertainty quantification: 4.36
# Anomaly detection: 2.92, Random forests: 2.00, Anomaly detection: 4.35
# Performance management: 2.87, Data and AI Summit: 2.00, data warehousing: 4.33
# labor disputes: 2.83, pseudo-labeling: 2.00, coding assistants: 4.27
# Charging infrastructure: 2.83, data flywheels: 2.00, MLPerf: 4.25
# Law enforcement: 2.83, Data augmentation: 2.00, model behavior: 4.24
# drone technology: 2.83, Portfolio optimization: 2.00, Reddit: 4.24
# Wearable technology: 2.83, Neuroscience: 2.00, biomarkers: 4.23
# coding assistants: 2.83, Force prompting: 2.00, Climate modeling: 4.20
# Climate modeling: 2.78, 3D environments: 2.00, Bioinformatics: 4.16
# data integration: 2.78, attachment theory: 2.00, Python: 4.10
# future of work: 2.78, Veterans: 2.00, CUDA: 4.07
# Causal inference: 2.73, web-based research: 2.00, acquisitions: 4.06
# Weather forecasting: 2.70, investment research: 2.00, atrial fibrillation: 4.00
# educational technology: 2.67, Operating systems: 2.00, note-taking: 4.00
# AI watermarking: 2.67, US-China trade relations: 2.00, Geopolitics: 4.00
# PC market: 2.67, DeepSeek: 2.00, cognitive processes: 3.98
# Graph neural networks: 2.67, CAPTCHA: 2.00, gene expression: 3.93
# defense technology: 2.64, Brokerage: 2.00, Financial technology: 3.92
# Business process: 2.62, Hallucination: 2.00, Carbon emissions: 3.91
# IBM: 2.58, Environmental law: 2.00, Salesforce: 3.90
# human resources: 2.58, Telegram: 2.00, Music streaming: 3.90
# public health: 2.53, Electrochemical immunoassay: 2.00, Unreal Engine: 3.90
# decision making: 2.53, Plant breeding: 2.00, Baseline models: 3.82
# copyright infringement: 2.53, Lung cancer: 2.00, legal technology: 3.81
# chain of thought: 2.50, RNA sequencing: 2.00, text-to-video: 3.81
# data warehousing: 2.50, COVID-19: 2.00, Workday: 3.81
# Malware: 2.50, wastewater-based epidemiology: 2.00, central processing units: 3.80
# Financial services: 2.50, lncRNA-disease association: 2.00, networking: 3.80
# United Arab Emirates: 2.50, RNA structure: 2.00, Windows 11: 3.80
# digital infrastructure: 2.50, Drug-target affinity: 2.00, Distributed databases: 3.80
# Relationships: 2.50, Antimicrobial peptides: 2.00, Zero-shot learning: 3.79
# email: 2.50, Plant leaf disease identification: 2.00, Tariffs: 3.73
# cognitive science: 2.50, Microbiomes: 2.00, Terms of service: 3.73
# International relations: 2.45, bladder cancer: 2.00, Text-to-SQL: 3.73
# Random forests: 2.45, skeleton-based action recognition: 2.00, study tools: 3.73
# MLPerf: 2.42, Histopathology: 2.00, Mathematics: 3.73
# Data and AI Summit: 2.39, Liver transplantation: 2.00, Charging infrastructure: 3.71
# PyTorch: 2.37, Microsoft Fabric: 2.00, Law enforcement: 3.71
# pseudo-labeling: 2.37, Waymo: 2.00, labor disputes: 3.71
# science fiction: 2.33, Adobe Photoshop: 2.00, drone technology: 3.71
# no-code development: 2.33, global capability centers: 2.00, Wearable technology: 3.71
# Online scams: 2.33, Reward models: 2.00, digital infrastructure: 3.70
# cross-region inference: 2.33, Sentiment analysis: 2.00, AI safety: 3.66
# model behavior: 2.33, pandas: 2.00, AI watermarking: 3.62
# collaboration: 2.33, vertical integration: 2.00, PC market: 3.62
# Python: 2.28, geospatial intelligence: 2.00, kubernetes: 3.60
# transparency: 2.25, Sketching: 2.00, Robots.txt: 3.60
# Amazon Personalize: 2.20, Google Photos: 2.00, Weather forecasting: 3.56
# Sam Altman: 2.17, Data orchestration: 1.41, IBM: 3.54
# business models: 2.17, document processing: 1.40, human resources: 3.54
# human-in-the-loop: 2.17, developer tools: 1.33, 3D reconstruction: 3.52
# intellectual property: 2.12, Renewable energy: 1.32, business models: 3.52
# Unreal Editor for Fortnite: 2.08, semantic search: 1.32, human-in-the-loop: 3.52
# inference: 2.08, Databricks: 1.32, data preprocessing: 3.51
# Geopolitics: 2.08, Materials science: 1.32, diagnostic accuracy: 3.51
# antitrust: 2.08, Genomics: 1.30, State space models: 3.51
# Reddit: 2.08, digital infrastructure: 1.30, Amazon Personalize: 3.46
# data flywheels: 2.00, Claude: 1.24, Unreal Editor for Fortnite: 3.44
# Data augmentation: 2.00, semiconductors: 1.23, antitrust: 3.44
# Portfolio optimization: 2.00, data sharing: 1.23, defense technology: 3.43
# kubernetes: 2.00, Amazon SageMaker: 1.22, Gemini (language model): 3.42
# Neuroscience: 2.00, educational technology: 1.22, summarization: 3.42
# Force prompting: 2.00, Graph neural networks: 1.22, International relations: 3.39
# 3D environments: 2.00, Causal inference: 1.21, Random forests: 3.39
# attachment theory: 2.00, Amazon Personalize: 1.20, Data lakehouse: 3.36
# Veterans: 2.00, career advice: 1.20, microservices: 3.35
# web-based research: 2.00, AI assistants: 1.20, Foundation models: 3.34
# investment research: 2.00, data warehousing: 1.13, Publishing: 3.33
# career advice: 2.00, SQL: 1.12, Data and AI Summit: 3.26
# Operating systems: 2.00, Performance management: 1.12, transformers: 3.26
# US-China trade relations: 2.00, data integration: 1.12, Sanctions: 3.25
# DeepSeek: 2.00, Business process: 1.12, threat detection: 3.25
# CAPTCHA: 2.00, MLPerf: 1.12, research and development: 3.25
# Brokerage: 2.00, decision making: 1.12, pseudo-labeling: 3.25
# Robots.txt: 2.00, business models: 1.12, innovation: 3.22
# Hallucination: 2.00, human-in-the-loop: 1.12, emotional intelligence: 3.22
# Environmental law: 2.00, Python: 1.11, simulation: 3.21
# Telegram: 2.00, Unreal Editor for Fortnite: 1.11, ESG: 3.17
# Electrochemical immunoassay: 2.00, antitrust: 1.11, content marketing: 3.17
# Plant breeding: 2.00, question answering: 1.11, Elon Musk: 3.10
# Lung cancer: 2.00, cyborgs: 1.11, SAML: 3.09
# RNA sequencing: 2.00, Data lakehouse: 1.10, Data Breach: 3.08
# COVID-19: 2.00, innovation: 1.10, computer hardware: 3.08
# wastewater-based epidemiology: 2.00, emotional intelligence: 1.10, cryo-electron microscopy: 3.08
# lncRNA-disease association: 2.00, agent-based modeling: 1.10, variable importance: 3.08
# RNA structure: 2.00, Disaster response: 1.10, scalability: 3.01
# Drug-target affinity: 2.00, Quadruped robots: 1.10, telecommunications: 3.00
# Antimicrobial peptides: 2.00, Kaggle: 1.10, Video modeling: 3.00
# Plant leaf disease identification: 2.00, High voltage direct current: 1.10, Parkinson's disease: 3.00
# Microbiomes: 2.00, content monetization: 1.10, Nintendo Switch: 3.00
# bladder cancer: 2.00, proof of concept: 1.10, PostgreSQL: 3.00
# skeleton-based action recognition: 2.00, SAG-AFTRA: 1.10, Microsoft Bing: 3.00
# Histopathology: 2.00, Online Pharmacy: 1.10, gradient boosting: 3.00
# Liver transplantation: 2.00, computer science: 1.10, tool use: 2.94
# Microsoft Fabric: 2.00, OpenSearch: 1.10, Immunotherapy: 2.92
# Data lakehouse: 2.00, Business growth: 1.10, chain of thought: 2.90
# Waymo: 2.00, co-packaged optics: 1.10, United Arab Emirates: 2.90
# Adobe Photoshop: 2.00, Lawrence Berkeley National Laboratory: 1.10, Relationships: 2.90
# global capability centers: 2.00, voice applications: 1.10, email: 2.90
# Reward models: 2.00, self-efficacy: 1.10, cognitive science: 2.90
# Sentiment analysis: 2.00, handwriting analysis: 1.10, Funding: 2.89
# pandas: 2.00, Dashboards: 1.10, Return on investment: 2.84
# vertical integration: 2.00, data transformations: 1.10, cross-region inference: 2.81
# geospatial intelligence: 2.00, Microsoft Outlook: 1.10, science fiction: 2.81
# Sketching: 2.00, fact-checking: 1.10, no-code development: 2.81
# Google Photos: 2.00, augmented reality: 1.10, Online scams: 2.81
# AI assistants: 2.00, productivity: 1.05, career advice: 2.80
# biomarkers: 2.00, model behavior: 1.04, AI assistants: 2.80
# emotional intelligence: 1.92, Financial services: 1.03, Hugging Face Hub: 2.74
# microservices: 1.92, United States: 1.02, AI policy: 2.74
# Phishing: 1.92, microservices: 1.02, question answering: 2.71
# innovation: 1.92, simulation: 1.02, cyborgs: 2.71
# data preprocessing: 1.83, film: 1.02, Physics: 2.70
# CUDA: 1.83, super-resolution imaging: 1.02, enterprise adoption: 2.70
# State space models: 1.83, Geopolitics: 1.01, Cluster analysis: 2.70
# diagnostic accuracy: 1.83, Windows: 1.01, MetaHuman: 2.70
# question answering: 1.83, LlamaIndex: 1.01, Human-computer interaction: 2.70
# cyborgs: 1.83, Vulnerability management: 1.01, agent-based modeling: 2.63
# simulation: 1.83, Indonesia: 1.01, Disaster response: 2.63
# cookies: 1.83, data migration: 1.01, Quadruped robots: 2.63
# agent-based modeling: 1.75, data loss prevention: 1.01, film: 2.62
# Disaster response: 1.75, Patch management: 1.01, super-resolution imaging: 2.62
# Quadruped robots: 1.75, Tech sovereignty: 1.01, Palantir: 2.61
# business strategy: 1.75, language translation: 1.01, market dominance: 2.61
# acquisitions: 1.75, Zero trust: 1.01, TSMC: 2.61
# Financial technology: 1.73, XML: 1.01, government: 2.61
# cognitive processes: 1.67, LangGraph: 1.01, Air quality: 2.61
# film: 1.67, Human consciousness: 1.01, divestitures: 2.61
# Gemini (language model): 1.67, Microtransactions: 1.01, Biomimicry: 2.61
# Zero-shot learning: 1.67, leadership: 1.00, Samsung: 2.61
# super-resolution imaging: 1.67, speech recognition: 1.00, Windows: 2.54
# summarization: 1.67, copyright law: 1.00, LlamaIndex: 2.54
# Carbon emissions: 1.62, Robot Operating System: 1.00, Sales: 2.53
# Windows: 1.58, Facial recognition: 1.00, Digital assets: 2.53
# Foundation models: 1.58, AI agents: 1.00, DevOps: 2.53
# LlamaIndex: 1.58, Bioprinting: 1.00, Smart contracts: 2.53
# feature engineering: 1.57, Fintech: 1.00, toolkits: 2.52
# Vulnerability management: 1.53, Government legislation: 1.00, Jony Ive: 2.52
# Kaggle: 1.50, cyberpunk: 1.00, medical diagnosis: 2.52
# High voltage direct current: 1.50, AI software: 1.00, software as a service: 2.52
# leadership: 1.50, Social media: 1.00, GitHub Actions: 2.52
# Physics: 1.50, economic impact: 0.84, Vulnerability management: 2.47
# speech recognition: 1.50, vector databases: 0.61, leadership: 2.46
# content monetization: 1.50, model compression: 0.47, speech recognition: 2.46
# proof of concept: 1.50, Meta: 0.44, copyright law: 2.46
# enterprise adoption: 1.50, Model Context Protocol: 0.44, communication: 2.44
# Baseline models: 1.50, information retrieval: 0.43, Brain mapping: 2.43
# Cluster analysis: 1.50, kubernetes: 0.40, Surveillance: 2.43
# transformers: 1.50, Robots.txt: 0.40, Pharmaceutical Industry: 2.43
# SAG-AFTRA: 1.50, Malware: 0.33, Robot Operating System: 2.39
# Online Pharmacy: 1.50, collaboration: 0.32, Facial recognition: 2.39
# computer science: 1.50, Reddit: 0.31, AI agents: 2.39
# OpenSearch: 1.50, data preprocessing: 0.31, technology assessment: 2.37
# Business growth: 1.50, State space models: 0.31, Amazon: 2.37
# co-packaged optics: 1.50, diagnostic accuracy: 0.31, financial performance: 2.36
# MetaHuman: 1.50, Physics: 0.30, electronic design automation: 2.35
# Lawrence Berkeley National Laboratory: 1.50, enterprise adoption: 0.30, Transfer learning: 2.35
# voice applications: 1.50, Cluster analysis: 0.30, trust: 2.29
# Human-computer interaction: 1.50, MetaHuman: 0.30, AMD: 2.29
# self-efficacy: 1.50, Human-computer interaction: 0.30, Long-term memory: 2.28
# handwriting analysis: 1.50, data engineering: 0.25, Product reviews: 2.28
# Dashboards: 1.50, future of work: 0.24, XGBoost: 2.27
# data transformations: 1.50, United Kingdom: 0.23, distributed training: 2.27
# Microsoft Outlook: 1.50, transparency: 0.23, Fluid dynamics: 2.27
# fact-checking: 1.50, biomarkers: 0.23, Decentralized computing: 2.22
# augmented reality: 1.50, PyTorch: 0.22, Unity Catalog: 2.21
# copyright law: 1.50, Sam Altman: 0.22, artificial general intelligence: 2.21
# Publishing: 1.50, intellectual property: 0.22, Japan: 2.21
# Robot Operating System: 1.45, Gemini (language model): 0.22, Licensing: 2.20
# Facial recognition: 1.45, summarization: 0.22, traffic management: 2.20
# AI agents: 1.45, public health: 0.21, content creation: 2.20
# Sanctions: 1.42, copyright infringement: 0.21, OpenUSD: 2.19
# threat detection: 1.42, inference: 0.21, memory management: 2.13
# research and development: 1.42, CUDA: 0.21, enterprise software: 2.12
# Bioinformatics: 1.38, Foundation models: 0.21, model optimization: 2.11
# Tariffs: 1.37, Financial technology: 0.21, Customer experience: 2.04
# Terms of service: 1.37, Zero-shot learning: 0.21, brand management: 2.02
# TSMC: 1.33, TSMC: 0.21, data flywheels: 2.00
# Indonesia: 1.33, government: 0.21, Data augmentation: 2.00
# government: 1.33, Air quality: 0.21, Portfolio optimization: 2.00
# Air quality: 1.33, divestitures: 0.21, Neuroscience: 2.00
# divestitures: 1.33, Palantir: 0.21, Force prompting: 2.00
# Palantir: 1.33, Biomimicry: 0.21, 3D environments: 2.00
# Biomimicry: 1.33, Samsung: 0.21, attachment theory: 2.00
# data migration: 1.33, market dominance: 0.21, Veterans: 2.00
# data loss prevention: 1.33, transformers: 0.20, web-based research: 2.00
# Samsung: 1.33, Sales: 0.20, investment research: 2.00
# Patch management: 1.33, Digital assets: 0.20, Operating systems: 2.00
# Tech sovereignty: 1.33, DevOps: 0.20, US-China trade relations: 2.00
# language translation: 1.33, Smart contracts: 0.20, DeepSeek: 2.00
# Zero trust: 1.33, stroke: 0.20, CAPTCHA: 2.00
# XML: 1.33, model faithfulness: 0.20, Brokerage: 2.00
# ESG: 1.33, Apple Intelligence: 0.20, Hallucination: 2.00
# LangGraph: 1.33, Real-time translation: 0.20, Environmental law: 2.00
# market dominance: 1.33, behavioral analysis: 0.20, Telegram: 2.00
# Human consciousness: 1.33, Hearing loss: 0.20, Electrochemical immunoassay: 2.00
# Microtransactions: 1.33, ReAct architecture: 0.20, Plant breeding: 2.00
# content marketing: 1.33, Technology investment: 0.20, Lung cancer: 2.00
# gene expression: 1.32, model updates: 0.20, RNA sequencing: 2.00
# 3D reconstruction: 1.30, Company formation: 0.20, COVID-19: 2.00
# Elon Musk: 1.28, Sweden: 0.20, wastewater-based epidemiology: 2.00
# Sales: 1.25, wage growth: 0.20, lncRNA-disease association: 2.00
# Digital assets: 1.25, shutdown sabotage: 0.20, RNA structure: 2.00
# DevOps: 1.25, ASUS: 0.20, Drug-target affinity: 2.00
# Bioprinting: 1.25, interrogation: 0.20, Antimicrobial peptides: 2.00
# SAML: 1.25, 3D video conferencing: 0.20, Plant leaf disease identification: 2.00
# Smart contracts: 1.25, T cell antigens: 0.20, Microbiomes: 2.00
# Fintech: 1.25, Kinesiophobia: 0.20, bladder cancer: 2.00
# Government legislation: 1.25, isoform quantification: 0.20, skeleton-based action recognition: 2.00
# cyberpunk: 1.20, Scientific databases: 0.20, Histopathology: 2.00
# AI software: 1.20, motor symptoms: 0.20, Liver transplantation: 2.00
# Social media: 1.20, nonnegative matrix factorization: 0.20, Microsoft Fabric: 2.00
# toolkits: 1.17, structural biology: 0.20, Waymo: 2.00
# Data Breach: 1.17, de novo design: 0.20, Adobe Photoshop: 2.00
# Jony Ive: 1.17, structured illumination microscopy: 0.20, global capability centers: 2.00
# Funding: 1.17, Spatial transcriptomics: 0.20, Reward models: 2.00
# computer hardware: 1.17, microRNA: 0.20, Sentiment analysis: 2.00
# cryo-electron microscopy: 1.17, Image interpolation: 0.20, pandas: 2.00
# variable importance: 1.17, royalty fraud: 0.20, vertical integration: 2.00
# medical diagnosis: 1.17, unemployment: 0.20, geospatial intelligence: 2.00
# software as a service: 1.17, technology addiction: 0.20, Sketching: 2.00
# GitHub Actions: 1.17, in-vehicle connectivity: 0.20, Google Photos: 2.00
# tool use: 1.15, small and medium-sized enterprises: 0.20, Kaggle: 1.90
# scalability: 1.12, attention mechanism: 0.20, High voltage direct current: 1.90
# gradient boosting: 1.08, cultural analysis: 0.20, content monetization: 1.90
# communication: 1.08, Well-being: 0.20, proof of concept: 1.90
# AI policy: 1.03, Climate change: 0.20, SAG-AFTRA: 1.90
# technology assessment: 1.03, Alphabet: 0.20, Online Pharmacy: 1.90
# Hugging Face Hub: 1.03, job displacement: 0.20, computer science: 1.90
# Amazon: 1.03, Gemini: 0.20, OpenSearch: 1.90
# stroke: 1.00, AI ethics: 0.15, Business growth: 1.90
# Brain mapping: 1.00, acquisitions: 0.13, co-packaged optics: 1.90
# model faithfulness: 1.00, Publishing: 0.13, Lawrence Berkeley National Laboratory: 1.90
# Apple Intelligence: 1.00, Phishing: 0.12, voice applications: 1.90
# Real-time translation: 1.00, cognitive processes: 0.12, self-efficacy: 1.90
# behavioral analysis: 1.00, Carbon emissions: 0.12, handwriting analysis: 1.90
# Hearing loss: 1.00, Sanctions: 0.12, Dashboards: 1.90
# ReAct architecture: 1.00, threat detection: 0.12, data transformations: 1.90
# Technology investment: 1.00, research and development: 0.12, Microsoft Outlook: 1.90
# model updates: 1.00, toolkits: 0.12, fact-checking: 1.90
# Company formation: 1.00, Jony Ive: 0.12, augmented reality: 1.90
# Sweden: 1.00, GitHub Actions: 0.12, Indonesia: 1.81
# wage growth: 1.00, medical diagnosis: 0.12, data migration: 1.81
# financial performance: 1.00, software as a service: 0.12, data loss prevention: 1.81
# shutdown sabotage: 1.00, ESG: 0.11, Patch management: 1.81
# ASUS: 1.00, content marketing: 0.11, Tech sovereignty: 1.81
# interrogation: 1.00, Elon Musk: 0.11, language translation: 1.81
# 3D video conferencing: 1.00, communication: 0.11, Zero trust: 1.81
# T cell antigens: 1.00, technology assessment: 0.11, XML: 1.81
# Immunotherapy: 1.00, Amazon: 0.11, LangGraph: 1.81
# Kinesiophobia: 1.00, Funding: 0.11, Human consciousness: 1.81
# isoform quantification: 1.00, stacking: 0.11, Microtransactions: 1.81
# Scientific databases: 1.00, software installation: 0.11, stroke: 1.80
# Surveillance: 1.00, Sim-to-Real Transfer: 0.11, model faithfulness: 1.80
# motor symptoms: 1.00, logistics: 0.11, Apple Intelligence: 1.80
# nonnegative matrix factorization: 1.00, Oracle: 0.11, Real-time translation: 1.80
# structural biology: 1.00, freelance work: 0.11, behavioral analysis: 1.80
# de novo design: 1.00, tropical cyclones: 0.11, Hearing loss: 1.80
# structured illumination microscopy: 1.00, privileged access management: 0.11, ReAct architecture: 1.80
# Spatial transcriptomics: 1.00, bankruptcy: 0.11, Technology investment: 1.80
# microRNA: 1.00, Google I/O: 0.11, model updates: 1.80
# Image interpolation: 1.00, Biosensors: 0.11, Company formation: 1.80
# Pharmaceutical Industry: 1.00, Powdery mildew: 0.11, Sweden: 1.80
# royalty fraud: 1.00, revenge porn: 0.11, wage growth: 1.80
# unemployment: 1.00, TensorRT: 0.11, shutdown sabotage: 1.80
# technology addiction: 1.00, Linear algebra: 0.11, ASUS: 1.80
# in-vehicle connectivity: 1.00, Low-rank adaptation: 0.11, interrogation: 1.80
# small and medium-sized enterprises: 1.00, Humor: 0.11, 3D video conferencing: 1.80
# attention mechanism: 1.00, React: 0.11, T cell antigens: 1.80
# cultural analysis: 1.00, transportation: 0.11, Kinesiophobia: 1.80
# Well-being: 1.00, Canva: 0.11, isoform quantification: 1.80
# Climate change: 1.00, Journalism: 0.11, Scientific databases: 1.80
# Alphabet: 1.00, technology: 0.11, motor symptoms: 1.80
# job displacement: 1.00, User stories: 0.11, nonnegative matrix factorization: 1.80
# Gemini: 1.00, recycling: 0.11, structural biology: 1.80
# Return on investment: 0.95, GPU: 0.11, de novo design: 1.80
# trust: 0.95, Baseline models: 0.10, structured illumination microscopy: 1.80
# AMD: 0.95, SAML: 0.10, Spatial transcriptomics: 1.80
# Decentralized computing: 0.92, financial performance: 0.10, microRNA: 1.80
# electronic design automation: 0.92, tool use: 0.10, Image interpolation: 1.80
# Transfer learning: 0.92, trust: 0.10, royalty fraud: 1.80
# artificial general intelligence: 0.90, AMD: 0.10, unemployment: 1.80
# Unity Catalog: 0.90, Decentralized computing: 0.10, technology addiction: 1.80
# Long-term memory: 0.87, Malaysia: 0.10, in-vehicle connectivity: 1.80
# Product reviews: 0.87, LangChain: 0.10, small and medium-sized enterprises: 1.80
# XGBoost: 0.83, freedom of speech: 0.10, attention mechanism: 1.80
# stacking: 0.83, Video game updates: 0.10, cultural analysis: 1.80
# software installation: 0.83, European Union: 0.10, Well-being: 1.80
# Sim-to-Real Transfer: 0.83, online courses: 0.10, Climate change: 1.80
# logistics: 0.83, Life sciences: 0.10, Alphabet: 1.80
# Japan: 0.83, defense spending: 0.10, job displacement: 1.80
# Oracle: 0.83, multilingual support: 0.10, Gemini: 1.80
# freelance work: 0.83, social media: 0.10, Bioprinting: 1.73
# tropical cyclones: 0.83, utility: 0.10, Fintech: 1.73
# privileged access management: 0.83, data strategy: 0.10, Government legislation: 1.73
# bankruptcy: 0.83, 3D reconstruction: 0.10, stacking: 1.71
# Google I/O: 0.83, Unity Catalog: 0.10, software installation: 1.71
# Biosensors: 0.83, artificial general intelligence: 0.10, Sim-to-Real Transfer: 1.71
# Powdery mildew: 0.83, Hugging Face Hub: 0.10, logistics: 1.71
# revenge porn: 0.83, AI policy: 0.10, Oracle: 1.71
# TensorRT: 0.83, Ukraine: 0.10, freelance work: 1.71
# Linear algebra: 0.83, Media: 0.10, tropical cyclones: 1.71
# Low-rank adaptation: 0.83, waste reduction: 0.10, privileged access management: 1.71
# Humor: 0.83, brand management: 0.10, bankruptcy: 1.71
# distributed training: 0.83, cookies: 0.04, Google I/O: 1.71
# React: 0.83, business strategy: 0.03, Biosensors: 1.71
# transportation: 0.83, Brain mapping: 0.03, Powdery mildew: 1.71
# Canva: 0.83, Surveillance: 0.03, revenge porn: 1.71
# Journalism: 0.83, Pharmaceutical Industry: 0.03, TensorRT: 1.71
# technology: 0.83, feature engineering: 0.02, Linear algebra: 1.71
# Fluid dynamics: 0.83, Tariffs: 0.02, Low-rank adaptation: 1.71
# User stories: 0.83, Terms of service: 0.02, Humor: 1.71
# recycling: 0.83, Data Breach: 0.02, React: 1.71
# GPU: 0.83, computer hardware: 0.02, transportation: 1.71
# brand management: 0.81, cryo-electron microscopy: 0.02, Canva: 1.71
# Licensing: 0.78, variable importance: 0.02, Journalism: 1.71
# traffic management: 0.78, scalability: 0.02, technology: 1.71
# content creation: 0.78, electronic design automation: 0.02, User stories: 1.71
# Malaysia: 0.75, Transfer learning: 0.02, recycling: 1.71
# LangChain: 0.75, gene expression: 0.02, GPU: 1.71
# freedom of speech: 0.75, Long-term memory: 0.02, cyberpunk: 1.66
# OpenUSD: 0.75, Product reviews: 0.02, AI software: 1.66
# Video game updates: 0.75, Japan: 0.02, Social media: 1.66
# European Union: 0.75, Grace Hopper: 0.02, Malaysia: 1.63
# online courses: 0.75, Hybrid algorithms: 0.02, LangChain: 1.63
# Life sciences: 0.75, Animated 3D icons: 0.02, freedom of speech: 1.63
# defense spending: 0.75, Assistive technology: 0.02, Video game updates: 1.63
# multilingual support: 0.75, Third-party risk: 0.02, European Union: 1.63
# social media: 0.75, WWDC: 0.02, online courses: 1.63
# utility: 0.75, business value: 0.02, Life sciences: 1.63
# memory management: 0.75, Fannie Mae: 0.02, defense spending: 1.63
# data strategy: 0.75, Inflation: 0.02, multilingual support: 1.63
# enterprise software: 0.73, Pavel Durov: 0.02, social media: 1.63
# Ukraine: 0.70, visual reasoning: 0.02, utility: 1.63
# Media: 0.70, coercion: 0.02, data strategy: 1.63
# waste reduction: 0.70, Antigen-HLA binding: 0.02, Grace Hopper: 1.62
# model optimization: 0.70, chemical probing: 0.02, Hybrid algorithms: 1.62
# Grace Hopper: 0.67, Multitask learning: 0.02, Animated 3D icons: 1.62
# Hybrid algorithms: 0.67, multiplexed immunofluorescence: 0.02, Assistive technology: 1.62
# Animated 3D icons: 0.67, Microbiology: 0.02, Third-party risk: 1.62
# Assistive technology: 0.67, disulfide bonds: 0.02, WWDC: 1.62
# Third-party risk: 0.67, infrared technology: 0.02, business value: 1.62
# WWDC: 0.67, Optical flow: 0.02, Fannie Mae: 1.62
# business value: 0.67, Dimensionality reduction: 0.02, Inflation: 1.62
# Fannie Mae: 0.67, voice acting: 0.02, Pavel Durov: 1.62
# Inflation: 0.67, Sustainability: 0.02, visual reasoning: 1.62
# Pavel Durov: 0.67, Optical character recognition: 0.02, coercion: 1.62
# visual reasoning: 0.67, independent artists: 0.02, Antigen-HLA binding: 1.62
# coercion: 0.67, portable gaming: 0.02, chemical probing: 1.62
# Antigen-HLA binding: 0.67, SerDes: 0.02, Multitask learning: 1.62
# chemical probing: 0.67, Exploit: 0.02, multiplexed immunofluorescence: 1.62
# Multitask learning: 0.67, generational differences: 0.02, Microbiology: 1.62
# multiplexed immunofluorescence: 0.67, Color recognition: 0.02, disulfide bonds: 1.62
# Microbiology: 0.67, upskilling: 0.02, infrared technology: 1.62
# disulfide bonds: 0.67, multimodal AI: 0.02, Optical flow: 1.62
# infrared technology: 0.67, debugging: 0.02, Dimensionality reduction: 1.62
# Optical flow: 0.67, gradient boosting: 0.01, voice acting: 1.62
# Dimensionality reduction: 0.67, XGBoost: 0.01, Sustainability: 1.62
# voice acting: 0.67, distributed training: 0.01, Optical character recognition: 1.62
# Sustainability: 0.67, Fluid dynamics: 0.01, independent artists: 1.62
# Optical character recognition: 0.67, Bioinformatics: 0.01, portable gaming: 1.62
# independent artists: 0.67, Licensing: 0.01, SerDes: 1.62
# portable gaming: 0.67, traffic management: 0.01, Exploit: 1.62
# SerDes: 0.67, content creation: 0.01, generational differences: 1.62
# Exploit: 0.67, memory management: 0.01, Color recognition: 1.62
# generational differences: 0.67, Disease resistance: 0.01, upskilling: 1.62
# Color recognition: 0.67, Neuromorphic computing: 0.01, multimodal AI: 1.62
# upskilling: 0.67, censorship: 0.01, debugging: 1.62
# multimodal AI: 0.67, Donald Trump: 0.01, Ukraine: 1.56
# debugging: 0.67, game communities: 0.01, Media: 1.56
# Customer experience: 0.65, Constellation Energy: 0.01, waste reduction: 1.56
# Disease resistance: 0.58, Penetration Testing: 0.01, Disease resistance: 1.54
# Neuromorphic computing: 0.58, Legal ethics: 0.01, Neuromorphic computing: 1.54
# censorship: 0.58, Epic Games Store: 0.01, censorship: 1.54
# Donald Trump: 0.58, Token management: 0.01, Donald Trump: 1.54
# game communities: 0.58, data lineage: 0.01, game communities: 1.54
# Constellation Energy: 0.58, offline computing: 0.01, Constellation Energy: 1.54
# Penetration Testing: 0.58, game development: 0.01, Penetration Testing: 1.54
# Legal ethics: 0.58, productivity tools: 0.01, Legal ethics: 1.54
# Epic Games Store: 0.58, enterprise software: 0.01, Epic Games Store: 1.54
# Token management: 0.58, Digital skills: 0.01, Token management: 1.54
# data lineage: 0.58, digital rights: 0.01, data lineage: 1.54
# offline computing: 0.58, RTX Remix: 0.01, offline computing: 1.54
# game development: 0.58, Initial public offering: 0.01, game development: 1.54
# productivity tools: 0.58, Satellite imagery: 0.01, productivity tools: 1.54
# Digital skills: 0.53, embeddings: 0.01, Digital skills: 1.47
# digital rights: 0.53, QLoRA: 0.01, digital rights: 1.47
# RTX Remix: 0.53, DNS rebinding: 0.01, RTX Remix: 1.47
# Initial public offering: 0.53, Perplexity: 0.01, Initial public offering: 1.47
# Satellite imagery: 0.53, user agreement: 0.01, Satellite imagery: 1.47
# embeddings: 0.53, A/B testing: 0.01, embeddings: 1.47
# QLoRA: 0.53, Authentication: 0.01, QLoRA: 1.47
# DNS rebinding: 0.53, AWS CDK: 0.01, DNS rebinding: 1.47
# Perplexity: 0.53, Immunotherapy: 0.00, Perplexity: 1.47
# user agreement: 0.53, Return on investment: 0.00, user agreement: 1.47
# Database: 0.50, OpenUSD: 0.00, Database: 1.46
# CPU offloading: 0.50, model optimization: 0.00, CPU offloading: 1.46
# Red Hat OpenShift: 0.50, Database: 0.00, Red Hat OpenShift: 1.46
# Brown University: 0.50, CPU offloading: 0.00, Brown University: 1.46
# speculative decoding: 0.50, Red Hat OpenShift: 0.00, speculative decoding: 1.46
# regulatory compliance: 0.50, Brown University: 0.00, regulatory compliance: 1.46
# Checklists: 0.50, speculative decoding: 0.00, Checklists: 1.46
# Political influence: 0.50, regulatory compliance: 0.00, Political influence: 1.46
# International trade: 0.50, Checklists: 0.00, International trade: 1.46
# Bloomberg: 0.50, Political influence: 0.00, Bloomberg: 1.46
# Hardware pricing: 0.50, International trade: 0.00, Hardware pricing: 1.46
# financial planning: 0.50, Bloomberg: 0.00, financial planning: 1.46
# Goodhart's law: 0.50, Hardware pricing: 0.00, Goodhart's law: 1.46
# Financial restructuring: 0.50, financial planning: 0.00, Financial restructuring: 1.46
# Service disruption: 0.50, Goodhart's law: 0.00, Service disruption: 1.46
# accelerometer: 0.50, Financial restructuring: 0.00, accelerometer: 1.46
# Mitochondrial morphology: 0.50, Service disruption: 0.00, Mitochondrial morphology: 1.46
# Access Control: 0.50, accelerometer: 0.00, Access Control: 1.46
# geology: 0.50, Mitochondrial morphology: 0.00, geology: 1.46
# Coronary artery bypass grafting: 0.50, Access Control: 0.00, Coronary artery bypass grafting: 1.46
# A/B testing: 0.50, geology: 0.00, system on a chip: 1.46
# Authentication: 0.50, Coronary artery bypass grafting: 0.00, Data visualization: 1.46
# system on a chip: 0.50, system on a chip: 0.00, North America: 1.46
# AWS CDK: 0.50, Data visualization: 0.00, search technology: 1.46
# Data visualization: 0.50, North America: 0.00, A/B testing: 1.40
# North America: 0.50, search technology: 0.00, Authentication: 1.40
# search technology: 0.50, Customer experience: 0.00, AWS CDK: 1.40
# Barley: 0.45, Barley: 0.00, Barley: 1.39
# antimicrobial resistance: 0.45, antimicrobial resistance: 0.00, antimicrobial resistance: 1.39
# multiple sequence alignment: 0.45, multiple sequence alignment: 0.00, multiple sequence alignment: 1.39
# Apache Iceberg: 0.45, Apache Iceberg: 0.00, Apache Iceberg: 1.39
# contemporary literature: 0.45, contemporary literature: 0.00, contemporary literature: 1.39
# Security Operations Center: 0.45, Security Operations Center: 0.00, Security Operations Center: 1.39
# Moral concern: 0.45, Moral concern: 0.00, Moral concern: 1.39
# Influence campaigns: 0.45, Influence campaigns: 0.00, Influence campaigns: 1.39
# problem solving: 0.45, problem solving: 0.00, problem solving: 1.39
# AI governance: 0.45, AI governance: 0.00, AI governance: 1.39
# cancer research: 0.45, cancer research: 0.00, cancer research: 1.39
# AI platforms: 0.45, AI platforms: 0.00, AI platforms: 1.39
# unified memory: 0.40, unified memory: 0.00, unified memory: 1.31
# magnetic resonance imaging: 0.40, magnetic resonance imaging: 0.00, magnetic resonance imaging: 1.31
# supercomputers: 0.40, supercomputers: 0.00, supercomputers: 1.31
# FP8 training: 0.40, FP8 training: 0.00, FP8 training: 1.31
# skills gap: 0.40, skills gap: 0.00, skills gap: 1.31
# Glossaries: 0.40, Glossaries: 0.00, Glossaries: 1.31
# Siri: 0.40, Siri: 0.00, Siri: 1.31
# Economic uncertainty: 0.40, Economic uncertainty: 0.00, Economic uncertainty: 1.31
# Neoantigens: 0.40, Neoantigens: 0.00, Neoantigens: 1.31
# inceptionTime: 0.40, inceptionTime: 0.00, inceptionTime: 1.31
# Duchenne muscular dystrophy: 0.40, Duchenne muscular dystrophy: 0.00, Duchenne muscular dystrophy: 1.31
# computational efficiency: 0.40, computational efficiency: 0.00, computational efficiency: 1.31
# Fuzzy Logic: 0.40, Fuzzy Logic: 0.00, Fuzzy Logic: 1.31
# Earth's core: 0.40, Earth's core: 0.00, Earth's core: 1.31
# Digital cameras: 0.40, Digital cameras: 0.00, Digital cameras: 1.31
# Entertainment: 0.40, Entertainment: 0.00, Entertainment: 1.31
# Government policy: 0.40, Government policy: 0.00, Government policy: 1.31
# AI alignment: 0.40, AI alignment: 0.00, AI alignment: 1.31
# Facility management: 0.37, Facility management: 0.00, Facility management: 1.25
# NAACP: 0.37, NAACP: 0.00, NAACP: 1.25
# Postoperative care: 0.37, Postoperative care: 0.00, Postoperative care: 1.25
# Cardiovascular disease: 0.37, Cardiovascular disease: 0.00, Cardiovascular disease: 1.25
# automatic mixed precision: 0.33, automatic mixed precision: 0.00, automatic mixed precision: 1.18
# Sharpe ratio: 0.33, Sharpe ratio: 0.00, Sharpe ratio: 1.18
# PowerShell: 0.33, PowerShell: 0.00, PowerShell: 1.18
# thermodynamic models: 0.33, thermodynamic models: 0.00, thermodynamic models: 1.18
# live-cell imaging: 0.33, live-cell imaging: 0.00, live-cell imaging: 1.18
# cell segmentation: 0.33, cell segmentation: 0.00, cell segmentation: 1.18
# Algorithm: 0.33, Algorithm: 0.00, Algorithm: 1.18
# Reputation systems: 0.33, Reputation systems: 0.00, Reputation systems: 1.18

# %% [markdown]
# ### Look at linear selection using linear vs sub-exp vs sup-exp order

# %%
from ttd.flows.article_selection.steps.select_articles import compute_article_cluster_scores
from ttd.flows.article_selection.steps.select_articles import get_top_n_articles
from typing import Callable

linearly_scored_articles = compute_article_cluster_scores(
        articles, linear_cluster_scores, order_metric=linear_order_metric
)
top_n_linearly_scored_articles = get_top_n_articles(linearly_scored_articles, n=20)
sub_scored_articles = compute_article_cluster_scores(
        articles, sub_exponential_cluster_scores, order_metric=linear_order_metric
)
top_n_sub_scored_articles = get_top_n_articles(sub_scored_articles, n=20)
sup_scored_articles = compute_article_cluster_scores(
        articles, sup_exponential_cluster_scores, order_metric=linear_order_metric
)
top_n_sup_scored_articles = get_top_n_articles(sup_scored_articles, n=20)
for article, article_2, article_3 in zip(top_n_linearly_scored_articles, top_n_sub_scored_articles, top_n_sup_scored_articles):
        print(f"{article['clusters_score']:0.2f} {article['title']}")
        print(article['clusters_names_in_order_added'])
        print(f"{article_2['clusters_score']:0.2f} {article_2['title']}")
        print(article_2['clusters_names_in_order_added'])
        print(f"{article_3['clusters_score']:0.2f} {article_3['title']}")
        print(article_3['clusters_names_in_order_added'])
        print("-"*100)
# Out:
# 88.77 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# 52.58 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# 141.23 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# ----------------------------------------------------------------------------------------------------
# 88.17 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 52.45 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 140.46 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# ----------------------------------------------------------------------------------------------------
# 88.17 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 51.45 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# 140.46 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# ----------------------------------------------------------------------------------------------------
# 87.85 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# 51.45 Welcome to the AI factory era: A preview of Dell Technologies World 2025
# ['NVIDIA', 'automation']
# 140.02 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# ----------------------------------------------------------------------------------------------------
# 87.69 JFrog and Nvidia partner on secure software supply chain for Enterprise AI Factory
# ['data science', 'NVIDIA']
# 51.06 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# 139.10 JFrog and Nvidia partner on secure software supply chain for Enterprise AI Factory
# ['data science', 'NVIDIA']
# ----------------------------------------------------------------------------------------------------
# 86.67 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 50.81 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 130.62 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# ----------------------------------------------------------------------------------------------------
# 85.61 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# 50.81 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 130.37 Your 2025 Data and AI Summit Guide for Public Sector Industry Experience
# ['data science', 'reliability', 'public sector', 'data governance', 'data privacy', 'Databricks']
# ----------------------------------------------------------------------------------------------------
# 85.38 Welcome to the AI factory era: A preview of Dell Technologies World 2025
# ['NVIDIA', 'automation']
# 50.80 JFrog and Nvidia partner on secure software supply chain for Enterprise AI Factory
# ['data science', 'NVIDIA']
# 129.45 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# ----------------------------------------------------------------------------------------------------
# 83.45 Microsoft Just Laid Off 6,000 Workers. And AI Might Be to Blame
# ['automation', 'software development', 'employment', 'business strategy']
# 50.33 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# 128.86 Welcome to the AI factory era: A preview of Dell Technologies World 2025
# ['NVIDIA', 'automation']
# ----------------------------------------------------------------------------------------------------
# 82.76 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# 49.86 AWS open-sources Strands Agents SDK to ease AI agent development
# ['software development', 'Cloud computing', 'open source software']
# 127.78 Microsoft Just Laid Off 6,000 Workers. And AI Might Be to Blame
# ['automation', 'software development', 'employment', 'business strategy']
# ----------------------------------------------------------------------------------------------------
# 79.89 HPE’s stock rises on AI momentum and more clarity on market conditions
# ['data science', 'server architecture', 'Cloud computing', 'acquisitions', 'search engines']
# 49.27 Microsoft debuts Windows AI Foundry for local model development on AI PCs
# ['Cloud computing', 'NVIDIA', 'semantic search']
# 126.68 HPE’s stock rises on AI momentum and more clarity on market conditions
# ['data science', 'server architecture', 'Cloud computing', 'acquisitions', 'search engines']
# ----------------------------------------------------------------------------------------------------
# 79.87 Nvidia says its Blackwell chips lead benchmarks in training AI LLMs
# ['NVIDIA', 'MLPerf', 'data science']
# 49.01 Microsoft Just Laid Off 6,000 Workers. And AI Might Be to Blame
# ['automation', 'software development', 'employment', 'business strategy']
# 122.15 Nvidia says its Blackwell chips lead benchmarks in training AI LLMs
# ['NVIDIA', 'MLPerf', 'data science']
# ----------------------------------------------------------------------------------------------------
# 79.74 Your 2025 Data and AI Summit Guide for Public Sector Industry Experience
# ['data science', 'reliability', 'public sector', 'data governance', 'data privacy', 'Databricks']
# 48.83 Amazon EC2 P6-B200 instances powered by NVIDIA B200 GPUs now generally available
# ['Cloud computing', 'NVIDIA']
# 121.88 Reducing Time to Value for Data Science Projects: Part 2
# ['data science', 'Experimentation', 'automation', 'Configuration management', 'Data pipelines', 'Logging', 'Artifact management']
# ----------------------------------------------------------------------------------------------------
# 79.24 AWS open-sources Strands Agents SDK to ease AI agent development
# ['software development', 'Cloud computing', 'open source software']
# 48.20 AI can't replace devs until it understands office politics
# ['software development', 'automation', 'semiconductors', 'Business process']
# 121.58 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# ----------------------------------------------------------------------------------------------------
# 78.15 AI can't replace devs until it understands office politics
# ['software development', 'automation', 'semiconductors', 'Business process']
# 48.04 Nvidia says its Blackwell chips lead benchmarks in training AI LLMs
# ['NVIDIA', 'MLPerf', 'data science']
# 118.63 AWS open-sources Strands Agents SDK to ease AI agent development
# ['software development', 'Cloud computing', 'open source software']
# ----------------------------------------------------------------------------------------------------
# 77.30 How open systems drive AI performance
# ['Cloud computing', 'open source software', 'search engines', 'NVIDIA']
# 47.97 AWS Open-Sources Strands Agents SDK to Simplify AI Agent Development
# ['software development', 'Cloud computing', 'model-driven engineering']
# 118.55 CrowdStrike earnings beat expectations but revenue outlook weighs on shares
# ['data privacy', 'data science', 'risk assessment', 'SIEM']
# ----------------------------------------------------------------------------------------------------
# 76.77 TechRepublic Premium Editorial Calendar: Policies, Hiring Kits, and Glossaries for Download
# ['software development', 'data privacy', 'employment', 'Checklists', 'Glossaries', 'PowerShell']
# 47.84 How open systems drive AI performance
# ['Cloud computing', 'open source software', 'search engines', 'NVIDIA']
# 117.65 How open systems drive AI performance
# ['Cloud computing', 'open source software', 'search engines', 'NVIDIA']
# ----------------------------------------------------------------------------------------------------
# 76.77 TechRepublic Premium Editorial Calendar: Policies, Hiring Kits, and Glossaries for Download
# ['software development', 'data privacy', 'employment', 'Checklists', 'Glossaries', 'PowerShell']
# 47.51 From prototype to production: How AWS and Snowflake are scaling gen AI
# ['software development', 'automation']
# 117.05 AI can't replace devs until it understands office politics
# ['software development', 'automation', 'semiconductors', 'Business process']
# ----------------------------------------------------------------------------------------------------
# 76.50 From prototype to production: How AWS and Snowflake are scaling gen AI
# ['software development', 'automation']
# 47.02 HPE’s stock rises on AI momentum and more clarity on market conditions
# ['data science', 'server architecture', 'Cloud computing', 'acquisitions', 'search engines']
# 116.42 TechRepublic Premium Editorial Calendar: Policies, Hiring Kits, and Glossaries for Download
# ['software development', 'data privacy', 'employment', 'Checklists', 'Glossaries', 'PowerShell']
# ----------------------------------------------------------------------------------------------------
# 75.41 Reducing Time to Value for Data Science Projects: Part 2
# ['data science', 'Experimentation', 'automation', 'Configuration management', 'Data pipelines', 'Logging', 'Artifact management']
# 46.95 TechRepublic Premium Editorial Calendar: Policies, Hiring Kits, and Glossaries for Download
# ['software development', 'data privacy', 'employment', 'Checklists', 'Glossaries', 'PowerShell']
# 116.42 TechRepublic Premium Editorial Calendar: Policies, Hiring Kits, and Glossaries for Download
# ['software development', 'data privacy', 'employment', 'Checklists', 'Glossaries', 'PowerShell']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Look at sub-exponential selection using linear vs sub-exp vs sup-exp order

# %%
from ttd.flows.article_selection.steps.select_articles import compute_article_cluster_scores
from ttd.flows.article_selection.steps.select_articles import get_top_n_articles
from typing import Callable

linearly_scored_articles = compute_article_cluster_scores(
        articles, linear_cluster_scores, order_metric=exponential_order_metric(0.1)
)
top_n_linearly_scored_articles = get_top_n_articles(linearly_scored_articles, n=20)
sub_scored_articles = compute_article_cluster_scores(
        articles, sub_exponential_cluster_scores, order_metric=exponential_order_metric(0.1)
)
top_n_sub_scored_articles = get_top_n_articles(sub_scored_articles, n=20)
sup_scored_articles = compute_article_cluster_scores(
        articles, sup_exponential_cluster_scores, order_metric=exponential_order_metric(0.1)
)
top_n_sup_scored_articles = get_top_n_articles(sup_scored_articles, n=20)
for article, article_2, article_3 in zip(top_n_linearly_scored_articles, top_n_sub_scored_articles, top_n_sup_scored_articles):
        print(f"{article['clusters_score']:0.2f} {article['title']}")
        print(article['clusters_names_in_order_added'])
        print(f"{article_2['clusters_score']:0.2f} {article_2['title']}")
        print(article_2['clusters_names_in_order_added'])
        print(f"{article_3['clusters_score']:0.2f} {article_3['title']}")
        print(article_3['clusters_names_in_order_added'])
        print("-"*100)
# Out:
# 64.57 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 39.65 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 103.76 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# ----------------------------------------------------------------------------------------------------
# 64.53 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# 39.62 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# 103.76 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# ----------------------------------------------------------------------------------------------------
# 64.53 Welcome to the AI factory era: A preview of Dell Technologies World 2025
# ['NVIDIA', 'automation']
# 39.62 Welcome to the AI factory era: A preview of Dell Technologies World 2025
# ['NVIDIA', 'automation']
# 103.74 JFrog and Nvidia partner on secure software supply chain for Enterprise AI Factory
# ['data science', 'NVIDIA']
# ----------------------------------------------------------------------------------------------------
# 63.97 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 38.26 AI-generated CUDA kernels outperform PyTorch in several GPU-heavy machine learning benchmarks
# ['NVIDIA', 'search engines', 'PyTorch']
# 103.13 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# ----------------------------------------------------------------------------------------------------
# 63.97 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 38.26 Blackwell Breaks the 1,000 TPS/User Barrier With Meta’s Llama 4 Maverick
# ['NVIDIA', 'search engines']
# 97.62 Your 2025 Data and AI Summit Guide for Public Sector Industry Experience
# ['data science', 'reliability', 'public sector', 'data governance', 'data privacy', 'Databricks']
# ----------------------------------------------------------------------------------------------------
# 63.97 JFrog and Nvidia partner on secure software supply chain for Enterprise AI Factory
# ['data science', 'NVIDIA']
# 37.94 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# 97.02 AI-Powered Video Insights Are Coming to Google Drive — Here’s When You’ll Get Them
# ['data science', 'Android']
# ----------------------------------------------------------------------------------------------------
# 63.36 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# 37.62 Ready to Reason: Storage Leaders Build Infrastructure to Fuel AI Agents With NVIDIA AI Data Platform
# ['NVIDIA', 'retrieval-augmented generation']
# 96.54 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# ----------------------------------------------------------------------------------------------------
# 61.80 AI-generated CUDA kernels outperform PyTorch in several GPU-heavy machine learning benchmarks
# ['NVIDIA', 'search engines', 'PyTorch']
# 37.61 Nvidia and Microsoft accelerate AI processing on PCs
# ['NVIDIA', 'Microsoft', 'TensorRT']
# 96.50 How To Build a Benchmark for Your Models
# ['data science', 'benchmarking', 'Performance management', 'Baseline models']
# ----------------------------------------------------------------------------------------------------
# 61.78 Blackwell Breaks the 1,000 TPS/User Barrier With Meta’s Llama 4 Maverick
# ['NVIDIA', 'search engines']
# 37.61 Foxconn Taps NVIDIA to Accelerate Physical and Digital Robotics for Global Healthcare Industry
# ['NVIDIA', 'Microsoft']
# 96.49 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# ----------------------------------------------------------------------------------------------------
# 61.03 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# 37.32 NVIDIA Grace CPU C1 Gains Broad Support in Edge, Telco and Storage
# ['NVIDIA', 'energy efficiency']
# 96.49 Welcome to the AI factory era: A preview of Dell Technologies World 2025
# ['NVIDIA', 'automation']
# ----------------------------------------------------------------------------------------------------
# 60.63 Ready to Reason: Storage Leaders Build Infrastructure to Fuel AI Agents With NVIDIA AI Data Platform
# ['NVIDIA', 'retrieval-augmented generation']
# 37.19 NVIDIA CEO Envisions AI Infrastructure Industry Worth ‘Trillions of Dollars’
# ['NVIDIA', 'digital twins']
# 96.17 Evaluating LLMs for Inference, or Lessons from Teaching for Machine Learning
# ['data science', 'prompt engineering', 'ground truth', 'Performance management']
# ----------------------------------------------------------------------------------------------------
# 60.53 Nvidia and Microsoft accelerate AI processing on PCs
# ['NVIDIA', 'Microsoft', 'TensorRT']
# 37.10 Nvidia says its Blackwell chips lead benchmarks in training AI LLMs
# ['NVIDIA', 'MLPerf', 'data science']
# 96.01 HPE’s stock rises on AI momentum and more clarity on market conditions
# ['data science', 'server architecture', 'Cloud computing', 'acquisitions', 'search engines']
# ----------------------------------------------------------------------------------------------------
# 60.53 Foxconn Taps NVIDIA to Accelerate Physical and Digital Robotics for Global Healthcare Industry
# ['NVIDIA', 'Microsoft']
# 37.09 Scaling to Millions of Tokens with Efficient Long-Context LLM Training
# ['NVIDIA', 'context learning', 'activation recomputation', 'memory management']
# 95.97 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# ----------------------------------------------------------------------------------------------------
# 60.40 NVIDIA Grace CPU C1 Gains Broad Support in Edge, Telco and Storage
# ['NVIDIA', 'energy efficiency']
# 36.94 RAPIDS Brings Zero-Code-Change Acceleration, IO Performance Gains, and Out-of-Core XGBoost
# ['NVIDIA', 'central processing units', 'machine learning', 'XGBoost']
# 95.71 Reducing Time to Value for Data Science Projects: Part 2
# ['data science', 'Experimentation', 'automation', 'Configuration management', 'Data pipelines', 'Logging', 'Artifact management']
# ----------------------------------------------------------------------------------------------------
# 60.14 Nvidia says its Blackwell chips lead benchmarks in training AI LLMs
# ['NVIDIA', 'MLPerf', 'data science']
# 36.89 How Dell Technologies Is Building the Engines of AI Factories With NVIDIA Blackwell
# ['NVIDIA', 'server architecture']
# 95.67 May Must-Reads: Math for Machine Learning Engineers, LLMs, Agent Protocols, and More
# ['data science', 'PyTorch', 'reinforcement learning']
# ----------------------------------------------------------------------------------------------------
# 59.97 NVIDIA CEO Envisions AI Infrastructure Industry Worth ‘Trillions of Dollars’
# ['NVIDIA', 'digital twins']
# 36.88 RAPIDS Brings Zero-Code-Change Acceleration, IO Performance Gains, and Out-of-Core XGBoost
# ['NVIDIA', 'central processing units', 'XGBoost']
# 95.56 AI pioneer Yoshua Bengio launches nonprofit LawZero AI lab, with a focus on safe AI
# ['data science', 'non-profit organizations', 'Yoshua Bengio']
# ----------------------------------------------------------------------------------------------------
# 59.93 Scaling to Millions of Tokens with Efficient Long-Context LLM Training
# ['NVIDIA', 'context learning', 'activation recomputation', 'memory management']
# 36.87 Oracle's $40B Nvidia hardware haul may be too hot for OpenAI's Abilene, Texas DC to handle
# ['NVIDIA', 'Oracle', 'OpenAI']
# 95.52 Google Researchers Introduce LightLab: A Diffusion-Based AI Method for Physically Plausible, Fine-Grained Light Control in Single Images
# ['data science', 'Diffusion models', 'artificial lighting', 'computer vision', 'synthetic data']
# ----------------------------------------------------------------------------------------------------
# 59.87 AI-Powered Video Insights Are Coming to Google Drive — Here’s When You’ll Get Them
# ['data science', 'Android']
# 36.86 NVIDIA Dynamo Adds GPU Autoscaling, Kubernetes Automation, and Networking Optimizations
# ['NVIDIA', 'kubernetes', 'search engines']
# 95.51 Deep learning-driven automated mitochondrial segmentation for analysis of complex transmission electron microscopy images
# ['data science', 'Image segmentation', 'cryo-electron microscopy', 'Mitochondrial morphology', 'Duchenne muscular dystrophy']
# ----------------------------------------------------------------------------------------------------
# 59.76 Your 2025 Data and AI Summit Guide for Public Sector Industry Experience
# ['data science', 'reliability', 'public sector', 'data governance', 'data privacy', 'Databricks']
# 36.83 5 impressive feats of DeepMind’s new self-evolving AI coding agent
# ['NVIDIA', 'Linear algebra', 'search engines']
# 95.51 Deep learning-driven automated mitochondrial segmentation for analysis of complex transmission electron microscopy images
# ['data science', 'Image segmentation', 'cryo-electron microscopy', 'Mitochondrial morphology', 'Duchenne muscular dystrophy']
# ----------------------------------------------------------------------------------------------------
# 59.76 NVIDIA Dynamo Adds GPU Autoscaling, Kubernetes Automation, and Networking Optimizations
# ['NVIDIA', 'kubernetes', 'search engines']
# 36.75 NVIDIA Dynamo Adds GPU Autoscaling, Kubernetes Automation, and Networking Optimizations
# ['NVIDIA', 'kubernetes', 'cloud computing', 'inference', 'supercomputers']
# 95.39 Anthropic Future-Proofs New AI Model With Rigorous Safety Rules
# ['data science', 'transparency']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Look at sup-exponential selection using linear vs sub-exp vs sup-exp order

# %%
from ttd.flows.article_selection.steps.select_articles import compute_article_cluster_scores
from ttd.flows.article_selection.steps.select_articles import get_top_n_articles
from typing import Callable

linearly_scored_articles = compute_article_cluster_scores(
        articles, linear_cluster_scores, order_metric=exponential_order_metric(0.9)
)
top_n_linearly_scored_articles = get_top_n_articles(linearly_scored_articles, n=20)
sub_scored_articles = compute_article_cluster_scores(
        articles, sub_exponential_cluster_scores, order_metric=exponential_order_metric(0.9)
)
top_n_sub_scored_articles = get_top_n_articles(sub_scored_articles, n=20)
sup_scored_articles = compute_article_cluster_scores(
        articles, sup_exponential_cluster_scores, order_metric=exponential_order_metric(0.9)
)
top_n_sup_scored_articles = get_top_n_articles(sup_scored_articles, n=20)
for article, article_2, article_3 in zip(top_n_linearly_scored_articles, top_n_sub_scored_articles, top_n_sup_scored_articles):
        print(f"{article['clusters_score']:0.2f} {article['title']}")
        print(article['clusters_names_in_order_added'])
        print(f"{article_2['clusters_score']:0.2f} {article_2['title']}")
        print(article_2['clusters_names_in_order_added'])
        print(f"{article_3['clusters_score']:0.2f} {article_3['title']}")
        print(article_3['clusters_names_in_order_added'])
        print("-"*100)
# Out:
# 138.38 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# 81.27 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# 215.83 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# ----------------------------------------------------------------------------------------------------
# 125.46 How open systems drive AI performance
# ['Cloud computing', 'open source software', 'search engines', 'NVIDIA']
# 75.30 How open systems drive AI performance
# ['Cloud computing', 'open source software', 'search engines', 'NVIDIA']
# 193.55 How open systems drive AI performance
# ['Cloud computing', 'open source software', 'search engines', 'NVIDIA']
# ----------------------------------------------------------------------------------------------------
# 115.16 Your 2025 Data and AI Summit Guide for Public Sector Industry Experience
# ['data science', 'reliability', 'public sector', 'data governance', 'data privacy', 'Databricks']
# 72.48 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# 188.93 Your 2025 Data and AI Summit Guide for Public Sector Industry Experience
# ['data science', 'reliability', 'public sector', 'data governance', 'data privacy', 'Databricks']
# ----------------------------------------------------------------------------------------------------
# 114.43 HPE’s stock rises on AI momentum and more clarity on market conditions
# ['data science', 'server architecture', 'Cloud computing', 'acquisitions', 'search engines']
# 69.84 HPE’s stock rises on AI momentum and more clarity on market conditions
# ['data science', 'server architecture', 'Cloud computing', 'acquisitions', 'search engines']
# 181.39 Digital lab for data- and robot-driven materials science
# ['Materials science', 'automation', 'data science', 'Thin films', 'open source software']
# ----------------------------------------------------------------------------------------------------
# 114.07 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# 67.32 Run LLMs on AnythingLLM Faster With NVIDIA RTX AI PCs
# ['retrieval-augmented generation', 'NVIDIA', 'Cloud computing']
# 179.05 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# ----------------------------------------------------------------------------------------------------
# 112.79 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# 66.56 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# 178.39 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# ----------------------------------------------------------------------------------------------------
# 112.78 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 66.49 Microsoft Just Laid Off 6,000 Workers. And AI Might Be to Blame
# ['automation', 'software development', 'employment', 'business strategy']
# 178.39 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# ----------------------------------------------------------------------------------------------------
# 112.78 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 65.72 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 177.37 HPE’s stock rises on AI momentum and more clarity on market conditions
# ['data science', 'server architecture', 'Cloud computing', 'acquisitions', 'search engines']
# ----------------------------------------------------------------------------------------------------
# 112.57 Microsoft Just Laid Off 6,000 Workers. And AI Might Be to Blame
# ['automation', 'software development', 'employment', 'business strategy']
# 65.48 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 174.45 JFrog and Nvidia partner on secure software supply chain for Enterprise AI Factory
# ['data science', 'NVIDIA']
# ----------------------------------------------------------------------------------------------------
# 111.42 JFrog and Nvidia partner on secure software supply chain for Enterprise AI Factory
# ['data science', 'NVIDIA']
# 65.48 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 172.14 Microsoft Just Laid Off 6,000 Workers. And AI Might Be to Blame
# ['automation', 'software development', 'employment', 'business strategy']
# ----------------------------------------------------------------------------------------------------
# 110.26 Digital lab for data- and robot-driven materials science
# ['Materials science', 'automation', 'data science', 'Thin films', 'open source software']
# 65.46 JFrog and Nvidia partner on secure software supply chain for Enterprise AI Factory
# ['data science', 'NVIDIA']
# 169.09 Nvidia says its Blackwell chips lead benchmarks in training AI LLMs
# ['NVIDIA', 'MLPerf', 'data science']
# ----------------------------------------------------------------------------------------------------
# 109.37 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 64.77 AWS open-sources Strands Agents SDK to ease AI agent development
# ['software development', 'Cloud computing', 'open source software']
# 168.41 An anomaly detection framework anyone can use
# ['Anomaly detection', 'data science', 'open source software', 'Cloud computing']
# ----------------------------------------------------------------------------------------------------
# 108.50 Nvidia says its Blackwell chips lead benchmarks in training AI LLMs
# ['NVIDIA', 'MLPerf', 'data science']
# 64.56 Microsoft debuts Windows AI Foundry for local model development on AI PCs
# ['Cloud computing', 'NVIDIA', 'semantic search']
# 165.51 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# ----------------------------------------------------------------------------------------------------
# 106.90 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# 63.97 Nvidia says its Blackwell chips lead benchmarks in training AI LLMs
# ['NVIDIA', 'MLPerf', 'data science']
# 164.96 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# ----------------------------------------------------------------------------------------------------
# 106.50 AWS open-sources Strands Agents SDK to ease AI agent development
# ['software development', 'Cloud computing', 'open source software']
# 63.50 Spotlight: Build Scalable and Observable AI Ready for Production with Iguazio’s MLRun and NVIDIA NIM
# ['MLOps', 'NVIDIA', 'data science']
# 163.52 CrowdStrike earnings beat expectations but revenue outlook weighs on shares
# ['data privacy', 'data science', 'risk assessment', 'SIEM']
# ----------------------------------------------------------------------------------------------------
# 106.24 Welcome to the AI factory era: A preview of Dell Technologies World 2025
# ['NVIDIA', 'automation']
# 63.50 Spotlight: Build Scalable and Observable AI Ready for Production with Iguazio’s MLRun and NVIDIA NIM
# ['MLOps', 'NVIDIA', 'data science']
# 163.08 AWS open-sources Strands Agents SDK to ease AI agent development
# ['software development', 'Cloud computing', 'open source software']
# ----------------------------------------------------------------------------------------------------
# 105.73 Spotlight: Build Scalable and Observable AI Ready for Production with Iguazio’s MLRun and NVIDIA NIM
# ['MLOps', 'NVIDIA', 'data science']
# 63.49 Amazon EC2 P6-B200 instances powered by NVIDIA B200 GPUs now generally available
# ['Cloud computing', 'NVIDIA']
# 163.03 Spotlight: Build Scalable and Observable AI Ready for Production with Iguazio’s MLRun and NVIDIA NIM
# ['MLOps', 'NVIDIA', 'data science']
# ----------------------------------------------------------------------------------------------------
# 105.73 Spotlight: Build Scalable and Observable AI Ready for Production with Iguazio’s MLRun and NVIDIA NIM
# ['MLOps', 'NVIDIA', 'data science']
# 63.29 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# 163.03 Spotlight: Build Scalable and Observable AI Ready for Production with Iguazio’s MLRun and NVIDIA NIM
# ['MLOps', 'NVIDIA', 'data science']
# ----------------------------------------------------------------------------------------------------
# 103.87 This AI paper from DeepSeek-AI Explores How DeepSeek-V3 Delivers High-Performance Language Modeling by Minimizing Hardware Overhead and Maximizing Computational Efficiency
# ['mixture of experts', 'NVIDIA', 'model compression', 'quantization', 'data science']
# 63.27 Welcome to the AI factory era: A preview of Dell Technologies World 2025
# ['NVIDIA', 'automation']
# 162.95 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# ----------------------------------------------------------------------------------------------------
# 103.65 An anomaly detection framework anyone can use
# ['Anomaly detection', 'data science', 'open source software', 'Cloud computing']
# 62.91 SWE-Bench Performance Reaches 50.8% Without Tool Use: A Case for Monolithic State-in-Context Agents
# ['software development', 'context learning', 'data science']
# 161.56 This AI paper from DeepSeek-AI Explores How DeepSeek-V3 Delivers High-Performance Language Modeling by Minimizing Hardware Overhead and Maximizing Computational Efficiency
# ['mixture of experts', 'NVIDIA', 'model compression', 'quantization', 'data science']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Look at selection with diversity using linear vs sub-exp vs sup-exp order

# %%
from ttd.flows.article_selection.steps.select_articles import select_top_articles_with_diversity

top_n_linearly_scored_articles_with_diversity = select_top_articles_with_diversity(
articles, articles,
order_metric=linear_order_metric, n=20
)
top_n_sub_scored_articles_with_diversity = select_top_articles_with_diversity(
articles, articles,
order_metric=exponential_order_metric(0.1), n=20
)
top_n_sup_scored_articles_with_diversity = select_top_articles_with_diversity(
articles, articles,
order_metric=exponential_order_metric(0.9), n=20
)
for article, article_2, article_3 in zip(top_n_linearly_scored_articles_with_diversity, top_n_sub_scored_articles_with_diversity, top_n_sup_scored_articles_with_diversity)     :
    print(f"{article['clusters_score']:0.2f} {article['title']}")
    print(article['clusters_names_in_order_added'])
    print(f"{article_2['clusters_score']:0.2f} {article_2['title']}")
    print(article_2['clusters_names_in_order_added'])
    print(f"{article_3['clusters_score']:0.2f} {article_3['title']}")
    print(article_3['clusters_names_in_order_added'])
    print("-"*100)
# Out:
# 88.77 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# 39.65 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 215.83 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# ----------------------------------------------------------------------------------------------------
# 86.67 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 35.83 AWS open-sources Strands Agents SDK to ease AI agent development
# ['software development', 'Cloud computing', 'open source software']
# 193.55 How open systems drive AI performance
# ['Cloud computing', 'open source software', 'search engines', 'NVIDIA']
# ----------------------------------------------------------------------------------------------------
# 83.45 Microsoft Just Laid Off 6,000 Workers. And AI Might Be to Blame
# ['automation', 'software development', 'employment', 'business strategy']
# 35.52 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# 172.14 Microsoft Just Laid Off 6,000 Workers. And AI Might Be to Blame
# ['automation', 'software development', 'employment', 'business strategy']
# ----------------------------------------------------------------------------------------------------
# 79.24 AWS open-sources Strands Agents SDK to ease AI agent development
# ['software development', 'Cloud computing', 'open source software']
# 33.46 7 AWS Services for Machine Learning Projects
# ['Cloud computing', 'automation']
# 164.96 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# ----------------------------------------------------------------------------------------------------
# 64.64 Ryan Ries, Chief AI & Data Scientist at Mission – Interview Series
# ['Cloud computing', 'data privacy']
# 31.85 The future of engineering belongs to those who build with AI, not without it
# ['automation', 'data privacy', 'MLOps']
# 157.40 TechRepublic Premium Editorial Calendar: Policies, Hiring Kits, and Glossaries for Download
# ['software development', 'data privacy', 'employment', 'Checklists', 'Glossaries', 'PowerShell']
# ----------------------------------------------------------------------------------------------------
# 46.02 Inside GitHub: How we hardened our SAML implementation
# ['data privacy', 'risk assessment', 'Exploit', 'SAML', 'DNS rebinding', 'NVIDIA', 'Kernel']
# 23.04 Shadow AI in the enterprise: Managing risk without slowing progress
# ['data privacy', 'cybersecurity', 'privileged access management']
# 121.90 Synology ActiveProtect: Closing the Cyber Resilience Gap in Indian Enterprises
# ['cybersecurity', 'reliability', 'data privacy', 'cloud computing', 'digital transformation']
# ----------------------------------------------------------------------------------------------------
# 42.12 India Surpasses US as Largest ChatGPT User Base, Report Finds
# ['OpenAI', 'digital transformation', 'Startups', 'ESG']
# 22.16 India Surpasses US as Largest ChatGPT User Base, Report Finds
# ['OpenAI', 'digital transformation', 'Startups', 'ESG']
# 110.69 Covasant Partners with Botminds to Deliver Scalable Agentic AI Solution
# ['venture capital', 'digital transformation', 'customer service', 'advertising', 'data privacy']
# ----------------------------------------------------------------------------------------------------
# 37.42 VerSe Innovation Denies Allegations of Fake Biz Deals with Builder.ai
# ['AI training', 'Startups', 'venture capital', 'data centers', 'cybersecurity', 'digital economy']
# 19.55 Meta to Let AI Create Ads by 2026: Report
# ['digital transformation', 'advertising']
# 107.18 Reddit Sues Anthropic For Allegedly Using Its Unauthorised Data
# ['reliability', 'data privacy', 'data centers', 'business', 'AI software']
# ----------------------------------------------------------------------------------------------------
# 36.34 DeepSeek R1-0528 arrives in powerful open source challenge to OpenAI o3 and Google Gemini 2.5 Pro
# ['open source software', 'search engines', 'reasoning', 'benchmarking']
# 19.08 Klarna CEO says company will use humans to offer VIP customer service
# ['AI training', 'customer service', 'business strategy', 'Fintech', 'Initial public offering']
# 106.57 Data + AI Summit 2025: Your guide to data and AI governance talks
# ['data governance', 'Unity Catalog', 'data privacy', 'data management']
# ----------------------------------------------------------------------------------------------------
# 36.22 New York Times, Amazon ink AI deal
# ['search engines', 'drug discovery', 'natural language processing', 'Licensing']
# 17.23 New York Times, Amazon ink AI deal
# ['search engines', 'drug discovery', 'natural language processing', 'Licensing']
# 103.39 Forget Otter.ai: ChatGPT just entered the meeting room
# ['OpenAI', 'ChatGPT', 'data privacy', 'copyright infringement']
# ----------------------------------------------------------------------------------------------------
# 32.24 How HCLTech is Dabbling with GenAI for Real ROI
# ['digital transformation', 'business', 'data management']
# 16.26 Google's popular AI tool gets its own Android app - how to use NotebookLM on your phone
# ['Android', 'Google', 'summarization']
# 101.70 EkStep’s Plus One Philosophy for Building AI for Bharat
# ['data quality', 'data privacy', 'digital transformation', 'Startups']
# ----------------------------------------------------------------------------------------------------
# 31.19 Cursor AI Introduces ‘BugBot’, ‘Memories’ Features in Big Update
# ['reliability', 'cloud computing', 'data engineering', 'quantum computing', 'computer vision', 'healthcare']
# 13.48 Collaborators: Healthcare Innovation to Impact
# ['healthcare', 'Microsoft', 'Renewable energy']
# 94.39 Survey: Almost 80% of IT Leaders Saw Negative Company Outcomes Due to AI
# ['Generative AI', 'data privacy', 'data management', 'AI governance']
# ----------------------------------------------------------------------------------------------------
# 27.67 Genpact Moves Beyond Automation to Build Agentic Enterprises
# ['data management', 'healthcare', 'education']
# 12.01 QwenLong-L1 solves long-context reasoning challenge that stumps current LLMs
# ['reinforcement learning', 'context learning', 'question answering', 'Alibaba']
# 94.26 How the Boomi Enterprise Platform powers agentic AI with agile data management
# ['data management', 'data privacy', 'Data orchestration']
# ----------------------------------------------------------------------------------------------------
# 24.38 How Apple Lost the AI Race Ahead of WWDC 2025
# ['Android', 'machine learning', 'automation']
# 11.99 MLOmics: Cancer Multi-Omics Database for Machine Learning
# ['drug discovery', 'genomics', 'Bioinformatics', 'data management']
# 92.60 Hugging Face says its new robotics model is so efficient it can run on a MacBook
# ['Robotics', 'open source software', 'machine learning', 'AI training', 'Hugging Face Hub']
# ----------------------------------------------------------------------------------------------------
# 23.77 The Hidden Environmental Costs of Processing Unstructured Data in AI Systems
# ['customer service', 'healthcare', 'education']
# 11.97 Quantum Machines launches Qualibrate open source framework to speed quantum computer calibration
# ['quantum computing', 'open source software']
# 92.24 CockroachDB’s distributed vector indexing tackles the looming AI data explosion enterprises aren’t ready for
# ['Distributed databases', 'vector databases', 'data privacy', 'search engines']
# ----------------------------------------------------------------------------------------------------
# 22.99 Collaborators: Healthcare Innovation to Impact
# ['healthcare', 'Microsoft', 'Renewable energy']
# 11.93 Ex-Meta exec: Copyright consent obligation = end of AI biz
# ['Copyright', 'data governance', 'United Kingdom']
# 92.11 Peers vote to defy government over copyright threat from AI
# ['copyright law', 'AI training', 'data privacy', 'Government legislation', 'AI ethics']
# ----------------------------------------------------------------------------------------------------
# 22.75 Four-legged robot plays badminton with humans
# ['reinforcement learning', 'Quadruped robots', 'computer vision', 'Robotics']
# 11.86 GitHub Universe 2025: Here’s what’s in store at this year’s developer wonderland
# ['GitHub Copilot', 'GitHub', 'GitHub Actions', 'availability report']
# 91.37 DeepSeek R1-0528 arrives in powerful open source challenge to OpenAI o3 and Google Gemini 2.5 Pro
# ['open source software', 'search engines', 'reasoning', 'benchmarking']
# ----------------------------------------------------------------------------------------------------
# 22.66 Ex-Meta exec: Copyright consent obligation = end of AI biz
# ['Copyright', 'data governance', 'United Kingdom']
# 10.60 AI Is Changing the Game for PMs and CSMs—But Not Ending It
# ['data management', 'customer success', 'employment', 'skills']
# 89.69 Will AI Affect Your Appraisal This Financial Year?
# ['human resources', 'digital transformation', 'data privacy', 'model evaluation']
# ----------------------------------------------------------------------------------------------------
# 22.22 How Much Does AI Really Threaten Entry-Level Jobs?
# ['employment', 'labor market', 'future of work', 'automation', 'skills gap']
# 10.56 Create an agentic RAG application for advanced knowledge discovery with LlamaIndex, and Mistral in Amazon Bedrock
# ['retrieval-augmented generation', 'Amazon Bedrock', 'LlamaIndex', 'knowledge graphs', 'vector databases']
# 89.68 Viral video of Chinese paraglider likely includes faked AI footage
# ['Paragliding', 'AI training', 'data privacy', 'Media integrity', 'Content verification', 'China']
# ----------------------------------------------------------------------------------------------------
# 21.57 Create an agentic RAG application for advanced knowledge discovery with LlamaIndex, and Mistral in Amazon Bedrock
# ['retrieval-augmented generation', 'Amazon Bedrock', 'LlamaIndex', 'knowledge graphs', 'vector databases']
# 10.53 Top Artificial Intelligence AI Books to Read in 2025
# ['reliability', 'machine learning', 'AI ethics', 'emerging technologies', 'AI safety']
# 87.70 Veo 3 Changes How Videos are Made and Consumed, says Andrej Karpathy
# ['digital transformation', 'data privacy']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Inspect result

# %%
flow.config.get("db_path")
# Out:
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/ttd_tinydb.json'

# %%
from ttd.storage.ttd_storage import TTDStorage

storage = TTDStorage(flow.config.get("db_path"))
storage.get_all('selected_articles')
# Out:
# [{'original_table_name': 'replicated_articles',
#   'original_doc_id': '810',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:46.846697',
#   'doc_id': '1'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '333',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:46.903167',
#   'doc_id': '2'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '473',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:46.939717',
#   'doc_id': '3'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '577',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:46.975671',
#   'doc_id': '4'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '590',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.019303',
#   'doc_id': '5'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '742',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.054636',
#   'doc_id': '6'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '747',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.091039',
#   'doc_id': '7'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '778',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.126440',
#   'doc_id': '8'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '781',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.162758',
#   'doc_id': '9'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '791',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.198395',
#   'doc_id': '10'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '800',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.240365',
#   'doc_id': '11'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '805',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.276108',
#   'doc_id': '12'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '897',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.312181',
#   'doc_id': '13'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '769',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.348202',
#   'doc_id': '14'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '68',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.383207',
#   'doc_id': '15'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '76',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.419698',
#   'doc_id': '16'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '326',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.463300',
#   'doc_id': '17'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '344',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.498982',
#   'doc_id': '18'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '347',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.534795',
#   'doc_id': '19'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '369',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-13T15:57:47.570892',
#   'doc_id': '20'}]
