# %% [markdown]
# # 🔍 Article Selection Analysis for Hex Machina Newsletter
#
# This notebook is an interactive replica of the article selection flow using [Metaflow](https://metaflow.org/).
#
# You can run the complete flow using the following command:
#
# ```bash
# python -m hex.flows.article_selection.flow
# ```
#
# To learn more about how Metaflow works, see the [official documentation](https://docs.metaflow.org/).
#
# It consists of five main steps :
#
# <img src="images/article_selection_flow.png" width="400">
#
#
# Use this notebook to **find, test, and evaluate** the flow with dummy data.
#
# > ⚠️ **Make sure to execute all steps in order** to obtain valid results.
# > 🔎 **Inspect the flow state at each step** to better understand the process.

# %%
from metaflow import FlowSpec, step, Parameter
from pydantic import BaseModel, Field
from datetime import datetime

from hex.utils.print import safe_pretty_print
from hex.utils.date import parse_date

class FlowParametersSchema(BaseModel):
    """Schema for flow parameters."""
    articles_table: str = Field(
        'articles', description="Table to load articles from"
    )
    articles_limit: int = Field(
        2, description="Maximum number of articles to select"
    )
    date_threshold: datetime = Field(
        'Thu, 03 Apr 2025 18:00:00 +0000',
        description="Select articles published after this date"
    )
    cluster_date_threshold: datetime = Field(
        'Thu, 03 Apr 2025 18:00:00 +0000',
        description="articles published after this date are used to compute clusters scores"
    )
    clean_tables: bool = Field(
        False, description="Clean tables (selected_articles_table)"
    )
    selected_articles_table: str = Field(
        'selected_articles_dummy_table',
        description='Table to register selected articles'
    )
    class Config:
        extra = 'allow'
    pass

flow = FlowParametersSchema(
    articles_table='replicated_articles',
    date_threshold=parse_date('Thu, 05 Jun 2025 12:00:00 +0000'),
    cluster_date_threshold=parse_date('Thu, 05 Jun 2025 12:00:00 +0000'),
    articles_limit=2,
    clean_tables=True
)
safe_pretty_print(flow.model_dump())
# Out:
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 2,
#     'date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'clean_tables': True,
#     'selected_articles_table': 'selected_articles_dummy_table'
# }

# %% [markdown]
# ### **1. Start step**
# Init, config, parameters, tracks versioning...

# %%
from hex.flows.article_selection.steps.start import execute as start_step

start_step(flow)
safe_pretty_print(flow.model_dump())
# Out:
# 2025-06-08 23:58:12,771 - hex.flows.article_selection.steps.start - INFO - ✅ Database first connection established.
# 2025-06-08 23:58:12,912 - hex.flows.article_selection.steps.start - INFO - ✅ Database cleaned.
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 2,
#     'date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'clean_tables': True,
#     'selected_articles_table': 'selected_articles_dummy_table',
#     'config': {
#         'data_dir': '/Users/mathieucrilout/Repos/train_tune_deploy/data',
#         'db_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/hex_tinydb.json',
#         'feeds_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds.txt',
#         'feeds_stealth_path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds_stealth.txt'
#     },
#     'git_metadata': {
#         'git_commit': 'e384e110803b739e45417119bca628380bf54480',
#         'git_branch': 'dev',
#         'git_repo': 'git@github.com:mcrilo33/train-tune-deploy.git'
#     },
#     'parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'parsed_cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'min_parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'metrics': {},
#     'errors': {}
# }

# %% [markdown]
# ### **2. Load articles step**

# %%
from hex.flows.article_selection.steps.load_articles \
    import execute as load_articles_step

load_articles_step(flow)
safe_pretty_print(flow.model_dump())
# Out:
# 2025-06-08 23:58:12,921 - hex.flows.article_selection.steps.load_articles - INFO - Loading articles...
# /Users/mathieucrilout/.miniconda3/envs/ttd/lib/python3.10/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# 2025-06-08 23:58:13,111 - hex.flows.article_selection.steps.load_articles - INFO - ✅ Loaded 5 articles from 'replicated_articles': len(articles)=5, date_threshold='2025-06-05 12:00:00+00:00'
# 2025-06-08 23:58:13,112 - hex.flows.article_selection.steps.load_articles - INFO - ✅ Filtering out already replicated articles...
# 2025-06-08 23:58:13,166 - hex.flows.article_selection.steps.load_articles - INFO - ✅ There are 0 already selected articles
# 2025-06-08 23:58:13,166 - hex.flows.article_selection.steps.load_articles - INFO - ✅ Filtered out 0 already selected articles from 'selected_articles_dummy_table'
# 2025-06-08 23:58:13,166 - hex.flows.article_selection.steps.load_articles - INFO - ✅ Loaded 5 articles...
# 2025-06-08 23:58:13,166 - hex.flows.article_selection.steps.load_articles - INFO - ✅ Step load_articles done in 0.25s
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 2,
#     'date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'clean_tables': True,
#     'selected_articles_table': 'selected_articles_dummy_table',
#     'config': {
#         'data_dir': '/Users/mathieucrilout/Repos/train_tune_deploy/data',
#         'db_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/hex_tinydb.json',
#         'feeds_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds.txt',
#         'feeds_stealth_path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds_stealth.txt'
#     },
#     'git_metadata': {
#         'git_commit': 'e384e110803b739e45417119bca628380bf54480',
#         'git_branch': 'dev',
#         'git_repo': 'git@github.com:mcrilo33/train-tune-deploy.git'
#     },
#     'parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'parsed_cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'min_parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'metrics': {
#         'step_start_times': {
#             'load_articles': 1749419892.921448
#         },
#         'step_duration': {
#             'load_articles': 0.2453758716583252
#         }
#     },
#     'errors': {},
#     'articles': [
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Top 5 Alternative Data Career Paths and How to Learn Them for Free',
#             'author': 'Nate Rosidi',
#             'published_date': 'Thu, 05 Jun 2025 12:00:02 +0000',
#             'url_domain': 'kdnuggets.com',
#             'url':
# 'https://www.kdnuggets.com/top-5-alternative-data-career-paths-and-how-to-learn-t...',
#             'summary': 'How about some alternative options for a data career? Learn about
# five non-stand...',
#             'tags': [],
#             'html_content_length': 201344,
#             'text_content_length': 10758,
#             'summary_length': 146,
#             'summary_text_ratio': 0.013571295779884737,
#             'metadata': {
#                 'error': None,
#                 'duration': 5
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:06.750408',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3622',
#             'is_ai_added': True,
#             'dense_summary_added': 'Alternative data career paths include Data Product
# Manager, Data Journalist, Ana...',
#             'dense_summary_length_added': 1763,
#             'core_line_summary_added': 'The field of data offers diverse career paths
# beyond traditional data science, i...',
#             'core_line_summary_length_added': 238,
#             'tags_pred_added': [
#                 'Data analysis',
#                 'Data product management',
#                 'Analytics engineering',
#                 'Data journalism',
#                 'Data ethics'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'data analysis',
#                 'data management',
#                 'cloud computing',
#                 'Data journalism',
#                 'data ethics'
#             ],
#             'title_vs_core_rouge_eval': 0.049792531120331954,
#             'tag_similarity_eval': 0.0,
#             'doc_id': '3644'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'OnePlus Looks to Undercut Apple and Samsung With New $700 Tablet',
#             'author': 'Chris Welch',
#             'published_date': 'Thu, 05 Jun 2025 12:00:38 GMT',
#             'url_domain': 'bloomberg.com',
#             'url':
# 'https://www.bloomberg.com/news/articles/2025-06-05/oneplus-announces-700-oneplus...',
#             'summary': 'Three generations into its Pad lineup, OnePlus is still trying to
# stand out in a...',
#             'tags': [
#                 'NMS:AAPL'
#             ],
#             'html_content_length': 14073,
#             'text_content_length': 464,
#             'summary_length': 115,
#             'summary_text_ratio': 0.2478448275862069,
#             'metadata': {
#                 'error': None,
#                 'duration': 3
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:10.324951',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3625',
#             'is_ai_added': False,
#             'doc_id': '3647'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'How to handle the tech challenges of moving overseas',
#             'author': 'Tom Hawking',
#             'published_date': '2025-06-05T08:00:00-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/tech/676306/moving-tech-overseas-how-to-tips',
#             'summary': 'Moving is stressful at the best of times, and while moving to a
# new country is e...',
#             'tags': [
#                 'Gadgets',
#                 'How to',
#                 'Tech'
#             ],
#             'html_content_length': 494295,
#             'text_content_length': 10290,
#             'summary_length': 320,
#             'summary_text_ratio': 0.031098153547133137,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:17.795847',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3631',
#             'is_ai_added': False,
#             'doc_id': '3653'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'The cursed world of AI kiss and hug apps',
#             'author': 'Victoria Song',
#             'published_date': '2025-06-05T08:00:00-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/ai-artificial-intelligence/679295/ai-hug-kiss-video-app...',
#             'summary': "Doomscroll on TikTok long enough, and you'll come across an ad for
# AI video apps...",
#             'tags': [
#                 'AI',
#                 'Analysis',
#                 'Hands-on',
#                 'Reviews',
#                 'Tech'
#             ],
#             'html_content_length': 472554,
#             'text_content_length': 14796,
#             'summary_length': 314,
#             'summary_text_ratio': 0.021221951878886185,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:20.556450',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3632',
#             'is_ai_added': True,
#             'dense_summary_added': 'AI video apps offer benign and disturbing video
# templates, including kissing, hu...',
#             'dense_summary_length_added': 1324,
#             'core_line_summary_added': 'AI video apps offering deepfake templates,
# including sexualized content, raise e...',
#             'core_line_summary_length_added': 207,
#             'tags_pred_added': [
#                 'Generative AI',
#                 'deepfakes',
#                 'AI ethics',
#                 'mobile applications',
#                 'content moderation'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'Generative AI',
#                 'deepfakes',
#                 'AI ethics',
#                 'software development',
#                 'content moderation'
#             ],
#             'title_vs_core_rouge_eval': 0.028436018957345967,
#             'tag_similarity_eval': 0.38524137017476817,
#             'doc_id': '3654'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Forget Otter.ai: ChatGPT just entered the meeting room',
#             'author': '',
#             'published_date': 'Thu, 05 Jun 2025 12:05:00 GMT',
#             'url_domain': 'zdnet.com',
#             'url':
# 'https://www.zdnet.com/article/forget-otter-ai-chatgpt-just-entered-the-meeting-r...',
#             'summary': 'ChatGPT just got two major upgrades that could make your work life
# easier.',
#             'tags': [],
#             'html_content_length': 581226,
#             'text_content_length': 6965,
#             'summary_length': 74,
#             'summary_text_ratio': 0.010624551328068915,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:19:07.924772',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3650',
#             'is_ai_added': True,
#             'dense_summary_added': 'OpenAI has introduced Connectors and Record Mode to
# ChatGPT, enhancing its utili...',
#             'dense_summary_length_added': 1247,
#             'core_line_summary_added': "OpenAI's new Connectors and Record Mode enhance
# ChatGPT's professional utility b...",
#             'core_line_summary_length_added': 232,
#             'tags_pred_added': [
#                 'Large language models',
#                 'OpenAI',
#                 'ChatGPT',
#                 'Data privacy',
#                 'Copyright infringement'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'large language models',
#                 'OpenAI',
#                 'ChatGPT',
#                 'data privacy',
#                 'copyright infringement'
#             ],
#             'title_vs_core_rouge_eval': 0.020618556701030927,
#             'tag_similarity_eval': 0.0,
#             'doc_id': '3672'
#         }
#     ]
# }

# %% [markdown]
# ### **3. Article Selection step**
#
# Propose multiple selection based on various unsupervised strategies.

# %%
from hex.flows.article_selection.steps.select_articles \
    import execute as select_articles_step

select_articles_step(flow)
safe_pretty_print(flow.model_dump())
# Out:
# 2025-06-08 23:58:13,408 - numexpr.utils - INFO - NumExpr defaulting to 10 threads.
# 2025-06-08 23:58:14,144 - hex.flows.article_selection.steps.select_articles - INFO - Selecting articles...
# 2025-06-08 23:58:14,145 - hex.flows.article_selection.steps.select_articles - INFO - ✅ Scoring clusters...
# 2025-06-08 23:58:14,742 - hex.flows.article_selection.steps.select_articles - INFO - ✅ Step select_articles done in 0.60s
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 2,
#     'date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0, tzinfo=tzutc()),
#     'clean_tables': True,
#     'selected_articles_table': 'selected_articles_dummy_table',
#     'config': {
#         'data_dir': '/Users/mathieucrilout/Repos/train_tune_deploy/data',
#         'db_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/hex_tinydb.json',
#         'feeds_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds.txt',
#         'feeds_stealth_path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds_stealth.txt'
#     },
#     'git_metadata': {
#         'git_commit': 'e384e110803b739e45417119bca628380bf54480',
#         'git_branch': 'dev',
#         'git_repo': 'git@github.com:mcrilo33/train-tune-deploy.git'
#     },
#     'parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'parsed_cluster_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'min_parsed_date_threshold': datetime.datetime(2025, 6, 5, 12, 0,
# tzinfo=datetime.timezone.utc),
#     'metrics': {
#         'step_start_times': {
#             'load_articles': 1749419892.921448,
#             'select_articles': 1749419894.1450372
#         },
#         'step_duration': {
#             'load_articles': 0.2453758716583252,
#             'select_articles': 0.5969898700714111
#         }
#     },
#     'errors': {},
#     'articles': [
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Top 5 Alternative Data Career Paths and How to Learn Them for Free',
#             'author': 'Nate Rosidi',
#             'published_date': 'Thu, 05 Jun 2025 12:00:02 +0000',
#             'url_domain': 'kdnuggets.com',
#             'url':
# 'https://www.kdnuggets.com/top-5-alternative-data-career-paths-and-how-to-learn-t...',
#             'summary': 'How about some alternative options for a data career? Learn about
# five non-stand...',
#             'tags': [],
#             'html_content_length': 201344,
#             'text_content_length': 10758,
#             'summary_length': 146,
#             'summary_text_ratio': 0.013571295779884737,
#             'metadata': {
#                 'error': None,
#                 'duration': 5
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:06.750408',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3622',
#             'is_ai_added': True,
#             'dense_summary_added': 'Alternative data career paths include Data Product
# Manager, Data Journalist, Ana...',
#             'dense_summary_length_added': 1763,
#             'core_line_summary_added': 'The field of data offers diverse career paths
# beyond traditional data science, i...',
#             'core_line_summary_length_added': 238,
#             'tags_pred_added': [
#                 'Data analysis',
#                 'Data product management',
#                 'Analytics engineering',
#                 'Data journalism',
#                 'Data ethics'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'data analysis',
#                 'data management',
#                 'cloud computing',
#                 'Data journalism',
#                 'data ethics'
#             ],
#             'title_vs_core_rouge_eval': 0.049792531120331954,
#             'tag_similarity_eval': 0.0,
#             'doc_id': '3644'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'OnePlus Looks to Undercut Apple and Samsung With New $700 Tablet',
#             'author': 'Chris Welch',
#             'published_date': 'Thu, 05 Jun 2025 12:00:38 GMT',
#             'url_domain': 'bloomberg.com',
#             'url':
# 'https://www.bloomberg.com/news/articles/2025-06-05/oneplus-announces-700-oneplus...',
#             'summary': 'Three generations into its Pad lineup, OnePlus is still trying to
# stand out in a...',
#             'tags': [
#                 'NMS:AAPL'
#             ],
#             'html_content_length': 14073,
#             'text_content_length': 464,
#             'summary_length': 115,
#             'summary_text_ratio': 0.2478448275862069,
#             'metadata': {
#                 'error': None,
#                 'duration': 3
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:10.324951',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3625',
#             'is_ai_added': False,
#             'doc_id': '3647'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'How to handle the tech challenges of moving overseas',
#             'author': 'Tom Hawking',
#             'published_date': '2025-06-05T08:00:00-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/tech/676306/moving-tech-overseas-how-to-tips',
#             'summary': 'Moving is stressful at the best of times, and while moving to a
# new country is e...',
#             'tags': [
#                 'Gadgets',
#                 'How to',
#                 'Tech'
#             ],
#             'html_content_length': 494295,
#             'text_content_length': 10290,
#             'summary_length': 320,
#             'summary_text_ratio': 0.031098153547133137,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:17.795847',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3631',
#             'is_ai_added': False,
#             'doc_id': '3653'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'The cursed world of AI kiss and hug apps',
#             'author': 'Victoria Song',
#             'published_date': '2025-06-05T08:00:00-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/ai-artificial-intelligence/679295/ai-hug-kiss-video-app...',
#             'summary': "Doomscroll on TikTok long enough, and you'll come across an ad for
# AI video apps...",
#             'tags': [
#                 'AI',
#                 'Analysis',
#                 'Hands-on',
#                 'Reviews',
#                 'Tech'
#             ],
#             'html_content_length': 472554,
#             'text_content_length': 14796,
#             'summary_length': 314,
#             'summary_text_ratio': 0.021221951878886185,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:18:20.556450',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3632',
#             'is_ai_added': True,
#             'dense_summary_added': 'AI video apps offer benign and disturbing video
# templates, including kissing, hu...',
#             'dense_summary_length_added': 1324,
#             'core_line_summary_added': 'AI video apps offering deepfake templates,
# including sexualized content, raise e...',
#             'core_line_summary_length_added': 207,
#             'tags_pred_added': [
#                 'Generative AI',
#                 'deepfakes',
#                 'AI ethics',
#                 'mobile applications',
#                 'content moderation'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'Generative AI',
#                 'deepfakes',
#                 'AI ethics',
#                 'software development',
#                 'content moderation'
#             ],
#             'title_vs_core_rouge_eval': 0.028436018957345967,
#             'tag_similarity_eval': 0.38524137017476817,
#             'doc_id': '3654'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Forget Otter.ai: ChatGPT just entered the meeting room',
#             'author': '',
#             'published_date': 'Thu, 05 Jun 2025 12:05:00 GMT',
#             'url_domain': 'zdnet.com',
#             'url':
# 'https://www.zdnet.com/article/forget-otter-ai-chatgpt-just-entered-the-meeting-r...',
#             'summary': 'ChatGPT just got two major upgrades that could make your work life
# easier.',
#             'tags': [],
#             'html_content_length': 581226,
#             'text_content_length': 6965,
#             'summary_length': 74,
#             'summary_text_ratio': 0.010624551328068915,
#             'metadata': {
#                 'error': None,
#                 'duration': 0
#             },
#             'original_table_name': 'articles',
#             'created_at': '2025-06-05T12:19:07.924772',
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '3650',
#             'is_ai_added': True,
#             'dense_summary_added': 'OpenAI has introduced Connectors and Record Mode to
# ChatGPT, enhancing its utili...',
#             'dense_summary_length_added': 1247,
#             'core_line_summary_added': "OpenAI's new Connectors and Record Mode enhance
# ChatGPT's professional utility b...",
#             'core_line_summary_length_added': 232,
#             'tags_pred_added': [
#                 'Large language models',
#                 'OpenAI',
#                 'ChatGPT',
#                 'Data privacy',
#                 'Copyright infringement'
#             ],
#             'tags_pred_length_added': 5,
#             'clusters_names_in_order_added': [
#                 'OpenAI',
#                 'ChatGPT',
#                 'data privacy',
#                 'copyright infringement'
#             ],
#             'title_vs_core_rouge_eval': 0.020618556701030927,
#             'tag_similarity_eval': 0.0,
#             'doc_id': '3672'
#         }
#     ],
#     'selection': {
#         'selection_time': '2025-06-08 21:58:14.146214+00:00',
#         'clusters_scores': {
#             'data analysis': 0,
#             'Generative AI': 0
#         },
#         'linearly_selected_articles_with_diversity': [
#             {
#                 'table_name': 'replicated_articles',
#                 'title': 'Top 5 Alternative Data Career Paths and How to Learn Them for
# Free',
#                 'author': 'Nate Rosidi',
#                 'published_date': 'Thu, 05 Jun 2025 12:00:02 +0000',
#                 'url_domain': 'kdnuggets.com',
#                 'url':
# 'https://www.kdnuggets.com/top-5-alternative-data-career-paths-and-how-to-learn-t...',
#                 'summary': 'How about some alternative options for a data career? Learn
# about five non-stand...',
#                 'tags': [],
#                 'html_content_length': 201344,
#                 'text_content_length': 10758,
#                 'summary_length': 146,
#                 'summary_text_ratio': 0.013571295779884737,
#                 'metadata': {
#                     'error': None,
#                     'duration': 5
#                 },
#                 'original_table_name': 'articles',
#                 'created_at': '2025-06-05T12:18:06.750408',
#                 'html_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'text_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'original_doc_id': '3622',
#                 'is_ai_added': True,
#                 'dense_summary_added': 'Alternative data career paths include Data Product
# Manager, Data Journalist, Ana...',
#                 'dense_summary_length_added': 1763,
#                 'core_line_summary_added': 'The field of data offers diverse career paths
# beyond traditional data science, i...',
#                 'core_line_summary_length_added': 238,
#                 'tags_pred_added': [
#                     'Data analysis',
#                     'Data product management',
#                     'Analytics engineering',
#                     'Data journalism',
#                     'Data ethics'
#                 ],
#                 'tags_pred_length_added': 5,
#                 'clusters_names_in_order_added': [
#                     'data analysis',
#                     'data management',
#                     'cloud computing',
#                     'Data journalism',
#                     'data ethics'
#                 ],
#                 'title_vs_core_rouge_eval': 0.049792531120331954,
#                 'tag_similarity_eval': 0.0,
#                 'doc_id': '3644',
#                 'clusters_score': 0
#             },
#             {
#                 'table_name': 'replicated_articles',
#                 'title': 'The cursed world of AI kiss and hug apps',
#                 'author': 'Victoria Song',
#                 'published_date': '2025-06-05T08:00:00-04:00',
#                 'url_domain': 'theverge.com',
#                 'url':
# 'https://www.theverge.com/ai-artificial-intelligence/679295/ai-hug-kiss-video-app...',
#                 'summary': "Doomscroll on TikTok long enough, and you'll come across an ad
# for AI video apps...",
#                 'tags': [
#                     'AI',
#                     'Analysis',
#                     'Hands-on',
#                     'Reviews',
#                     'Tech'
#                 ],
#                 'html_content_length': 472554,
#                 'text_content_length': 14796,
#                 'summary_length': 314,
#                 'summary_text_ratio': 0.021221951878886185,
#                 'metadata': {
#                     'error': None,
#                     'duration': 0
#                 },
#                 'original_table_name': 'articles',
#                 'created_at': '2025-06-05T12:18:20.556450',
#                 'html_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'text_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'original_doc_id': '3632',
#                 'is_ai_added': True,
#                 'dense_summary_added': 'AI video apps offer benign and disturbing video
# templates, including kissing, hu...',
#                 'dense_summary_length_added': 1324,
#                 'core_line_summary_added': 'AI video apps offering deepfake templates,
# including sexualized content, raise e...',
#                 'core_line_summary_length_added': 207,
#                 'tags_pred_added': [
#                     'Generative AI',
#                     'deepfakes',
#                     'AI ethics',
#                     'mobile applications',
#                     'content moderation'
#                 ],
#                 'tags_pred_length_added': 5,
#                 'clusters_names_in_order_added': [
#                     'Generative AI',
#                     'deepfakes',
#                     'AI ethics',
#                     'software development',
#                     'content moderation'
#                 ],
#                 'title_vs_core_rouge_eval': 0.028436018957345967,
#                 'tag_similarity_eval': 0.38524137017476817,
#                 'doc_id': '3654',
#                 'clusters_score': 0
#             }
#         ],
#         'ingestion_summary': 'For this digest it ingested more than 3 articles from 3
# sources (saving you 1 ho...',
#         'table_name': 'selections',
#         'created_at': '2025-06-08T21:58:14.496691',
#         'doc_id': '21'
#     }
# }

# %% [markdown]
# ### **4. Prepare Report**
#
# Generate a detailed report from the selected articles.
#
# Once the flow has been executed, you can retrieve the report using the following command :
#
# ```bash # python -m ttd.flows.article_selection.flow card get prepare_report article_enrichment_report_example.html```
#
# Here is an example output :
#
# <img src="images/article_selection_report_example.png" width="800">

# %% [markdown]
# ## Quick Analysis

# %%
db_path = flow.config.get("db_path")

# %%
from hex.flows.analysis import get_articles_with_no_error, get_oldest_and_latest_dates
from hex.storage.hex_storage import HexStorage

# Get articles from first inge:stion
storage = HexStorage(db_path)
articles = storage.get_obj_in_range("replicated_articles", first_id=2000)
articles_with_no_error = get_articles_with_no_error(articles)
oldest_date, latest_date = get_oldest_and_latest_dates(articles_with_no_error)
if oldest_date and latest_date:
    print(f"Oldest date: {oldest_date}")
    print(f"Latest date: {latest_date}")
# Out:
# Oldest date: Tue, 13 May 2025 13:31:57 +0000
# Latest date: Thu, 05 Jun 2025 12:05:00 +0000

# %%
from hex.flows.analysis import filter_articles_by_clusters
articles = filter_articles_by_clusters(articles_with_no_error, ["artificial intelligence", "large language models", "India"])

# %% [markdown]
# ### Look at linear vs sub exponential vs sup exponential orders

# %%
from hex.flows.article_selection.steps.select_articles import compute_cluster_scores
from hex.flows.article_selection.steps.select_articles import linear_order_metric
from hex.flows.article_selection.steps.select_articles import exponential_order_metric
linear_cluster_scores = compute_cluster_scores(
    articles,
    order_metric=linear_order_metric
)
sub_exponential_cluster_scores = compute_cluster_scores(
    articles,
    order_metric=exponential_order_metric(0.1)
)
sup_exponential_cluster_scores = compute_cluster_scores(
    articles,
    order_metric=exponential_order_metric(0.9)
)
linear_ordered_by_value = dict(sorted(linear_cluster_scores.items(), key=lambda x: x[1], reverse=True))
sub_exponential_ordered_by_value = dict(sorted(sub_exponential_cluster_scores.items(), key=lambda x: x[1], reverse=True))
sup_exponential_ordered_by_value = dict(sorted(sup_exponential_cluster_scores.items(), key=lambda x: x[1], reverse=True))
print("Linear cluster scores, Sub-exp cluster scores, Sup-exp cluster scores")
i = 0
for key, value, key_2, value_2, key_3, value_3 in zip(linear_ordered_by_value.keys(), linear_ordered_by_value.values(), sub_exponential_ordered_by_value.keys(), sub_exponential_ordered_by_value.values(), sup_exponential_ordered_by_value.keys(), sup_exponential_ordered_by_value.values()):
    print(f"{key}: {value:0.2f}, {key_2}: {value_2:0.2f}, {key_3}: {value_3:0.2f}")
    i += 1
    if i > 20:
        break
# Out:
# Linear cluster scores, Sub-exp cluster scores, Sup-exp cluster scores
# NVIDIA: 59.32, NVIDIA: 36.66, data science: 94.90
# data science: 58.03, software development: 32.72, NVIDIA: 88.39
# automation: 52.13, data science: 32.47, automation: 80.93
# software development: 50.43, Cloud computing: 30.50, software development: 73.62
# Cloud computing: 44.23, automation: 29.57, data privacy: 66.20
# data privacy: 40.82, data privacy: 22.32, Cloud computing: 63.23
# OpenAI: 27.32, OpenAI: 20.25, open source software: 40.19
# AI training: 24.83, digital transformation: 18.81, search engines: 36.67
# search engines: 24.60, AI training: 18.14, OpenAI: 35.89
# digital transformation: 23.03, search engines: 16.00, AI training: 33.06
# open source software: 20.07, Android: 15.61, data governance: 30.47
# Android: 18.33, healthcare: 12.52, digital transformation: 28.12
# data governance: 17.52, reinforcement learning: 11.56, data management: 28.12
# data management: 17.48, drug discovery: 11.54, reliability: 26.84
# reliability: 17.10, quantum computing: 11.40, employment: 26.65
# employment: 17.00, GitHub Copilot: 11.30, machine learning: 21.91
# reinforcement learning: 16.00, Copyright: 11.11, reinforcement learning: 21.82
# healthcare: 15.64, data management: 10.51, Android: 21.21
# drug discovery: 15.48, reliability: 9.96, drug discovery: 20.78
# customer service: 13.58, retrieval-augmented generation: 9.62, healthcare: 19.83
# quantum computing: 13.25, Microsoft: 9.51, customer service: 19.63

# %% [markdown]
# ### Look at linear selection using linear vs sub-exp vs sup-exp order

# %%
from hex.flows.article_selection.steps.select_articles import compute_article_cluster_scores
from hex.flows.article_selection.steps.select_articles import get_top_n_articles
from typing import Callable

linearly_scored_articles = compute_article_cluster_scores(
        articles, linear_cluster_scores, order_metric=linear_order_metric
)
top_n_linearly_scored_articles = get_top_n_articles(linearly_scored_articles, n=5)
sub_scored_articles = compute_article_cluster_scores(
        articles, sub_exponential_cluster_scores, order_metric=linear_order_metric
)
top_n_sub_scored_articles = get_top_n_articles(sub_scored_articles, n=5)
sup_scored_articles = compute_article_cluster_scores(
        articles, sup_exponential_cluster_scores, order_metric=linear_order_metric
)
top_n_sup_scored_articles = get_top_n_articles(sup_scored_articles, n=5)
for article, article_2, article_3 in zip(top_n_linearly_scored_articles, top_n_sub_scored_articles, top_n_sup_scored_articles):
        print(f"{article['clusters_score']:0.2f} {article['title']}")
        print(article['clusters_names_in_order_added'])
        print(f"{article_2['clusters_score']:0.2f} {article_2['title']}")
        print(article_2['clusters_names_in_order_added'])
        print(f"{article_3['clusters_score']:0.2f} {article_3['title']}")
        print(article_3['clusters_names_in_order_added'])
        print("-"*100)
# Out:
# 88.77 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# 52.58 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# 141.23 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# ----------------------------------------------------------------------------------------------------
# 88.17 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 52.45 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 140.46 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# ----------------------------------------------------------------------------------------------------
# 88.17 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 51.45 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# 140.46 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# ----------------------------------------------------------------------------------------------------
# 87.85 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# 51.45 Welcome to the AI factory era: A preview of Dell Technologies World 2025
# ['NVIDIA', 'automation']
# 140.02 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# ----------------------------------------------------------------------------------------------------
# 87.69 JFrog and Nvidia partner on secure software supply chain for Enterprise AI Factory
# ['data science', 'NVIDIA']
# 51.06 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# 139.10 JFrog and Nvidia partner on secure software supply chain for Enterprise AI Factory
# ['data science', 'NVIDIA']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Look at sub-exponential selection using linear vs sub-exp vs sup-exp order

# %%
from hex.flows.article_selection.steps.select_articles import compute_article_cluster_scores
from hex.flows.article_selection.steps.select_articles import get_top_n_articles
from typing import Callable

linearly_scored_articles = compute_article_cluster_scores(
        articles, linear_cluster_scores, order_metric=exponential_order_metric(0.1)
)
top_n_linearly_scored_articles = get_top_n_articles(linearly_scored_articles, n=5)
sub_scored_articles = compute_article_cluster_scores(
        articles, sub_exponential_cluster_scores, order_metric=exponential_order_metric(0.1)
)
top_n_sub_scored_articles = get_top_n_articles(sub_scored_articles, n=5)
sup_scored_articles = compute_article_cluster_scores(
        articles, sup_exponential_cluster_scores, order_metric=exponential_order_metric(0.1)
)
top_n_sup_scored_articles = get_top_n_articles(sup_scored_articles, n=5)
for article, article_2, article_3 in zip(top_n_linearly_scored_articles, top_n_sub_scored_articles, top_n_sup_scored_articles):
        print(f"{article['clusters_score']:0.2f} {article['title']}")
        print(article['clusters_names_in_order_added'])
        print(f"{article_2['clusters_score']:0.2f} {article_2['title']}")
        print(article_2['clusters_names_in_order_added'])
        print(f"{article_3['clusters_score']:0.2f} {article_3['title']}")
        print(article_3['clusters_names_in_order_added'])
        print("-"*100)
# Out:
# 64.57 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 39.65 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 103.76 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# ----------------------------------------------------------------------------------------------------
# 64.53 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# 39.62 Semiconductor Industry Accelerates Design Manufacturing With NVIDIA Blackwell and CUDA-X
# ['NVIDIA', 'automation', 'computational lithography', 'electronic design automation', 'process control']
# 103.76 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# ----------------------------------------------------------------------------------------------------
# 64.53 Welcome to the AI factory era: A preview of Dell Technologies World 2025
# ['NVIDIA', 'automation']
# 39.62 Welcome to the AI factory era: A preview of Dell Technologies World 2025
# ['NVIDIA', 'automation']
# 103.74 JFrog and Nvidia partner on secure software supply chain for Enterprise AI Factory
# ['data science', 'NVIDIA']
# ----------------------------------------------------------------------------------------------------
# 63.97 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 38.26 AI-generated CUDA kernels outperform PyTorch in several GPU-heavy machine learning benchmarks
# ['NVIDIA', 'search engines', 'PyTorch']
# 103.13 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# ----------------------------------------------------------------------------------------------------
# 63.97 Advanced Optimization Strategies for LLM Training on NVIDIA Grace Hopper
# ['data science', 'NVIDIA', 'Grace Hopper', 'CPU offloading', 'unified memory', 'automatic mixed precision']
# 38.26 Blackwell Breaks the 1,000 TPS/User Barrier With Meta’s Llama 4 Maverick
# ['NVIDIA', 'search engines']
# 97.62 Your 2025 Data and AI Summit Guide for Public Sector Industry Experience
# ['data science', 'reliability', 'public sector', 'data governance', 'data privacy', 'Databricks']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Look at sup-exponential selection using linear vs sub-exp vs sup-exp order

# %%
from hex.flows.article_selection.steps.select_articles import compute_article_cluster_scores
from hex.flows.article_selection.steps.select_articles import get_top_n_articles
from typing import Callable

linearly_scored_articles = compute_article_cluster_scores(
        articles, linear_cluster_scores, order_metric=exponential_order_metric(0.9)
)
top_n_linearly_scored_articles = get_top_n_articles(linearly_scored_articles, n=5)
sub_scored_articles = compute_article_cluster_scores(
        articles, sub_exponential_cluster_scores, order_metric=exponential_order_metric(0.9)
)
top_n_sub_scored_articles = get_top_n_articles(sub_scored_articles, n=5)
sup_scored_articles = compute_article_cluster_scores(
        articles, sup_exponential_cluster_scores, order_metric=exponential_order_metric(0.9)
)
top_n_sup_scored_articles = get_top_n_articles(sup_scored_articles, n=5)
for article, article_2, article_3 in zip(top_n_linearly_scored_articles, top_n_sub_scored_articles, top_n_sup_scored_articles):
        print(f"{article['clusters_score']:0.2f} {article['title']}")
        print(article['clusters_names_in_order_added'])
        print(f"{article_2['clusters_score']:0.2f} {article_2['title']}")
        print(article_2['clusters_names_in_order_added'])
        print(f"{article_3['clusters_score']:0.2f} {article_3['title']}")
        print(article_3['clusters_names_in_order_added'])
        print("-"*100)
# Out:
# 138.38 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# 81.27 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# 215.83 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# ----------------------------------------------------------------------------------------------------
# 125.46 How open systems drive AI performance
# ['Cloud computing', 'open source software', 'search engines', 'NVIDIA']
# 75.30 How open systems drive AI performance
# ['Cloud computing', 'open source software', 'search engines', 'NVIDIA']
# 193.55 How open systems drive AI performance
# ['Cloud computing', 'open source software', 'search engines', 'NVIDIA']
# ----------------------------------------------------------------------------------------------------
# 115.16 Your 2025 Data and AI Summit Guide for Public Sector Industry Experience
# ['data science', 'reliability', 'public sector', 'data governance', 'data privacy', 'Databricks']
# 72.48 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# 188.93 Your 2025 Data and AI Summit Guide for Public Sector Industry Experience
# ['data science', 'reliability', 'public sector', 'data governance', 'data privacy', 'Databricks']
# ----------------------------------------------------------------------------------------------------
# 114.43 HPE’s stock rises on AI momentum and more clarity on market conditions
# ['data science', 'server architecture', 'Cloud computing', 'acquisitions', 'search engines']
# 69.84 HPE’s stock rises on AI momentum and more clarity on market conditions
# ['data science', 'server architecture', 'Cloud computing', 'acquisitions', 'search engines']
# 181.39 Digital lab for data- and robot-driven materials science
# ['Materials science', 'automation', 'data science', 'Thin films', 'open source software']
# ----------------------------------------------------------------------------------------------------
# 114.07 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# 67.32 Run LLMs on AnythingLLM Faster With NVIDIA RTX AI PCs
# ['retrieval-augmented generation', 'NVIDIA', 'Cloud computing']
# 179.05 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Look at selection with diversity using linear vs sub-exp vs sup-exp order

# %%
from hex.flows.article_selection.steps.select_articles import select_top_articles_with_diversity

cluster_scores, top_n_linearly_scored_articles_with_diversity = select_top_articles_with_diversity(
    articles, articles,
    order_metric=linear_order_metric, n=5
)
cluster_scores, top_n_sub_scored_articles_with_diversity = select_top_articles_with_diversity(
    articles, articles,
    order_metric=exponential_order_metric(0.1), n=5
)
cluster_scores, top_n_sup_scored_articles_with_diversity = select_top_articles_with_diversity(
    articles, articles,
    order_metric=exponential_order_metric(0.9), n=5
)
for article, article_2, article_3 in zip(top_n_linearly_scored_articles_with_diversity, top_n_sub_scored_articles_with_diversity, top_n_sup_scored_articles_with_diversity)     :
    print(f"{article['clusters_score']:0.2f} {article['title']}")
    print(article['clusters_names_in_order_added'])
    print(f"{article_2['clusters_score']:0.2f} {article_2['title']}")
    print(article_2['clusters_names_in_order_added'])
    print(f"{article_3['clusters_score']:0.2f} {article_3['title']}")
    print(article_3['clusters_names_in_order_added'])
    print("-"*100)
# Out:
# 88.77 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# 39.65 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 215.83 Asana shares drop as earnings results top estimates but revenue growth slows
# ['data science', 'Business growth', 'automation', 'software development']
# ----------------------------------------------------------------------------------------------------
# 86.67 NVIDIA’s Bartley Richardson on How Teams of AI Agents Provide Next-Level Automation
# ['NVIDIA', 'automation', 'interoperability']
# 35.83 AWS open-sources Strands Agents SDK to ease AI agent development
# ['software development', 'Cloud computing', 'open source software']
# 193.55 How open systems drive AI performance
# ['Cloud computing', 'open source software', 'search engines', 'NVIDIA']
# ----------------------------------------------------------------------------------------------------
# 83.45 Microsoft Just Laid Off 6,000 Workers. And AI Might Be to Blame
# ['automation', 'software development', 'employment', 'business strategy']
# 35.52 Part 3: Building an AI-powered assistant for investment research with multi-agent collaboration in Amazon Bedrock and Amazon Bedrock Data Automation
# ['data science', 'automation', 'Amazon Bedrock']
# 172.14 Microsoft Just Laid Off 6,000 Workers. And AI Might Be to Blame
# ['automation', 'software development', 'employment', 'business strategy']
# ----------------------------------------------------------------------------------------------------
# 79.24 AWS open-sources Strands Agents SDK to ease AI agent development
# ['software development', 'Cloud computing', 'open source software']
# 33.46 7 AWS Services for Machine Learning Projects
# ['Cloud computing', 'automation']
# 164.96 NVIDIA and Microsoft Advance Development on RTX AI PCs
# ['NVIDIA', 'Microsoft', 'software development', 'microservices', 'RTX Remix']
# ----------------------------------------------------------------------------------------------------
# 64.64 Ryan Ries, Chief AI & Data Scientist at Mission – Interview Series
# ['Cloud computing', 'data privacy']
# 31.85 The future of engineering belongs to those who build with AI, not without it
# ['automation', 'data privacy', 'MLOps']
# 157.40 TechRepublic Premium Editorial Calendar: Policies, Hiring Kits, and Glossaries for Download
# ['software development', 'data privacy', 'employment', 'Checklists', 'Glossaries', 'PowerShell']
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Inspect result

# %%
db_path = flow.config.get("db_path")
db_path = '/Users/mathieucrilout/Repos/train_tune_deploy/data/hex_tinydb.json'

# %%
from hex.storage.hex_storage import HexStorage
import json

storage = HexStorage(db_path)
selection = storage.get_all('selections')[-1]
selection = storage.lazy_load(selection)[0]

if "clusters_scores_artifact" in selection:
    clusters_scores = json.loads(selection["clusters_scores"])
else:
    clusters_scores = selection["clusters_scores"]
if "linearly_selected_articles_with_diversity_artifact" in selection:
    articles = json.loads(selection["linearly_selected_articles_with_diversity"])
else:
    articles = selection["linearly_selected_articles_with_diversity"]

# %%
selection
# Out:
# {'selection_time': '2025-06-08 21:58:14.146214+00:00',
#  'clusters_scores': {'data analysis': 0, 'Generative AI': 0},
#  'linearly_selected_articles_with_diversity': [{'table_name': 'replicated_articles',
#    'title': 'Top 5 Alternative Data Career Paths and How to Learn Them for Free',
#    'author': 'Nate Rosidi',
#    'published_date': 'Thu, 05 Jun 2025 12:00:02 +0000',
#    'url_domain': 'kdnuggets.com',
#    'url': 'https://www.kdnuggets.com/top-5-alternative-data-career-paths-and-how-to-learn-them-for-free',
#    'summary': 'How about some alternative options for a data career? Learn about five non-standard career paths, required skills, and how to learn them for free.',
#    'tags': [],
#    'html_content_length': 201344,
#    'text_content_length': 10758,
#    'summary_length': 146,
#    'summary_text_ratio': 0.013571295779884737,
#    'metadata': {'error': None, 'duration': 5},
#    'original_table_name': 'articles',
#    'created_at': '2025-06-05T12:18:06.750408',
#    'html_content_artifact': {'path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/article_2dd81c3c100843c79e299990bf10fc2a/html_content.txt',
#     'format': 'text',
#     'encoding': 'utf-8'},
#    'text_content_artifact': {'path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/article_2dd81c3c100843c79e299990bf10fc2a/text_content.txt',
#     'format': 'text',
#     'encoding': 'utf-8'},
#    'original_doc_id': '3622',
#    'is_ai_added': True,
#    'dense_summary_added': 'Alternative data career paths include Data Product Manager, Data Journalist, Analytics Engineer, Operations Analyst, and Data Ethicist/AI Policy Analyst.\n\n**Data Product Managers** define data requirements for data products, focusing on accessibility, scalability, reliability, and user experience. Required skills include SQL, data analytics (EDA, KPIs), stakeholder communication (PRDs), product management (Agile, JIRA, prioritization frameworks), and basic UX for dashboards (Tableau, Power BI, Looker Studio).\n\n**Data Journalists** use data analysis and visualization to tell stories, working with public data to verify claims. Skills needed: data cleaning (Excel, Python/pandas, R/tidyverse), data visualization (Flourish, Datawrapper, Tableau Public, Observable, D3.js), storytelling, and data sourcing (data.gov, EU Open Data Portal, WHO, World Bank, FOIA).\n\n**Analytics Engineers** transform raw data into analysis-ready datasets, owning the analytics layer. Key skills: advanced SQL (CTEs, window functions, Jinja), Data Build Tool (dbt), Git, data warehousing (BigQuery, Snowflake, Redshift), and optional Python, Looker Studio/Mode/Metabase, Monte Carlo/Datafold.\n\n**Operations Analysts** optimize business operations using data, identifying inefficiencies and proposing solutions. Required skills: Excel, SQL, data visualization (Tableau, Power BI, Looker Studio), forecasting, scenario modeling, and process automation (Zapier/Power Automate/Make, Google Apps Scripts).\n\n**Data Ethicists/AI Policy Analysts** ensure fair and accountable use of algorithms, focusing on ethical aspects and compliance. Skills include understanding of algorithms/model bias, legal/ethical frameworks (GDPR, EU AI Act, FATE principles), and communication/policy writing.',
#    'dense_summary_length_added': 1763,
#    'core_line_summary_added': 'The field of data offers diverse career paths beyond traditional data science, including roles focused on product management, journalism, analytics engineering, operations, and ethical AI implementation, each requiring specialized skills.',
#    'core_line_summary_length_added': 238,
#    'tags_pred_added': ['Data analysis',
#     'Data product management',
#     'Analytics engineering',
#     'Data journalism',
#     'Data ethics'],
#    'tags_pred_length_added': 5,
#    'clusters_names_in_order_added': ['data analysis',
#     'data management',
#     'cloud computing',
#     'Data journalism',
#     'data ethics'],
#    'title_vs_core_rouge_eval': 0.049792531120331954,
#    'tag_similarity_eval': 0.0,
#    'doc_id': '3644',
#    'clusters_score': 0},
#   {'table_name': 'replicated_articles',
#    'title': 'The cursed world of AI kiss and hug apps',
#    'author': 'Victoria Song',
#    'published_date': '2025-06-05T08:00:00-04:00',
#    'url_domain': 'theverge.com',
#    'url': 'https://www.theverge.com/ai-artificial-intelligence/679295/ai-hug-kiss-video-apps-deepfakes',
#    'summary': "Doomscroll on TikTok long enough, and you'll come across an ad for AI video apps. In one ad, a stereotypically nerdy girl puckishly smirks as she uploads a picture of herself and her much more handsome crush. Boom - suddenly, thanks to AI, they're smooching. In another, I'm shown a woman in a blouse and [&#8230;]",
#    'tags': ['AI', 'Analysis', 'Hands-on', 'Reviews', 'Tech'],
#    'html_content_length': 472554,
#    'text_content_length': 14796,
#    'summary_length': 314,
#    'summary_text_ratio': 0.021221951878886185,
#    'metadata': {'error': None, 'duration': 0},
#    'original_table_name': 'articles',
#    'created_at': '2025-06-05T12:18:20.556450',
#    'html_content_artifact': {'path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/article_676800f6ff944566befa93ffbcfb0f96/html_content.txt',
#     'format': 'text',
#     'encoding': 'utf-8'},
#    'text_content_artifact': {'path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/06/article_676800f6ff944566befa93ffbcfb0f96/text_content.txt',
#     'format': 'text',
#     'encoding': 'utf-8'},
#    'original_doc_id': '3632',
#    'is_ai_added': True,
#    'dense_summary_added': "AI video apps offer benign and disturbing video templates, including kissing, hugging, and AI-generated nudity, often behind subscription fees ($2.99-$7.99/week or $49.99-$69.99/year). Apps like Boom.AI, VideoAI, and DreamVid, from companies like NineG (Mozart AI, Plum AI, Reel TV) and Shenzhen iMyFone Technology Co.Ltd (productivity apps, Studio Ghibi generator), allow users to upload photos to create deepfakes.\n\nGenerated videos often exhibit AI flaws: awkward kissing, stiff hugs, racial bias, and morphing features. While OpenAI's Sora and Google's Veo have restrictions, these apps offer simpler, less restrictive content generation.\n\nThese apps exist in a legal gray area, skirting anti-deepfake porn laws but potentially violating digital replica rules. Google Play Store prohibits sexually gratifying content, and Apple's App Store bans offensive or creepy content, but enforcement is inconsistent. Meta removes violating ads and accounts.\n\nThe apps' functions overlap with fan art but raise ethical concerns about deepfaking others without consent. The author experimented with deepfaking deceased parents, finding the results both eerie and comforting, highlighting the complex relationship between grief and AI. The question is not whether these apps are harmful, but what users seek to see reflected in them.",
#    'dense_summary_length_added': 1324,
#    'core_line_summary_added': 'AI video apps offering deepfake templates, including sexualized content, raise ethical and legal concerns due to inconsistent enforcement and potential misuse, despite their appeal to user desires and grief.',
#    'core_line_summary_length_added': 207,
#    'tags_pred_added': ['Generative AI',
#     'deepfakes',
#     'AI ethics',
#     'mobile applications',
#     'content moderation'],
#    'tags_pred_length_added': 5,
#    'clusters_names_in_order_added': ['Generative AI',
#     'deepfakes',
#     'AI ethics',
#     'software development',
#     'content moderation'],
#    'title_vs_core_rouge_eval': 0.028436018957345967,
#    'tag_similarity_eval': 0.38524137017476817,
#    'doc_id': '3654',
#    'clusters_score': 0}],
#  'ingestion_summary': 'For this digest it ingested more than 3 articles from 3 sources (saving you 1 hours of reading).',
#  'table_name': 'selections',
#  'created_at': '2025-06-08T21:58:14.496691',
#  'doc_id': '21'}
