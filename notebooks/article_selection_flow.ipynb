# %% [markdown]
# # 🔍 Article Selection Analysis for TTD Newsletter
#
# This notebook is an interactive replicate of the article selection flow.
#
# Find, test, and evaluate it with dummy data.
#
# **You have to execute all steps in order to get proper result.**
#
# **You should inspect the flow state at each step** to understand the flow.

# %%
from metaflow import FlowSpec, step, Parameter
from pydantic import BaseModel, Field
from datetime import datetime

from ttd.utils.print import safe_pretty_print

class FlowParametersSchema(BaseModel):
    """Schema for flow parameters."""
    articles_table: str = Field(
        'articles', description="Table to load articles from"
    )
    articles_limit: int = Field(
        2, description="Maximum number of articles to select"
    )
    date_threshold: datetime = Field(
        'Thu, 03 Apr 2025 18:00:00 +0000',
        description="Select articles published after this date"
    )
    cluster_date_threshold: datetime = Field(
        'Thu, 03 Apr 2025 18:00:00 +0000',
        description="articles published after this date are used to compute clusters scores"
    )
    clean_tables: bool = Field(
        False, description="Clean tables (selections, selected_articles)"
    )
    class Config:
        extra = 'allow'
    pass

flow = FlowParametersSchema(
    articles_table='replicated_articles',
    articles_limit=20,
    clean_tables=True
)
safe_pretty_print(flow.model_dump())
# Out:
# /Users/mathieucrilout/.miniconda3/envs/ttd/lib/python3.10/site-packages/pydantic/main.py:426: UserWarning: Pydantic serializer warnings:
#   Expected `datetime` but got `str` with value `'Thu, 03 Apr 2025 18:00:00 +0000'` - serialized value may not be as expected
#   Expected `datetime` but got `str` with value `'Thu, 03 Apr 2025 18:00:00 +0000'` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_python(
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 20,
#     'date_threshold': 'Thu, 03 Apr 2025 18:00:00 +0000',
#     'cluster_date_threshold': 'Thu, 03 Apr 2025 18:00:00 +0000',
#     'clean_tables': True
# }

# %% [markdown]
# ### **1. Start step**
# Init, config, parameters, tracks versioning...

# %%
from ttd.flows.article_selection.steps.start import execute as start_step

start_step(flow)
safe_pretty_print(flow.model_dump())
# Out:
# 2025-05-09 17:31:16,265 - ttd.flows.article_selection.steps.start - INFO - ✅ Database first connection established.
# 2025-05-09 17:31:16,384 - ttd.flows.article_selection.steps.start - INFO - ✅ Database cleaned.
# Thu, 03 Apr 2025 18:00:00 +0000
# /Users/mathieucrilout/.miniconda3/envs/ttd/lib/python3.10/site-packages/pydantic/main.py:426: UserWarning: Pydantic serializer warnings:
#   Expected `datetime` but got `str` with value `'Thu, 03 Apr 2025 18:00:00 +0000'` - serialized value may not be as expected
#   Expected `datetime` but got `str` with value `'Thu, 03 Apr 2025 18:00:00 +0000'` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_python(
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 20,
#     'date_threshold': 'Thu, 03 Apr 2025 18:00:00 +0000',
#     'cluster_date_threshold': 'Thu, 03 Apr 2025 18:00:00 +0000',
#     'clean_tables': True,
#     'config': {
#         'debug': False,
#         'persist': True,
#         'data_dir': '/Users/mathieucrilout/Repos/train_tune_deploy/data',
#         'db_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/ttd_tinydb.json',
#         'feeds_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds.txt',
#         'feeds_stealth_path':
# '/Users/mathieucrilout/Repos/train_tune_deployd/data/rss_feeds_stealth.txt',
#         'last_scrape': '2025-04-04T13:22:35.503007',
#         'last_alpha_pipeline': '2025-04-27T08:33:44.289608'
#     },
#     'git_metadata': {
#         'git_commit': '3fcfb77e442259fa1929f110c86e49b051d10b34',
#         'git_branch': 'dev',
#         'git_repo': 'git@github.com:mcrilo33/train-tune-deploy.git'
#     },
#     'parsed_date_threshold': datetime.datetime(2025, 4, 3, 18, 0, tzinfo=tzutc()),
#     'parsed_cluster_date_threshold': datetime.datetime(2025, 4, 3, 18, 0, tzinfo=tzutc()),
#     'min_parsed_date_threshold': datetime.datetime(2025, 4, 3, 18, 0, tzinfo=tzutc()),
#     'metrics': {},
#     'errors': {},
#     'prediction_times': {},
#     'token_usage': {}
# }

# %% [markdown]
# ### **2. Load articles step**

# %%
from ttd.flows.article_selection.steps.load_articles \
    import execute as load_articles_step

load_articles_step(flow)
safe_pretty_print(flow.model_dump())
# Out:
# 2025-05-09 17:31:29,252 - ttd.flows.article_selection.steps.load_articles - INFO - Loading articles...
# 2025-05-09 17:31:29,296 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ Loaded 100 articles from 'replicated_articles': len(articles)=100, date_threshold='2025-04-03 18:00:00+00:00'
# 2025-05-09 17:31:29,296 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ Filtering out already replicated articles...
# 2025-05-09 17:31:29,327 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ There are 0 already selected articles
# 2025-05-09 17:31:29,327 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ Filtered out 0 already selected articles from 'selected_articles'
# 2025-05-09 17:31:29,327 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ Loaded 100 articles...
# 2025-05-09 17:31:29,327 - ttd.flows.article_selection.steps.load_articles - INFO - ✅ Step load_articles done in 0.07s
# /Users/mathieucrilout/.miniconda3/envs/ttd/lib/python3.10/site-packages/pydantic/main.py:426: UserWarning: Pydantic serializer warnings:
#   Expected `datetime` but got `str` with value `'Thu, 03 Apr 2025 18:00:00 +0000'` - serialized value may not be as expected
#   Expected `datetime` but got `str` with value `'Thu, 03 Apr 2025 18:00:00 +0000'` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_python(
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 20,
#     'date_threshold': 'Thu, 03 Apr 2025 18:00:00 +0000',
#     'cluster_date_threshold': 'Thu, 03 Apr 2025 18:00:00 +0000',
#     'clean_tables': True,
#     'config': {
#         'debug': False,
#         'persist': True,
#         'data_dir': '/Users/mathieucrilout/Repos/train_tune_deploy/data',
#         'db_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/ttd_tinydb.json',
#         'feeds_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds.txt',
#         'feeds_stealth_path':
# '/Users/mathieucrilout/Repos/train_tune_deployd/data/rss_feeds_stealth.txt',
#         'last_scrape': '2025-04-04T13:22:35.503007',
#         'last_alpha_pipeline': '2025-04-27T08:33:44.289608'
#     },
#     'git_metadata': {
#         'git_commit': '3fcfb77e442259fa1929f110c86e49b051d10b34',
#         'git_branch': 'dev',
#         'git_repo': 'git@github.com:mcrilo33/train-tune-deploy.git'
#     },
#     'parsed_date_threshold': datetime.datetime(2025, 4, 3, 18, 0, tzinfo=tzutc()),
#     'parsed_cluster_date_threshold': datetime.datetime(2025, 4, 3, 18, 0, tzinfo=tzutc()),
#     'min_parsed_date_threshold': datetime.datetime(2025, 4, 3, 18, 0, tzinfo=tzutc()),
#     'metrics': {
#         'step_start_times': {
#             'load_articles': 1746804689.253129
#         },
#         'step_duration': {
#             'load_articles': 0.07477807998657227
#         }
#     },
#     'errors': {},
#     'prediction_times': {},
#     'token_usage': {},
#     'articles': [
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Trump Tariffs Unleash Shift in Global Economy',
#             'author': 'Pablo Valerio',
#             'published_date': 'Thu, 03 Apr 2025 18:00:00 +0000',
#             'url_domain': 'eetimes.com',
#             'url':
# 'https://www.eetimes.com/trump-tariffs-unleash-shift-in-global-economy/',
#             'summary': 'Trump tariffs, now 54% on Chinese goods, threaten to raise
# electronics prices. C...',
#             'tags': [
#                 'News',
#                 'Supply Chain & Distribution',
#                 'Supply Chain Analysis',
#                 'Global Trade',
#                 'supply chain disruptions',
#                 'Tariffs',
#                 'Trump administration'
#             ],
#             'html_content_length': 358447,
#             'text_content_length': 9980,
#             'summary_length': 225,
#             'summary_text_ratio': 0.022545090180360723,
#             'created_at': '2025-04-28T19:12:28.351109',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:13.940886',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '1',
#             'is_ai_pred_added': 'false',
#             'doc_id': '1'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Meet Open-Qwen2VL: A Fully Open and Compute-Efficient Multimodal
# Large Language ...',
#             'author': 'Asif Razzaq',
#             'published_date': 'Fri, 04 Apr 2025 05:15:52 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/meet-open-qwen2vl-a-fully-open-and-compu...',
#             'summary': 'Multimodal Large Language Models (MLLMs) have advanced the
# integration of visual...',
#             'tags': [
#                 'AI Paper Summary',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Language Model',
#                 'Large Language Model',
#                 'Machine Learning',
#                 'New Releases',
#                 'Open Source',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 370768,
#             'text_content_length': 5752,
#             'summary_length': 539,
#             'summary_text_ratio': 0.09370653685674547,
#             'created_at': '2025-04-28T19:12:30.322581',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.488251',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '309',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'Open-Qwen2VL, a 2-billion parameter Multimodal Large
# Language Model (MLLM) devel...',
#             'length_dense_summary_added': 1313,
#             'core_line_summary_added': 'Open-Qwen2VL offers an efficient, open-source MLLM
# alternative, achieving compet...',
#             'length_core_line_summary_added': 190,
#             'tags_pred_added': [
#                 'MLLMs',
#                 'multimodal learning',
#                 'open source',
#                 'computer vision'
#             ],
#             'length_tags_pred_added': 4,
#             'clusters_names_in_order_added': [
#                 'MLLMs',
#                 'multimodal learning',
#                 'open source',
#                 'computer vision'
#             ],
#             'dense_vs_core_rouge_eval': 0.07048458149779736,
#             'tag_similarity_eval': 0.5261094195634279,
#             'doc_id': '2'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Researchers from Dataocean AI and Tsinghua University Introduces
# Dolphin: A Mult...',
#             'author': 'Asif Razzaq',
#             'published_date': 'Fri, 04 Apr 2025 01:25:27 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/researchers-from-dataocean-ai-and-tsingh...',
#             'summary': 'Automatic speech recognition (ASR) technologies have advanced
# significantly, yet...',
#             'tags': [
#                 'AI Paper Summary',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Generative AI',
#                 'Language Model',
#                 'Large Language Model',
#                 'Machine Learning',
#                 'New Releases',
#                 'Open Source',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 375396,
#             'text_content_length': 5255,
#             'summary_length': 690,
#             'summary_text_ratio': 0.1313035204567079,
#             'created_at': '2025-04-28T19:12:32.032592',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.572481',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '310',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'Dataocean AI and Tsinghua University introduced
# Dolphin, a multilingual ASR mode...',
#             'length_dense_summary_added': 1108,
#             'core_line_summary_added': 'Dolphin, a new multilingual ASR model developed by
# Dataocean AI and Tsinghua Uni...',
#             'length_core_line_summary_added': 223,
#             'tags_pred_added': [
#                 'Automatic speech recognition',
#                 'Multilingual models',
#                 'Eastern languages',
#                 'Dialects'
#             ],
#             'length_tags_pred_added': 4,
#             'clusters_names_in_order_added': [
#                 'Automatic speech recognition',
#                 'Multilingual models',
#                 'Eastern languages',
#                 'Dialects'
#             ],
#             'dense_vs_core_rouge_eval': 0.16494845360824742,
#             'tag_similarity_eval': 0.4227679017903087,
#             'doc_id': '3'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'This AI Paper Introduces FASTCURL: A Curriculum Reinforcement
# Learning Framework...',
#             'author': 'Nikhil',
#             'published_date': 'Fri, 04 Apr 2025 00:33:47 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/this-ai-paper-introduces-fastcurl-a-curr...',
#             'summary': 'Large language models have transformed how machines comprehend and
# generate text...',
#             'tags': [
#                 'AI Paper Summary',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Language Model',
#                 'Large Language Model',
#                 'Machine Learning',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 358212,
#             'text_content_length': 5442,
#             'summary_length': 626,
#             'summary_text_ratio': 0.11503123851525175,
#             'created_at': '2025-04-28T19:12:33.837998',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.680091',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '311',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'Tencent researchers introduced FASTCURL, a curriculum
# reinforcement learning fra...',
#             'length_dense_summary_added': 1078,
#             'core_line_summary_added': 'FASTCURL offers a computationally efficient
# curriculum reinforcement learning fr...',
#             'length_core_line_summary_added': 228,
#             'tags_pred_added': [
#                 'Reinforcement learning',
#                 'Curriculum learning',
#                 'Reasoning',
#                 'Model training',
#                 'Benchmarking'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'Reinforcement learning',
#                 'Curriculum learning',
#                 'Reasoning',
#                 'Model training',
#                 'Benchmarking'
#             ],
#             'dense_vs_core_rouge_eval': 0.13684210526315788,
#             'tag_similarity_eval': 0.39229967376082875,
#             'doc_id': '4'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Introduction to MCP: The Ultimate Guide to Model Context Protocol
# for AI Assista...',
#             'author': 'Asif Razzaq',
#             'published_date': 'Thu, 03 Apr 2025 20:20:36 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/introduction-to-mcp-the-ultimate-guide-t...',
#             'summary': 'The Model Context Protocol (MCP) is an open standard (open-sourced
# by Anthropic)...',
#             'tags': [
#                 'Agentic AI',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Language Model',
#                 'Large Language Model',
#                 'Machine Learning',
#                 'Model Context Protocol',
#                 'New Releases',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 383286,
#             'text_content_length': 14928,
#             'summary_length': 457,
#             'summary_text_ratio': 0.030613612004287246,
#             'created_at': '2025-04-28T19:12:35.821819',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.765198',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '312',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'The Model Context Protocol (MCP) is an open standard
# for connecting AI assistant...',
#             'length_dense_summary_added': 1512,
#             'core_line_summary_added': "The Model Context Protocol (MCP) standardizes AI
# assistants' access to external ...",
#             'length_core_line_summary_added': 189,
#             'tags_pred_added': [
#                 'LLMs',
#                 'RAG',
#                 'AI architecture',
#                 'open standards',
#                 'data integration'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'MLLMs',
#                 'RAG',
#                 'AI architecture',
#                 'open source',
#                 'data integration'
#             ],
#             'dense_vs_core_rouge_eval': 0.145748987854251,
#             'tag_similarity_eval': 0.4115448201247924,
#             'doc_id': '5'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'UB-Mesh: A Cost-Efficient, Scalable Network Architecture for
# Large-Scale LLM Tra...',
#             'author': 'Sana Hassan',
#             'published_date': 'Thu, 03 Apr 2025 20:08:33 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/ub-mesh-a-cost-efficient-scalable-networ...',
#             'summary': 'As LLMs scale, their computational and bandwidth demands increase
# significantly,...',
#             'tags': [
#                 'AI Infrastructure',
#                 'AI Paper Summary',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Language Model',
#                 'Large Language Model',
#                 'Machine Learning',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 355087,
#             'text_content_length': 6079,
#             'summary_length': 545,
#             'summary_text_ratio': 0.08965290343806546,
#             'created_at': '2025-04-28T19:12:37.592010',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.872897',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '313',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'LLM training demands scalable, cost-effective, and
# fault-tolerant AI infrastruct...',
#             'length_dense_summary_added': 1287,
#             'core_line_summary_added': "Huawei's UB-Mesh network architecture offers a
# cost-effective and fault-tolerant...",
#             'length_core_line_summary_added': 222,
#             'tags_pred_added': [
#                 'LLMs',
#                 'distributed computing',
#                 'network architecture',
#                 'Huawei',
#                 'fault tolerance'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'MLLMs',
#                 'distributed computing',
#                 'network architecture',
#                 'Huawei',
#                 'fault tolerance'
#             ],
#             'dense_vs_core_rouge_eval': 0.15454545454545454,
#             'tag_similarity_eval': 0.3334022518968497,
#             'doc_id': '6'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'This AI Paper Unveils a Reverse-Engineered Simulator Model for
# Modern NVIDIA GPU...',
#             'author': 'Nikhil',
#             'published_date': 'Thu, 03 Apr 2025 19:39:21 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/this-ai-paper-unveils-a-reverse-engineer...',
#             'summary': 'GPUs are widely recognized for their efficiency in handling
# high-performance com...',
#             'tags': [
#                 'AI Infrastructure',
#                 'AI Paper Summary',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Language Model',
#                 'Large Language Model',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 358548,
#             'text_content_length': 5432,
#             'summary_length': 623,
#             'summary_text_ratio': 0.11469072164948453,
#             'created_at': '2025-04-28T19:12:39.549329',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.959640',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '314',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'A Universitat Politècnica de Catalunya team
# reverse-engineered modern NVIDIA GPU...',
#             'length_dense_summary_added': 1091,
#             'core_line_summary_added': 'Researchers developed a more accurate NVIDIA GPU
# simulation model, significantly...',
#             'length_core_line_summary_added': 195,
#             'tags_pred_added': [
#                 'GPU',
#                 'microarchitecture',
#                 'simulation',
#                 'performance modeling',
#                 'NVIDIA'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'GPU',
#                 'microarchitecture',
#                 'simulation',
#                 'performance modeling',
#                 'NVIDIA'
#             ],
#             'dense_vs_core_rouge_eval': 0.14054054054054055,
#             'tag_similarity_eval': 0.3600589270323685,
#             'doc_id': '7'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Superman’s latest trailer introduces his team of robot assistants',
#             'author': 'Charles Pulliam-Moore',
#             'published_date': '2025-04-03T21:13:49-04:00',
#             'url_domain': 'theverge.com',
#             'url': 'https://www.theverge.com/news/643100/superman-robots-trailer',
#             'summary': 'Though Superman is clearly going to get the living daylights beat
# out of him at ...',
#             'tags': [
#                 'Comics',
#                 'DC Comics',
#                 'Entertainment',
#                 'Film',
#                 'News',
#                 'Trailers'
#             ],
#             'html_content_length': 376544,
#             'text_content_length': 2670,
#             'summary_length': 331,
#             'summary_text_ratio': 0.12397003745318352,
#             'created_at': '2025-04-28T19:12:40.978978',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.253656',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '317',
#             'is_ai_pred_added': 'false',
#             'doc_id': '8'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Steve Jackson Games says tariffs are a ‘seismic shift’ for board
# games',
#             'author': 'Jay Peters',
#             'published_date': '2025-04-03T19:56:34-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/news/643173/trump-tariffs-steve-jackson-board-game-indu...',
#             'summary': 'The CEO of Steve Jackson Games, which makes board games and card
# games, says tha...',
#             'tags': [
#                 'Entertainment',
#                 'Gaming',
#                 'News'
#             ],
#             'html_content_length': 416012,
#             'text_content_length': 4141,
#             'summary_length': 312,
#             'summary_text_ratio': 0.07534411977783144,
#             'created_at': '2025-04-28T19:12:42.672075',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.446946',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '319',
#             'is_ai_pred_added': 'false',
#             'doc_id': '9'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Trump&#8217;s tariffs mean you&#8217;ll pay more for all gadgets',
#             'author': 'Victoria Song',
#             'published_date': '2025-04-03T18:47:51-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/tech/643041/trump-tariff-consumer-electronics-gadgets-s...',
#             'summary': 'If you were wondering how President Trump&#226;&#x20ac;&#x2122;s
# tariffs may imp...',
#             'tags': [
#                 'Gadgets',
#                 'Policy',
#                 'Tech'
#             ],
#             'html_content_length': 440752,
#             'text_content_length': 7142,
#             'summary_length': 473,
#             'summary_text_ratio': 0.06622794735368244,
#             'created_at': '2025-04-28T19:12:44.169013',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.555104',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '320',
#             'is_ai_pred_added': 'False',
#             'doc_id': '10'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'The best fitness trackers to buy right now',
#             'author': 'Victoria Song',
#             'published_date': '2025-04-03T18:24:46-04:00',
#             'url_domain': 'theverge.com',
#             'url': 'https://www.theverge.com/22985108/best-fitness-tracker',
#             'summary': 'Fitness trackers have come a long way from the simple bands that
# tracked steps a...',
#             'tags': [
#                 'Buying Guide',
#                 'Fitness',
#                 'Fitness Tracker Reviews',
#                 'Reviews',
#                 'Tech',
#                 'Wearable'
#             ],
#             'html_content_length': 801306,
#             'text_content_length': 37263,
#             'summary_length': 359,
#             'summary_text_ratio': 0.009634221613933392,
#             'created_at': '2025-04-28T19:12:45.991702',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.641572',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '321',
#             'is_ai_pred_added': 'False',
#             'doc_id': '11'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Google&#8217;s regular Pixel 10 will reportedly get worse (but more)
# cameras',
#             'author': 'Umar Shakir',
#             'published_date': '2025-04-03T18:22:58-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/news/643123/google-pixel-10-leak-telephoto-camera-downg...',
#             'summary': 'Google’s upcoming base Pixel 10 might come with primary and
# ultrawide cameras th...',
#             'tags': [
#                 'Google',
#                 'Google Pixel',
#                 'Mobile',
#                 'News',
#                 'Tech'
#             ],
#             'html_content_length': 390924,
#             'text_content_length': 2369,
#             'summary_length': 333,
#             'summary_text_ratio': 0.14056563951034193,
#             'created_at': '2025-04-28T19:12:47.694372',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.748250',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '322',
#             'is_ai_pred_added': 'false',
#             'doc_id': '12'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'PSA pauses card grading submissions from outside the US',
#             'author': 'Emma Roth',
#             'published_date': '2025-04-03T18:17:54-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/news/643117/psa-pausing-submissions-outside-us-tariffs',
#             'summary': 'The card grading service PSA will no longer take direct
# submissions from outside...',
#             'tags': [
#                 'Entertainment',
#                 'News',
#                 'Policy',
#                 'Politics'
#             ],
#             'html_content_length': 410492,
#             'text_content_length': 3252,
#             'summary_length': 367,
#             'summary_text_ratio': 0.11285362853628536,
#             'created_at': '2025-04-28T19:12:49.273193',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.832211',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '323',
#             'is_ai_pred_added': 'False',
#             'doc_id': '13'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Trump’s tariffs put the iPhone in a tough spot',
#             'author': 'Allison Johnson',
#             'published_date': '2025-04-03T17:15:26-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/tech/642769/trump-tariff-smartphone-apple-samsung-googl...',
#             'summary': 'The US smartphone market is weird. Most of us buy our phones
# through some combin...',
#             'tags': [
#                 'Apple',
#                 'iPhone',
#                 'Mobile',
#                 'Tech'
#             ],
#             'html_content_length': 420518,
#             'text_content_length': 4443,
#             'summary_length': 409,
#             'summary_text_ratio': 0.0920549178483007,
#             'created_at': '2025-04-28T19:12:50.742958',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.938891',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '324',
#             'is_ai_pred_added': 'False',
#             'doc_id': '14'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Here are the best iPad deals you can get',
#             'author': 'Quentyn Kennemer',
#             'published_date': '2025-04-03T16:50:51-04:00',
#             'url_domain': 'theverge.com',
#             'url': 'https://www.theverge.com/21280354/best-ipad-deals-apple',
#             'summary': 'While the best iPad deals usually land during major sale events
# like Black Frida...',
#             'tags': [
#                 'Apple',
#                 'Deals',
#                 'iPad',
#                 'Tech'
#             ],
#             'html_content_length': 602879,
#             'text_content_length': 13577,
#             'summary_length': 361,
#             'summary_text_ratio': 0.026589084481107757,
#             'created_at': '2025-04-28T19:12:52.555096',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.047850',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '325',
#             'is_ai_pred_added': 'True',
#             'dense_summary_added': 'iPad deals are available across models. The 10th-gen
# iPad (2022) features a USB-...',
#             'length_dense_summary_added': 1391,
#             'core_line_summary_added': 'Significant discounts are available across various
# iPad models, including the la...',
#             'length_core_line_summary_added': 153,
#             'tags_pred_added': [
#                 'Tablets',
#                 'iPad',
#                 'Deals',
#                 'Apple'
#             ],
#             'length_tags_pred_added': 4,
#             'clusters_names_in_order_added': [
#                 'Tablets',
#                 'iPad',
#                 'Deals',
#                 'Apple'
#             ],
#             'dense_vs_core_rouge_eval': 0.08783783783783784,
#             'tag_similarity_eval': 0.8685421248052222,
#             'doc_id': '15'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'TikTok is shutting down its Instagram-like Notes app',
#             'author': 'Emma Roth',
#             'published_date': '2025-04-03T16:43:04-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/news/643063/tiktok-notes-shutting-down-instagram-rival',
#             'summary': 'TikTok is shutting down Notes, its photos-sharing app that rivaled
# Instagram. In...',
#             'tags': [
#                 'Apps',
#                 'Creators',
#                 'News',
#                 'Tech',
#                 'TikTok'
#             ],
#             'html_content_length': 395615,
#             'text_content_length': 2691,
#             'summary_length': 337,
#             'summary_text_ratio': 0.12523225566703827,
#             'created_at': '2025-04-28T19:12:53.968427',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.131581',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '326',
#             'is_ai_pred_added': 'false',
#             'doc_id': '16'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Windows 11 tests taskbar icons that scale up and down like on a
# Mac',
#             'author': 'Umar Shakir',
#             'published_date': '2025-04-03T16:41:38-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/news/643042/windows-11-insider-preview-beta-taskbar-ico...',
#             'summary': 'Microsoft is testing out resizable taskbar icons in Windows 11
# that can shrink a...',
#             'tags': [
#                 'Microsoft',
#                 'News',
#                 'Tech',
#                 'Windows'
#             ],
#             'html_content_length': 394568,
#             'text_content_length': 2510,
#             'summary_length': 320,
#             'summary_text_ratio': 0.12749003984063745,
#             'created_at': '2025-04-28T19:12:55.438479',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.239153',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '327',
#             'is_ai_pred_added': 'false',
#             'doc_id': '17'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'ChatGPT: Everything you need to know about the AI-powered chatbot',
#             'author': 'Kyle Wiggers, Cody Corrall, Alyssa Stringer, Kate Park',
#             'published_date': 'Fri, 04 Apr 2025 09:17:39 +0000',
#             'url_domain': 'techcrunch.com',
#             'url':
# 'https://techcrunch.com/2025/04/04/chatgpt-everything-to-know-about-the-ai-chatbo...',
#             'summary': 'ChatGPT, OpenAI’s text-generating AI chatbot, has taken the world
# by storm since...',
#             'tags': [
#                 'AI',
#                 'OpenAI',
#                 'Generative AI',
#                 'ChatGPT',
#                 'evergreens'
#             ],
#             'html_content_length': 384588,
#             'text_content_length': 84249,
#             'summary_length': 345,
#             'summary_text_ratio': 0.004095004095004095,
#             'created_at': '2025-04-28T19:12:57.486283',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.325022',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '328',
#             'is_ai_pred_added': 'true',
#             'length_dense_summary_added': 14542,
#             'core_line_summary_added': "OpenAI's ChatGPT, experiencing rapid growth and
# feature evolution, faces challen...",
#             'length_core_line_summary_added': 206,
#             'tags_pred_added': [
#                 'LLMs',
#                 'OpenAI',
#                 'ChatGPT',
#                 'AI ethics',
#                 'Copyright',
#                 'AI agents',
#                 'GPT-4o',
#                 'AI safety',
#                 'Data privacy'
#             ],
#             'length_tags_pred_added': 9,
#             'clusters_names_in_order_added': [
#                 'MLLMs',
#                 'OpenAI',
#                 'ChatGPT',
#                 'AI architecture',
#                 'Copyright',
#                 'AI architecture',
#                 'GPT-4o',
#                 'AI architecture',
#                 'Data privacy'
#             ],
#             'dense_vs_core_rouge_eval': 0.01086048454469507,
#             'tag_similarity_eval': 0.5711216108162033,
#             'dense_summary_added_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/replicated_articles...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'doc_id': '18'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'StrictlyVC is heading to London this May',
#             'author': 'TechCrunch Events',
#             'published_date': 'Fri, 04 Apr 2025 07:00:00 +0000',
#             'url_domain': 'techcrunch.com',
#             'url':
# 'https://techcrunch.com/2025/04/04/strictlyvc-is-heading-to-london-this-may/',
#             'summary': 'StrictlyVC is crossing the Atlantic! On 13 May, London will play
# host to an excl...',
#             'tags': [
#                 'TC',
#                 'Startups',
#                 'Venture',
#                 'StrictlyVC',
#                 'StrictlyVC London'
#             ],
#             'html_content_length': 200053,
#             'text_content_length': 1918,
#             'summary_length': 365,
#             'summary_text_ratio': 0.1903023983315954,
#             'created_at': '2025-04-28T19:12:59.278101',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.434339',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '329',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'StrictlyVC will host an exclusive evening for venture
# capitalists and startup le...',
#             'length_dense_summary_added': 522,
#             'core_line_summary_added': "StrictlyVC's exclusive London event on May 13
# offers limited-ticket networking a...",
#             'length_core_line_summary_added': 164,
#             'tags_pred_added': [
#                 'Venture capital',
#                 'Startups',
#                 'Networking',
#                 'Paladin',
#                 'StrictlyVC'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'Venture capital',
#                 'Startups',
#                 'Networking',
#                 'Paladin',
#                 'StrictlyVC'
#             ],
#             'dense_vs_core_rouge_eval': 0.19999999999999998,
#             'tag_similarity_eval': 0.6542530134865714,
#             'doc_id': '19'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Midjourney releases V7, its first new AI image model in nearly a
# year',
#             'author': 'Kyle Wiggers',
#             'published_date': 'Fri, 04 Apr 2025 04:59:47 +0000',
#             'url_domain': 'techcrunch.com',
#             'url':
# 'https://techcrunch.com/2025/04/03/midjourney-releases-its-first-new-ai-image-mod...',
#             'summary': 'Midjourney, one of the first AI-based image generators on the web,
# has released ...',
#             'tags': [
#                 'AI',
#                 'Media & Entertainment',
#                 'AI image generators',
#                 'MidJourney'
#             ],
#             'html_content_length': 211758,
#             'text_content_length': 4500,
#             'summary_length': 316,
#             'summary_text_ratio': 0.07022222222222223,
#             'created_at': '2025-04-28T19:13:01.070657',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.519034',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '330',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'Midjourney released V7, its first new AI image model
# in nearly a year, after Ope...',
#             'length_dense_summary_added': 1000,
#             'core_line_summary_added': "Midjourney's V7, a major AI image model update
# featuring personalized image gene...",
#             'length_core_line_summary_added': 255,
#             'tags_pred_added': [
#                 'Generative AI',
#                 'Midjourney',
#                 'Image generation',
#                 'AI models',
#                 'AI copyright'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'Generative AI',
#                 'Midjourney',
#                 'Image generation',
#                 'AI architecture',
#                 'AI architecture'
#             ],
#             'dense_vs_core_rouge_eval': 0.12307692307692307,
#             'tag_similarity_eval': 0.743336875311058,
#             'doc_id': '20'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Amazon’s new AI agent will shop third-party sites for you',
#             'author': 'Maxwell Zeff',
#             'published_date': 'Fri, 04 Apr 2025 00:35:40 +0000',
#             'url_domain': 'techcrunch.com',
#             'url':
# 'https://techcrunch.com/2025/04/03/amazons-new-ai-agent-will-shop-third-party-sto...',
#             'summary': 'Amazon is starting to test a new AI shopping agent, a feature it
# calls &#8220;Bu...',
#             'tags': [
#                 'AI',
#                 'Commerce',
#                 'agent',
#                 'Amazon',
#                 'online shopping'
#             ],
#             'html_content_length': 202749,
#             'text_content_length': 3506,
#             'summary_length': 336,
#             'summary_text_ratio': 0.09583571021106674,
#             'created_at': '2025-04-28T19:13:02.875763',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.626535',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '331',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'Amazon is testing "Buy for Me," an AI shopping agent
# that purchases products fro...',
#             'length_dense_summary_added': 791,
#             'core_line_summary_added': 'Amazon\'s "Buy for Me" AI agent autonomously
# purchases items from third-party sit...',
#             'length_core_line_summary_added': 184,
#             'tags_pred_added': [
#                 'AI agents',
#                 'shopping',
#                 'Amazon',
#                 'third-party vendors',
#                 'autonomous systems'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'AI architecture',
#                 'shopping',
#                 'Amazon',
# ...
#             'url':
# 'https://www.theguardian.com/technology/2025/apr/03/meta-faces-18bn-lawsuit-over-...',
#             'summary': 'Son of murdered academic calls on Facebook owner to ‘radically
# change how it mod...',
#             'tags': [
#                 'Meta',
#                 'Ethiopia',
#                 'Technology',
#                 'Social media',
#                 'Facebook',
#                 'Internet safety',
#                 'Digital media',
#                 'Social networking',
#                 'Africa',
#                 'World news'
#             ],
#             'html_content_length': 413984,
#             'text_content_length': 3465,
#             'summary_length': 612,
#             'summary_text_ratio': 0.17662337662337663,
#             'created_at': '2025-04-28T19:14:57.346362',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:56.069649',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '437',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'Meta faces a £1.8bn lawsuit in Kenya over claims its
# Facebook algorithms inflame...',
#             'length_dense_summary_added': 941,
#             'core_line_summary_added': 'Meta is facing a £1.8bn lawsuit in Kenya for
# allegedly using Facebook algorithms...',
#             'length_core_line_summary_added': 224,
#             'tags_pred_added': [
#                 'Social media',
#                 'Facebook',
#                 'Meta',
#                 'Ethiopia',
#                 'Tigray',
#                 'Lawsuit',
#                 'Content moderation',
#                 'Hate speech',
#                 'Misinformation',
#                 'Censorship',
#                 'AI ethics'
#             ],
#             'length_tags_pred_added': 11,
#             'clusters_names_in_order_added': [
#                 'Social media',
#                 'Facebook',
#                 'Meta',
#                 'Ethiopia',
#                 'Tigray',
#                 'Lawsuit',
#                 'Content moderation',
#                 'Hate speech',
#                 'Misinformation',
#                 'Censorship',
#                 'AI architecture'
#             ],
#             'dense_vs_core_rouge_eval': 0.18390804597701152,
#             'tag_similarity_eval': 0.5880751857686904,
#             'doc_id': '92'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'EU urged to put human rights centre stage at first central Asia
# summit',
#             'author': 'Jennifer Rankin in Brussels',
#             'published_date': 'Fri, 04 Apr 2025 02:00:39 GMT',
#             'url_domain': 'theguardian.com',
#             'url':
# 'https://www.theguardian.com/world/2025/apr/04/eu-urged-to-put-human-rights-centr...',
#             'summary': 'Bloc to discuss trade, security and energy with leaders of
# Uzbekistan, Kazakhsta...',
#             'tags': [
#                 'European Union',
#                 'South and central Asia',
#                 'Uzbekistan',
#                 'Europe',
#                 'Kazakhstan',
#                 'Kyrgyzstan',
#                 'Tajikistan',
#                 'Turkmenistan',
#                 'European Commission',
#                 'Ursula von der Leyen',
#                 'Human rights',
#                 'World news'
#             ],
#             'html_content_length': 330228,
#             'text_content_length': 6169,
#             'summary_length': 478,
#             'summary_text_ratio': 0.07748419516939536,
#             'created_at': '2025-04-28T19:14:59.012415',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:56.154171',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '438',
#             'is_ai_pred_added': 'false',
#             'doc_id': '93'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'A Matter of Life and Death review – movie classic resuscitated with
# songs',
#             'author': 'Mark Fisher',
#             'published_date': 'Fri, 04 Apr 2025 09:23:33 GMT',
#             'url_domain': 'theguardian.com',
#             'url':
# 'https://www.theguardian.com/stage/2025/apr/04/a-matter-of-life-and-death-review-...',
#             'summary': 'New Vic, Newcastle-under-Lyme Ambitious adaptation of Powell and
# Pressburger’s r...',
#             'tags': [
#                 'Theatre',
#                 'Stage',
#                 'Culture',
#                 'Michael Powell',
#                 'Film'
#             ],
#             'html_content_length': 301818,
#             'text_content_length': 3079,
#             'summary_length': 1045,
#             'summary_text_ratio': 0.3393959077622605,
#             'created_at': '2025-04-28T19:15:00.496143',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:56.350644',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '440',
#             'is_ai_pred_added': 'false',
#             'doc_id': '94'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Paddington in Peru to G20: the seven best films to watch on TV this
# week',
#             'author': 'Simon Wardell',
#             'published_date': 'Fri, 04 Apr 2025 08:00:47 GMT',
#             'url_domain': 'theguardian.com',
#             'url':
# 'https://www.theguardian.com/tv-and-radio/2025/apr/04/paddington-in-peru-to-g20-t...',
#             'summary': 'The marmalade-loving bear returns to his homeland to hunt for his
# missing aunt, ...',
#             'tags': [
#                 'Television & radio',
#                 'Culture',
#                 'Film',
#                 'Paddington'
#             ],
#             'html_content_length': 336226,
#             'text_content_length': 5775,
#             'summary_length': 871,
#             'summary_text_ratio': 0.15082251082251083,
#             'created_at': '2025-04-28T19:15:01.962322',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:56.457409',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '441',
#             'is_ai_pred_added': 'false',
#             'doc_id': '95'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Anthony Horowitz: ‘I’m too nervous to reread The Lord of the Rings –
# it might re...',
#             'author': 'Anthony Horowitz',
#             'published_date': 'Fri, 04 Apr 2025 08:00:48 GMT',
#             'url_domain': 'theguardian.com',
#             'url':
# 'https://www.theguardian.com/books/2025/apr/04/anthony-horowitz-im-too-nervous-to...',
#             'summary': 'The Alex Rider author on being put off Dickens for a decade, why
# he reads poetry...',
#             'tags': [
#                 'Anthony Horowitz',
#                 'Fiction',
#                 'Books',
#                 'Culture',
#                 'Crime fiction'
#             ],
#             'html_content_length': 303271,
#             'text_content_length': 4047,
#             'summary_length': 706,
#             'summary_text_ratio': 0.17445021003212255,
#             'created_at': '2025-04-28T19:15:03.413729',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:56.542739',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '442',
#             'is_ai_pred_added': 'false',
#             'doc_id': '96'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': "Joe Lovano: Homage review | John Fordham's jazz album of the month",
#             'author': 'John Fordham',
#             'published_date': 'Fri, 04 Apr 2025 08:00:49 GMT',
#             'url_domain': 'theguardian.com',
#             'url':
# 'https://www.theguardian.com/music/2025/apr/04/joe-lovano-homage-review',
#             'summary': '(ECM)Backed by pianist Marcin Wasilewski’s group, the US sax elder
# plays freely ...',
#             'tags': [
#                 'Music',
#                 'Jazz',
#                 'Culture'
#             ],
#             'html_content_length': 303419,
#             'text_content_length': 3640,
#             'summary_length': 1454,
#             'summary_text_ratio': 0.3994505494505495,
#             'created_at': '2025-04-28T19:15:04.890231',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:56.650912',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '443',
#             'is_ai_pred_added': 'false',
#             'doc_id': '97'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Delivered to a Predator: Al Fayed’s Fixer review – this startling
# tale urgently ...',
#             'author': 'Jack Seale',
#             'published_date': 'Thu, 03 Apr 2025 22:00:35 GMT',
#             'url_domain': 'theguardian.com',
#             'url':
# 'https://www.theguardian.com/tv-and-radio/2025/apr/03/dispatches-delivered-to-a-p...',
#             'summary': 'Dispatches, presented by Cathy Newman, talks to 16 survivors or
# witnesses of the...',
#             'tags': [
#                 'Television & radio',
#                 'Culture',
#                 'Mohamed Al Fayed',
#                 'Harrods',
#                 '#MeToo movement',
#                 'Women',
#                 'Cathy Newman'
#             ],
#             'html_content_length': 307470,
#             'text_content_length': 5419,
#             'summary_length': 1194,
#             'summary_text_ratio': 0.2203358553238605,
#             'created_at': '2025-04-28T19:15:06.453139',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:56.739156',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '444',
#             'is_ai_pred_added': 'False',
#             'doc_id': '98'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'When the Going Was Good by Graydon Carter review – juicy stories
# from the heydey...',
#             'author': 'Emma Brockes',
#             'published_date': 'Fri, 04 Apr 2025 06:30:45 GMT',
#             'url_domain': 'theguardian.com',
#             'url':
# 'https://www.theguardian.com/books/2025/apr/04/when-the-going-was-good-by-graydon...',
#             'summary': 'From Anna Wintour’s table manners to Oscar party hijinks, the
# former editor of V...',
#             'tags': [
#                 'Autobiography and memoir',
#                 'Graydon Carter',
#                 'Magazines',
#                 'Media',
#                 'Books',
#                 'Culture',
#                 'Condé Nast',
#                 'Journalism books',
#                 'Life and style'
#             ],
#             'html_content_length': 315430,
#             'text_content_length': 7038,
#             'summary_length': 1312,
#             'summary_text_ratio': 0.18641659562375676,
#             'created_at': '2025-04-28T19:15:07.900104',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:56.847715',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '445',
#             'is_ai_pred_added': 'False',
#             'doc_id': '99'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'My latest garden fantasy? An elegant table covered in flower pots',
#             'author': 'Alice Vincent',
#             'published_date': 'Fri, 04 Apr 2025 10:00:49 GMT',
#             'url_domain': 'theguardian.com',
#             'url':
# 'https://www.theguardian.com/lifeandstyle/2025/apr/04/my-latest-garden-fantasy-an...',
#             'summary': 'Stuffing them full of tulips, crocus and muscari will give your
# garden an abunda...',
#             'tags': [
#                 'Gardens',
#                 'Gardening advice',
#                 'Life and style'
#             ],
#             'html_content_length': 296189,
#             'text_content_length': 3429,
#             'summary_length': 730,
#             'summary_text_ratio': 0.21289005540974046,
#             'created_at': '2025-04-28T19:15:09.342330',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:57.338620',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '450',
#             'is_ai_pred_added': 'false',
#             'doc_id': '100'
#         }
#     ]
# }

# %% [markdown]
# ### **3. Article Selection step**
#
# Propose multiple selection based on various unsupervised strategies.

# %%
from ttd.flows.article_selection.steps.select_articles \
    import execute as select_articles_step

select_articles_step(flow)
safe_pretty_print(flow.model_dump())
# Out:
# 2025-05-09 17:32:53,924 - ttd.flows.article_selection.steps.select_articles - INFO - Selecting articles...
# 2025-05-09 17:32:53,939 - ttd.flows.article_selection.steps.select_articles - INFO - ✅ Scoring clusters...
# 2025-05-09 17:32:53,939 - ttd.flows.article_selection.steps.select_articles - INFO - ✅ Scoring articles...
# 2025-05-09 17:32:55,338 - ttd.flows.article_selection.steps.select_articles - INFO - ✅ Step select_articles done in 1.41s
# /Users/mathieucrilout/.miniconda3/envs/ttd/lib/python3.10/site-packages/pydantic/main.py:426: UserWarning: Pydantic serializer warnings:
#   Expected `datetime` but got `str` with value `'Thu, 03 Apr 2025 18:00:00 +0000'` - serialized value may not be as expected
#   Expected `datetime` but got `str` with value `'Thu, 03 Apr 2025 18:00:00 +0000'` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_python(
# {
#     'articles_table': 'replicated_articles',
#     'articles_limit': 20,
#     'date_threshold': 'Thu, 03 Apr 2025 18:00:00 +0000',
#     'cluster_date_threshold': 'Thu, 03 Apr 2025 18:00:00 +0000',
#     'clean_tables': True,
#     'config': {
#         'debug': False,
#         'persist': True,
#         'data_dir': '/Users/mathieucrilout/Repos/train_tune_deploy/data',
#         'db_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/ttd_tinydb.json',
#         'feeds_path': '/Users/mathieucrilout/Repos/train_tune_deploy/data/rss_feeds.txt',
#         'feeds_stealth_path':
# '/Users/mathieucrilout/Repos/train_tune_deployd/data/rss_feeds_stealth.txt',
#         'last_scrape': '2025-04-04T13:22:35.503007',
#         'last_alpha_pipeline': '2025-04-27T08:33:44.289608'
#     },
#     'git_metadata': {
#         'git_commit': '3fcfb77e442259fa1929f110c86e49b051d10b34',
#         'git_branch': 'dev',
#         'git_repo': 'git@github.com:mcrilo33/train-tune-deploy.git'
#     },
#     'parsed_date_threshold': datetime.datetime(2025, 4, 3, 18, 0, tzinfo=tzutc()),
#     'parsed_cluster_date_threshold': datetime.datetime(2025, 4, 3, 18, 0, tzinfo=tzutc()),
#     'min_parsed_date_threshold': datetime.datetime(2025, 4, 3, 18, 0, tzinfo=tzutc()),
#     'metrics': {
#         'step_start_times': {
#             'load_articles': 1746804689.253129,
#             'select_articles': 1746804773.92552
#         },
#         'step_duration': {
#             'load_articles': 0.07477807998657227,
#             'select_articles': 1.4125189781188965
#         }
#     },
#     'errors': {},
#     'prediction_times': {},
#     'token_usage': {},
#     'articles': [
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Trump Tariffs Unleash Shift in Global Economy',
#             'author': 'Pablo Valerio',
#             'published_date': 'Thu, 03 Apr 2025 18:00:00 +0000',
#             'url_domain': 'eetimes.com',
#             'url':
# 'https://www.eetimes.com/trump-tariffs-unleash-shift-in-global-economy/',
#             'summary': 'Trump tariffs, now 54% on Chinese goods, threaten to raise
# electronics prices. C...',
#             'tags': [
#                 'News',
#                 'Supply Chain & Distribution',
#                 'Supply Chain Analysis',
#                 'Global Trade',
#                 'supply chain disruptions',
#                 'Tariffs',
#                 'Trump administration'
#             ],
#             'html_content_length': 358447,
#             'text_content_length': 9980,
#             'summary_length': 225,
#             'summary_text_ratio': 0.022545090180360723,
#             'created_at': '2025-04-28T19:12:28.351109',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:13.940886',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '1',
#             'is_ai_pred_added': 'false',
#             'doc_id': '1'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Meet Open-Qwen2VL: A Fully Open and Compute-Efficient Multimodal
# Large Language ...',
#             'author': 'Asif Razzaq',
#             'published_date': 'Fri, 04 Apr 2025 05:15:52 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/meet-open-qwen2vl-a-fully-open-and-compu...',
#             'summary': 'Multimodal Large Language Models (MLLMs) have advanced the
# integration of visual...',
#             'tags': [
#                 'AI Paper Summary',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Language Model',
#                 'Large Language Model',
#                 'Machine Learning',
#                 'New Releases',
#                 'Open Source',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 370768,
#             'text_content_length': 5752,
#             'summary_length': 539,
#             'summary_text_ratio': 0.09370653685674547,
#             'created_at': '2025-04-28T19:12:30.322581',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.488251',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '309',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'Open-Qwen2VL, a 2-billion parameter Multimodal Large
# Language Model (MLLM) devel...',
#             'length_dense_summary_added': 1313,
#             'core_line_summary_added': 'Open-Qwen2VL offers an efficient, open-source MLLM
# alternative, achieving compet...',
#             'length_core_line_summary_added': 190,
#             'tags_pred_added': [
#                 'MLLMs',
#                 'multimodal learning',
#                 'open source',
#                 'computer vision'
#             ],
#             'length_tags_pred_added': 4,
#             'clusters_names_in_order_added': [
#                 'MLLMs',
#                 'multimodal learning',
#                 'open source',
#                 'computer vision'
#             ],
#             'dense_vs_core_rouge_eval': 0.07048458149779736,
#             'tag_similarity_eval': 0.5261094195634279,
#             'doc_id': '2',
#             'clusters_score': 1.25
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Researchers from Dataocean AI and Tsinghua University Introduces
# Dolphin: A Mult...',
#             'author': 'Asif Razzaq',
#             'published_date': 'Fri, 04 Apr 2025 01:25:27 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/researchers-from-dataocean-ai-and-tsingh...',
#             'summary': 'Automatic speech recognition (ASR) technologies have advanced
# significantly, yet...',
#             'tags': [
#                 'AI Paper Summary',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Generative AI',
#                 'Language Model',
#                 'Large Language Model',
#                 'Machine Learning',
#                 'New Releases',
#                 'Open Source',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 375396,
#             'text_content_length': 5255,
#             'summary_length': 690,
#             'summary_text_ratio': 0.1313035204567079,
#             'created_at': '2025-04-28T19:12:32.032592',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.572481',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '310',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'Dataocean AI and Tsinghua University introduced
# Dolphin, a multilingual ASR mode...',
#             'length_dense_summary_added': 1108,
#             'core_line_summary_added': 'Dolphin, a new multilingual ASR model developed by
# Dataocean AI and Tsinghua Uni...',
#             'length_core_line_summary_added': 223,
#             'tags_pred_added': [
#                 'Automatic speech recognition',
#                 'Multilingual models',
#                 'Eastern languages',
#                 'Dialects'
#             ],
#             'length_tags_pred_added': 4,
#             'clusters_names_in_order_added': [
#                 'Automatic speech recognition',
#                 'Multilingual models',
#                 'Eastern languages',
#                 'Dialects'
#             ],
#             'dense_vs_core_rouge_eval': 0.16494845360824742,
#             'tag_similarity_eval': 0.4227679017903087,
#             'doc_id': '3',
#             'clusters_score': 0
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'This AI Paper Introduces FASTCURL: A Curriculum Reinforcement
# Learning Framework...',
#             'author': 'Nikhil',
#             'published_date': 'Fri, 04 Apr 2025 00:33:47 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/this-ai-paper-introduces-fastcurl-a-curr...',
#             'summary': 'Large language models have transformed how machines comprehend and
# generate text...',
#             'tags': [
#                 'AI Paper Summary',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Language Model',
#                 'Large Language Model',
#                 'Machine Learning',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 358212,
#             'text_content_length': 5442,
#             'summary_length': 626,
#             'summary_text_ratio': 0.11503123851525175,
#             'created_at': '2025-04-28T19:12:33.837998',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.680091',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '311',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'Tencent researchers introduced FASTCURL, a curriculum
# reinforcement learning fra...',
#             'length_dense_summary_added': 1078,
#             'core_line_summary_added': 'FASTCURL offers a computationally efficient
# curriculum reinforcement learning fr...',
#             'length_core_line_summary_added': 228,
#             'tags_pred_added': [
#                 'Reinforcement learning',
#                 'Curriculum learning',
#                 'Reasoning',
#                 'Model training',
#                 'Benchmarking'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'Reinforcement learning',
#                 'Curriculum learning',
#                 'Reasoning',
#                 'Model training',
#                 'Benchmarking'
#             ],
#             'dense_vs_core_rouge_eval': 0.13684210526315788,
#             'tag_similarity_eval': 0.39229967376082875,
#             'doc_id': '4',
#             'clusters_score': 0
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Introduction to MCP: The Ultimate Guide to Model Context Protocol
# for AI Assista...',
#             'author': 'Asif Razzaq',
#             'published_date': 'Thu, 03 Apr 2025 20:20:36 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/introduction-to-mcp-the-ultimate-guide-t...',
#             'summary': 'The Model Context Protocol (MCP) is an open standard (open-sourced
# by Anthropic)...',
#             'tags': [
#                 'Agentic AI',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Language Model',
#                 'Large Language Model',
#                 'Machine Learning',
#                 'Model Context Protocol',
#                 'New Releases',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 383286,
#             'text_content_length': 14928,
#             'summary_length': 457,
#             'summary_text_ratio': 0.030613612004287246,
#             'created_at': '2025-04-28T19:12:35.821819',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.765198',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '312',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'The Model Context Protocol (MCP) is an open standard
# for connecting AI assistant...',
#             'length_dense_summary_added': 1512,
#             'core_line_summary_added': "The Model Context Protocol (MCP) standardizes AI
# assistants' access to external ...",
#             'length_core_line_summary_added': 189,
#             'tags_pred_added': [
#                 'LLMs',
#                 'RAG',
#                 'AI architecture',
#                 'open standards',
#                 'data integration'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'MLLMs',
#                 'RAG',
#                 'AI architecture',
#                 'open source',
#                 'data integration'
#             ],
#             'dense_vs_core_rouge_eval': 0.145748987854251,
#             'tag_similarity_eval': 0.4115448201247924,
#             'doc_id': '5',
#             'clusters_score': 1.375
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'UB-Mesh: A Cost-Efficient, Scalable Network Architecture for
# Large-Scale LLM Tra...',
#             'author': 'Sana Hassan',
#             'published_date': 'Thu, 03 Apr 2025 20:08:33 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/ub-mesh-a-cost-efficient-scalable-networ...',
#             'summary': 'As LLMs scale, their computational and bandwidth demands increase
# significantly,...',
#             'tags': [
#                 'AI Infrastructure',
#                 'AI Paper Summary',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Language Model',
#                 'Large Language Model',
#                 'Machine Learning',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 355087,
#             'text_content_length': 6079,
#             'summary_length': 545,
#             'summary_text_ratio': 0.08965290343806546,
#             'created_at': '2025-04-28T19:12:37.592010',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.872897',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '313',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'LLM training demands scalable, cost-effective, and
# fault-tolerant AI infrastruct...',
#             'length_dense_summary_added': 1287,
#             'core_line_summary_added': "Huawei's UB-Mesh network architecture offers a
# cost-effective and fault-tolerant...",
#             'length_core_line_summary_added': 222,
#             'tags_pred_added': [
#                 'LLMs',
#                 'distributed computing',
#                 'network architecture',
#                 'Huawei',
#                 'fault tolerance'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'MLLMs',
#                 'distributed computing',
#                 'network architecture',
#                 'Huawei',
#                 'fault tolerance'
#             ],
#             'dense_vs_core_rouge_eval': 0.15454545454545454,
#             'tag_similarity_eval': 0.3334022518968497,
#             'doc_id': '6',
#             'clusters_score': 1.0
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'This AI Paper Unveils a Reverse-Engineered Simulator Model for
# Modern NVIDIA GPU...',
#             'author': 'Nikhil',
#             'published_date': 'Thu, 03 Apr 2025 19:39:21 +0000',
#             'url_domain': 'marktechpost.com',
#             'url':
# 'https://www.marktechpost.com/2025/04/03/this-ai-paper-unveils-a-reverse-engineer...',
#             'summary': 'GPUs are widely recognized for their efficiency in handling
# high-performance com...',
#             'tags': [
#                 'AI Infrastructure',
#                 'AI Paper Summary',
#                 'AI Shorts',
#                 'Applications',
#                 'Artificial Intelligence',
#                 'Editors Pick',
#                 'Language Model',
#                 'Large Language Model',
#                 'Staff',
#                 'Tech News',
#                 'Technology'
#             ],
#             'html_content_length': 358548,
#             'text_content_length': 5432,
#             'summary_length': 623,
#             'summary_text_ratio': 0.11469072164948453,
#             'created_at': '2025-04-28T19:12:39.549329',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:43.959640',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '314',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'A Universitat Politècnica de Catalunya team
# reverse-engineered modern NVIDIA GPU...',
#             'length_dense_summary_added': 1091,
#             'core_line_summary_added': 'Researchers developed a more accurate NVIDIA GPU
# simulation model, significantly...',
#             'length_core_line_summary_added': 195,
#             'tags_pred_added': [
#                 'GPU',
#                 'microarchitecture',
#                 'simulation',
#                 'performance modeling',
#                 'NVIDIA'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'GPU',
#                 'microarchitecture',
#                 'simulation',
#                 'performance modeling',
#                 'NVIDIA'
#             ],
#             'dense_vs_core_rouge_eval': 0.14054054054054055,
#             'tag_similarity_eval': 0.3600589270323685,
#             'doc_id': '7',
#             'clusters_score': 0.0625
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Superman’s latest trailer introduces his team of robot assistants',
#             'author': 'Charles Pulliam-Moore',
#             'published_date': '2025-04-03T21:13:49-04:00',
#             'url_domain': 'theverge.com',
#             'url': 'https://www.theverge.com/news/643100/superman-robots-trailer',
#             'summary': 'Though Superman is clearly going to get the living daylights beat
# out of him at ...',
#             'tags': [
#                 'Comics',
#                 'DC Comics',
#                 'Entertainment',
#                 'Film',
#                 'News',
#                 'Trailers'
#             ],
#             'html_content_length': 376544,
#             'text_content_length': 2670,
#             'summary_length': 331,
#             'summary_text_ratio': 0.12397003745318352,
#             'created_at': '2025-04-28T19:12:40.978978',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.253656',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '317',
#             'is_ai_pred_added': 'false',
#             'doc_id': '8'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Steve Jackson Games says tariffs are a ‘seismic shift’ for board
# games',
#             'author': 'Jay Peters',
#             'published_date': '2025-04-03T19:56:34-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/news/643173/trump-tariffs-steve-jackson-board-game-indu...',
#             'summary': 'The CEO of Steve Jackson Games, which makes board games and card
# games, says tha...',
#             'tags': [
#                 'Entertainment',
#                 'Gaming',
#                 'News'
#             ],
#             'html_content_length': 416012,
#             'text_content_length': 4141,
#             'summary_length': 312,
#             'summary_text_ratio': 0.07534411977783144,
#             'created_at': '2025-04-28T19:12:42.672075',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.446946',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '319',
#             'is_ai_pred_added': 'false',
#             'doc_id': '9'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Trump&#8217;s tariffs mean you&#8217;ll pay more for all gadgets',
#             'author': 'Victoria Song',
#             'published_date': '2025-04-03T18:47:51-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/tech/643041/trump-tariff-consumer-electronics-gadgets-s...',
#             'summary': 'If you were wondering how President Trump&#226;&#x20ac;&#x2122;s
# tariffs may imp...',
#             'tags': [
#                 'Gadgets',
#                 'Policy',
#                 'Tech'
#             ],
#             'html_content_length': 440752,
#             'text_content_length': 7142,
#             'summary_length': 473,
#             'summary_text_ratio': 0.06622794735368244,
#             'created_at': '2025-04-28T19:12:44.169013',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.555104',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '320',
#             'is_ai_pred_added': 'False',
#             'doc_id': '10'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'The best fitness trackers to buy right now',
#             'author': 'Victoria Song',
#             'published_date': '2025-04-03T18:24:46-04:00',
#             'url_domain': 'theverge.com',
#             'url': 'https://www.theverge.com/22985108/best-fitness-tracker',
#             'summary': 'Fitness trackers have come a long way from the simple bands that
# tracked steps a...',
#             'tags': [
#                 'Buying Guide',
#                 'Fitness',
#                 'Fitness Tracker Reviews',
#                 'Reviews',
#                 'Tech',
#                 'Wearable'
#             ],
#             'html_content_length': 801306,
#             'text_content_length': 37263,
#             'summary_length': 359,
#             'summary_text_ratio': 0.009634221613933392,
#             'created_at': '2025-04-28T19:12:45.991702',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.641572',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '321',
#             'is_ai_pred_added': 'False',
#             'doc_id': '11'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Google&#8217;s regular Pixel 10 will reportedly get worse (but more)
# cameras',
#             'author': 'Umar Shakir',
#             'published_date': '2025-04-03T18:22:58-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/news/643123/google-pixel-10-leak-telephoto-camera-downg...',
#             'summary': 'Google’s upcoming base Pixel 10 might come with primary and
# ultrawide cameras th...',
#             'tags': [
#                 'Google',
#                 'Google Pixel',
#                 'Mobile',
#                 'News',
#                 'Tech'
#             ],
#             'html_content_length': 390924,
#             'text_content_length': 2369,
#             'summary_length': 333,
#             'summary_text_ratio': 0.14056563951034193,
#             'created_at': '2025-04-28T19:12:47.694372',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.748250',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '322',
#             'is_ai_pred_added': 'false',
#             'doc_id': '12'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'PSA pauses card grading submissions from outside the US',
#             'author': 'Emma Roth',
#             'published_date': '2025-04-03T18:17:54-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/news/643117/psa-pausing-submissions-outside-us-tariffs',
#             'summary': 'The card grading service PSA will no longer take direct
# submissions from outside...',
#             'tags': [
#                 'Entertainment',
#                 'News',
#                 'Policy',
#                 'Politics'
#             ],
#             'html_content_length': 410492,
#             'text_content_length': 3252,
#             'summary_length': 367,
#             'summary_text_ratio': 0.11285362853628536,
#             'created_at': '2025-04-28T19:12:49.273193',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.832211',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '323',
#             'is_ai_pred_added': 'False',
#             'doc_id': '13'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Trump’s tariffs put the iPhone in a tough spot',
#             'author': 'Allison Johnson',
#             'published_date': '2025-04-03T17:15:26-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/tech/642769/trump-tariff-smartphone-apple-samsung-googl...',
#             'summary': 'The US smartphone market is weird. Most of us buy our phones
# through some combin...',
#             'tags': [
#                 'Apple',
#                 'iPhone',
#                 'Mobile',
#                 'Tech'
#             ],
#             'html_content_length': 420518,
#             'text_content_length': 4443,
#             'summary_length': 409,
#             'summary_text_ratio': 0.0920549178483007,
#             'created_at': '2025-04-28T19:12:50.742958',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:44.938891',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '324',
#             'is_ai_pred_added': 'False',
#             'doc_id': '14'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Here are the best iPad deals you can get',
#             'author': 'Quentyn Kennemer',
#             'published_date': '2025-04-03T16:50:51-04:00',
#             'url_domain': 'theverge.com',
#             'url': 'https://www.theverge.com/21280354/best-ipad-deals-apple',
#             'summary': 'While the best iPad deals usually land during major sale events
# like Black Frida...',
#             'tags': [
#                 'Apple',
#                 'Deals',
#                 'iPad',
#                 'Tech'
#             ],
#             'html_content_length': 602879,
#             'text_content_length': 13577,
#             'summary_length': 361,
#             'summary_text_ratio': 0.026589084481107757,
#             'created_at': '2025-04-28T19:12:52.555096',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.047850',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '325',
#             'is_ai_pred_added': 'True',
#             'dense_summary_added': 'iPad deals are available across models. The 10th-gen
# iPad (2022) features a USB-...',
#             'length_dense_summary_added': 1391,
#             'core_line_summary_added': 'Significant discounts are available across various
# iPad models, including the la...',
#             'length_core_line_summary_added': 153,
#             'tags_pred_added': [
#                 'Tablets',
#                 'iPad',
#                 'Deals',
#                 'Apple'
#             ],
#             'length_tags_pred_added': 4,
#             'clusters_names_in_order_added': [
#                 'Tablets',
#                 'iPad',
#                 'Deals',
#                 'Apple'
#             ],
#             'dense_vs_core_rouge_eval': 0.08783783783783784,
#             'tag_similarity_eval': 0.8685421248052222,
#             'doc_id': '15',
#             'clusters_score': 0
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'TikTok is shutting down its Instagram-like Notes app',
#             'author': 'Emma Roth',
#             'published_date': '2025-04-03T16:43:04-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/news/643063/tiktok-notes-shutting-down-instagram-rival',
#             'summary': 'TikTok is shutting down Notes, its photos-sharing app that rivaled
# Instagram. In...',
#             'tags': [
#                 'Apps',
#                 'Creators',
#                 'News',
#                 'Tech',
#                 'TikTok'
#             ],
#             'html_content_length': 395615,
#             'text_content_length': 2691,
#             'summary_length': 337,
#             'summary_text_ratio': 0.12523225566703827,
#             'created_at': '2025-04-28T19:12:53.968427',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.131581',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '326',
#             'is_ai_pred_added': 'false',
#             'doc_id': '16'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Windows 11 tests taskbar icons that scale up and down like on a
# Mac',
#             'author': 'Umar Shakir',
#             'published_date': '2025-04-03T16:41:38-04:00',
#             'url_domain': 'theverge.com',
#             'url':
# 'https://www.theverge.com/news/643042/windows-11-insider-preview-beta-taskbar-ico...',
#             'summary': 'Microsoft is testing out resizable taskbar icons in Windows 11
# that can shrink a...',
#             'tags': [
#                 'Microsoft',
#                 'News',
#                 'Tech',
#                 'Windows'
#             ],
#             'html_content_length': 394568,
#             'text_content_length': 2510,
#             'summary_length': 320,
#             'summary_text_ratio': 0.12749003984063745,
#             'created_at': '2025-04-28T19:12:55.438479',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.239153',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '327',
#             'is_ai_pred_added': 'false',
#             'doc_id': '17'
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'ChatGPT: Everything you need to know about the AI-powered chatbot',
#             'author': 'Kyle Wiggers, Cody Corrall, Alyssa Stringer, Kate Park',
#             'published_date': 'Fri, 04 Apr 2025 09:17:39 +0000',
#             'url_domain': 'techcrunch.com',
#             'url':
# 'https://techcrunch.com/2025/04/04/chatgpt-everything-to-know-about-the-ai-chatbo...',
#             'summary': 'ChatGPT, OpenAI’s text-generating AI chatbot, has taken the world
# by storm since...',
#             'tags': [
#                 'AI',
#                 'OpenAI',
#                 'Generative AI',
#                 'ChatGPT',
#                 'evergreens'
#             ],
#             'html_content_length': 384588,
#             'text_content_length': 84249,
#             'summary_length': 345,
#             'summary_text_ratio': 0.004095004095004095,
#             'created_at': '2025-04-28T19:12:57.486283',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.325022',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '328',
#             'is_ai_pred_added': 'true',
#             'length_dense_summary_added': 14542,
#             'core_line_summary_added': "OpenAI's ChatGPT, experiencing rapid growth and
# feature evolution, faces challen...",
#             'length_core_line_summary_added': 206,
#             'tags_pred_added': [
#                 'LLMs',
#                 'OpenAI',
#                 'ChatGPT',
#                 'AI ethics',
#                 'Copyright',
#                 'AI agents',
#                 'GPT-4o',
#                 'AI safety',
#                 'Data privacy'
#             ],
#             'length_tags_pred_added': 9,
#             'clusters_names_in_order_added': [
#                 'MLLMs',
#                 'OpenAI',
#                 'ChatGPT',
#                 'AI architecture',
#                 'Copyright',
#                 'AI architecture',
#                 'GPT-4o',
#                 'AI architecture',
#                 'Data privacy'
#             ],
#             'dense_vs_core_rouge_eval': 0.01086048454469507,
#             'tag_similarity_eval': 0.5711216108162033,
#             'dense_summary_added_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/replicated_articles...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'doc_id': '18',
#             'clusters_score': 1.6640625
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'StrictlyVC is heading to London this May',
#             'author': 'TechCrunch Events',
#             'published_date': 'Fri, 04 Apr 2025 07:00:00 +0000',
#             'url_domain': 'techcrunch.com',
#             'url':
# 'https://techcrunch.com/2025/04/04/strictlyvc-is-heading-to-london-this-may/',
#             'summary': 'StrictlyVC is crossing the Atlantic! On 13 May, London will play
# host to an excl...',
#             'tags': [
#                 'TC',
#                 'Startups',
#                 'Venture',
#                 'StrictlyVC',
#                 'StrictlyVC London'
#             ],
#             'html_content_length': 200053,
#             'text_content_length': 1918,
#             'summary_length': 365,
#             'summary_text_ratio': 0.1903023983315954,
#             'created_at': '2025-04-28T19:12:59.278101',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.434339',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '329',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'StrictlyVC will host an exclusive evening for venture
# capitalists and startup le...',
#             'length_dense_summary_added': 522,
#             'core_line_summary_added': "StrictlyVC's exclusive London event on May 13
# offers limited-ticket networking a...",
#             'length_core_line_summary_added': 164,
#             'tags_pred_added': [
#                 'Venture capital',
#                 'Startups',
#                 'Networking',
#                 'Paladin',
#                 'StrictlyVC'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'Venture capital',
#                 'Startups',
#                 'Networking',
#                 'Paladin',
#                 'StrictlyVC'
#             ],
#             'dense_vs_core_rouge_eval': 0.19999999999999998,
#             'tag_similarity_eval': 0.6542530134865714,
#             'doc_id': '19',
#             'clusters_score': 0.5
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Midjourney releases V7, its first new AI image model in nearly a
# year',
#             'author': 'Kyle Wiggers',
#             'published_date': 'Fri, 04 Apr 2025 04:59:47 +0000',
#             'url_domain': 'techcrunch.com',
#             'url':
# 'https://techcrunch.com/2025/04/03/midjourney-releases-its-first-new-ai-image-mod...',
#             'summary': 'Midjourney, one of the first AI-based image generators on the web,
# has released ...',
#             'tags': [
#                 'AI',
#                 'Media & Entertainment',
#                 'AI image generators',
#                 'MidJourney'
#             ],
#             'html_content_length': 211758,
#             'text_content_length': 4500,
#             'summary_length': 316,
#             'summary_text_ratio': 0.07022222222222223,
#             'created_at': '2025-04-28T19:13:01.070657',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.519034',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '330',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'Midjourney released V7, its first new AI image model
# in nearly a year, after Ope...',
#             'length_dense_summary_added': 1000,
#             'core_line_summary_added': "Midjourney's V7, a major AI image model update
# featuring personalized image gene...",
#             'length_core_line_summary_added': 255,
#             'tags_pred_added': [
#                 'Generative AI',
#                 'Midjourney',
#                 'Image generation',
#                 'AI models',
#                 'AI copyright'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'Generative AI',
#                 'Midjourney',
#                 'Image generation',
#                 'AI architecture',
#                 'AI architecture'
#             ],
#             'dense_vs_core_rouge_eval': 0.12307692307692307,
#             'tag_similarity_eval': 0.743336875311058,
#             'doc_id': '20',
#             'clusters_score': 1.1875
#         },
#         {
#             'table_name': 'replicated_articles',
#             'title': 'Amazon’s new AI agent will shop third-party sites for you',
#             'author': 'Maxwell Zeff',
#             'published_date': 'Fri, 04 Apr 2025 00:35:40 +0000',
#             'url_domain': 'techcrunch.com',
#             'url':
# 'https://techcrunch.com/2025/04/03/amazons-new-ai-agent-will-shop-third-party-sto...',
#             'summary': 'Amazon is starting to test a new AI shopping agent, a feature it
# calls &#8220;Bu...',
#             'tags': [
#                 'AI',
#                 'Commerce',
#                 'agent',
#                 'Amazon',
#                 'online shopping'
#             ],
#             'html_content_length': 202749,
#             'text_content_length': 3506,
#             'summary_length': 336,
#             'summary_text_ratio': 0.09583571021106674,
#             'created_at': '2025-04-28T19:13:02.875763',
#             'execution_time': 0,
#             'last_updated': '2025-04-28T15:04:45.626535',
#             'text_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'html_content_artifact': {
#                 'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                 'format': 'text',
#                 'encoding': 'utf-8'
#             },
#             'original_doc_id': '331',
#             'is_ai_pred_added': 'true',
#             'dense_summary_added': 'Amazon is testing "Buy for Me," an AI shopping agent
# that purchases products fro...',
#             'length_dense_summary_added': 791,
#             'core_line_summary_added': 'Amazon\'s "Buy for Me" AI agent autonomously
# purchases items from third-party sit...',
#             'length_core_line_summary_added': 184,
#             'tags_pred_added': [
#                 'AI agents',
#                 'shopping',
#                 'Amazon',
#                 'third-party vendors',
#                 'autonomous systems'
#             ],
#             'length_tags_pred_added': 5,
#             'clusters_names_in_order_added': [
#                 'AI architecture',
#                 'shopping',
#                 'Amazon',
#                 'third-party vendors',
# ...
# GPU simulation model, significantly...',
#                 'length_core_line_summary_added': 195,
#                 'tags_pred_added': [
#                     'GPU',
#                     'microarchitecture',
#                     'simulation',
#                     'performance modeling',
#                     'NVIDIA'
#                 ],
#                 'length_tags_pred_added': 5,
#                 'clusters_names_in_order_added': [
#                     'GPU',
#                     'microarchitecture',
#                     'simulation',
#                     'performance modeling',
#                     'NVIDIA'
#                 ],
#                 'dense_vs_core_rouge_eval': 0.14054054054054055,
#                 'tag_similarity_eval': 0.3600589270323685,
#                 'doc_id': '7',
#                 'clusters_score': 0.0625
#             },
#             {
#                 'table_name': 'replicated_articles',
#                 'title': 'Meta faces £1.8bn lawsuit over claims it inflamed violence in
# Ethiopia',
#                 'author': 'Dan Milmo Global technology editor',
#                 'published_date': 'Thu, 03 Apr 2025 18:01:39 GMT',
#                 'url_domain': 'theguardian.com',
#                 'url':
# 'https://www.theguardian.com/technology/2025/apr/03/meta-faces-18bn-lawsuit-over-...',
#                 'summary': 'Son of murdered academic calls on Facebook owner to ‘radically
# change how it mod...',
#                 'tags': [
#                     'Meta',
#                     'Ethiopia',
#                     'Technology',
#                     'Social media',
#                     'Facebook',
#                     'Internet safety',
#                     'Digital media',
#                     'Social networking',
#                     'Africa',
#                     'World news'
#                 ],
#                 'html_content_length': 413984,
#                 'text_content_length': 3465,
#                 'summary_length': 612,
#                 'summary_text_ratio': 0.17662337662337663,
#                 'created_at': '2025-04-28T19:14:57.346362',
#                 'execution_time': 0,
#                 'last_updated': '2025-04-28T15:04:56.069649',
#                 'text_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'html_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'original_doc_id': '437',
#                 'is_ai_pred_added': 'true',
#                 'dense_summary_added': 'Meta faces a £1.8bn lawsuit in Kenya over claims
# its Facebook algorithms inflame...',
#                 'length_dense_summary_added': 941,
#                 'core_line_summary_added': 'Meta is facing a £1.8bn lawsuit in Kenya for
# allegedly using Facebook algorithms...',
#                 'length_core_line_summary_added': 224,
#                 'tags_pred_added': [
#                     'Social media',
#                     'Facebook',
#                     'Meta',
#                     'Ethiopia',
#                     'Tigray',
#                     'Lawsuit',
#                     'Content moderation',
#                     'Hate speech',
#                     'Misinformation',
#                     'Censorship',
#                     'AI ethics'
#                 ],
#                 'length_tags_pred_added': 11,
#                 'clusters_names_in_order_added': [
#                     'Social media',
#                     'Facebook',
#                     'Meta',
#                     'Ethiopia',
#                     'Tigray',
#                     'Lawsuit',
#                     'Content moderation',
#                     'Hate speech',
#                     'Misinformation',
#                     'Censorship',
#                     'AI architecture'
#                 ],
#                 'dense_vs_core_rouge_eval': 0.18390804597701152,
#                 'tag_similarity_eval': 0.5880751857686904,
#                 'doc_id': '92',
#                 'clusters_score': 0.0009765625
#             },
#             {
#                 'table_name': 'replicated_articles',
#                 'title': 'Researchers from Dataocean AI and Tsinghua University Introduces
# Dolphin: A Mult...',
#                 'author': 'Asif Razzaq',
#                 'published_date': 'Fri, 04 Apr 2025 01:25:27 +0000',
#                 'url_domain': 'marktechpost.com',
#                 'url':
# 'https://www.marktechpost.com/2025/04/03/researchers-from-dataocean-ai-and-tsingh...',
#                 'summary': 'Automatic speech recognition (ASR) technologies have advanced
# significantly, yet...',
#                 'tags': [
#                     'AI Paper Summary',
#                     'AI Shorts',
#                     'Applications',
#                     'Artificial Intelligence',
#                     'Editors Pick',
#                     'Generative AI',
#                     'Language Model',
#                     'Large Language Model',
#                     'Machine Learning',
#                     'New Releases',
#                     'Open Source',
#                     'Staff',
#                     'Tech News',
#                     'Technology'
#                 ],
#                 'html_content_length': 375396,
#                 'text_content_length': 5255,
#                 'summary_length': 690,
#                 'summary_text_ratio': 0.1313035204567079,
#                 'created_at': '2025-04-28T19:12:32.032592',
#                 'execution_time': 0,
#                 'last_updated': '2025-04-28T15:04:43.572481',
#                 'text_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'html_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'original_doc_id': '310',
#                 'is_ai_pred_added': 'true',
#                 'dense_summary_added': 'Dataocean AI and Tsinghua University introduced
# Dolphin, a multilingual ASR mode...',
#                 'length_dense_summary_added': 1108,
#                 'core_line_summary_added': 'Dolphin, a new multilingual ASR model
# developed by Dataocean AI and Tsinghua Uni...',
#                 'length_core_line_summary_added': 223,
#                 'tags_pred_added': [
#                     'Automatic speech recognition',
#                     'Multilingual models',
#                     'Eastern languages',
#                     'Dialects'
#                 ],
#                 'length_tags_pred_added': 4,
#                 'clusters_names_in_order_added': [
#                     'Automatic speech recognition',
#                     'Multilingual models',
#                     'Eastern languages',
#                     'Dialects'
#                 ],
#                 'dense_vs_core_rouge_eval': 0.16494845360824742,
#                 'tag_similarity_eval': 0.4227679017903087,
#                 'doc_id': '3',
#                 'clusters_score': 0
#             },
#             {
#                 'table_name': 'replicated_articles',
#                 'title': 'This AI Paper Introduces FASTCURL: A Curriculum Reinforcement
# Learning Framework...',
#                 'author': 'Nikhil',
#                 'published_date': 'Fri, 04 Apr 2025 00:33:47 +0000',
#                 'url_domain': 'marktechpost.com',
#                 'url':
# 'https://www.marktechpost.com/2025/04/03/this-ai-paper-introduces-fastcurl-a-curr...',
#                 'summary': 'Large language models have transformed how machines comprehend
# and generate text...',
#                 'tags': [
#                     'AI Paper Summary',
#                     'AI Shorts',
#                     'Applications',
#                     'Artificial Intelligence',
#                     'Editors Pick',
#                     'Language Model',
#                     'Large Language Model',
#                     'Machine Learning',
#                     'Staff',
#                     'Tech News',
#                     'Technology'
#                 ],
#                 'html_content_length': 358212,
#                 'text_content_length': 5442,
#                 'summary_length': 626,
#                 'summary_text_ratio': 0.11503123851525175,
#                 'created_at': '2025-04-28T19:12:33.837998',
#                 'execution_time': 0,
#                 'last_updated': '2025-04-28T15:04:43.680091',
#                 'text_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'html_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'original_doc_id': '311',
#                 'is_ai_pred_added': 'true',
#                 'dense_summary_added': 'Tencent researchers introduced FASTCURL, a
# curriculum reinforcement learning fra...',
#                 'length_dense_summary_added': 1078,
#                 'core_line_summary_added': 'FASTCURL offers a computationally efficient
# curriculum reinforcement learning fr...',
#                 'length_core_line_summary_added': 228,
#                 'tags_pred_added': [
#                     'Reinforcement learning',
#                     'Curriculum learning',
#                     'Reasoning',
#                     'Model training',
#                     'Benchmarking'
#                 ],
#                 'length_tags_pred_added': 5,
#                 'clusters_names_in_order_added': [
#                     'Reinforcement learning',
#                     'Curriculum learning',
#                     'Reasoning',
#                     'Model training',
#                     'Benchmarking'
#                 ],
#                 'dense_vs_core_rouge_eval': 0.13684210526315788,
#                 'tag_similarity_eval': 0.39229967376082875,
#                 'doc_id': '4',
#                 'clusters_score': 0
#             },
#             {
#                 'table_name': 'replicated_articles',
#                 'title': 'Here are the best iPad deals you can get',
#                 'author': 'Quentyn Kennemer',
#                 'published_date': '2025-04-03T16:50:51-04:00',
#                 'url_domain': 'theverge.com',
#                 'url': 'https://www.theverge.com/21280354/best-ipad-deals-apple',
#                 'summary': 'While the best iPad deals usually land during major sale
# events like Black Frida...',
#                 'tags': [
#                     'Apple',
#                     'Deals',
#                     'iPad',
#                     'Tech'
#                 ],
#                 'html_content_length': 602879,
#                 'text_content_length': 13577,
#                 'summary_length': 361,
#                 'summary_text_ratio': 0.026589084481107757,
#                 'created_at': '2025-04-28T19:12:52.555096',
#                 'execution_time': 0,
#                 'last_updated': '2025-04-28T15:04:45.047850',
#                 'text_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'html_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'original_doc_id': '325',
#                 'is_ai_pred_added': 'True',
#                 'dense_summary_added': 'iPad deals are available across models. The
# 10th-gen iPad (2022) features a USB-...',
#                 'length_dense_summary_added': 1391,
#                 'core_line_summary_added': 'Significant discounts are available across
# various iPad models, including the la...',
#                 'length_core_line_summary_added': 153,
#                 'tags_pred_added': [
#                     'Tablets',
#                     'iPad',
#                     'Deals',
#                     'Apple'
#                 ],
#                 'length_tags_pred_added': 4,
#                 'clusters_names_in_order_added': [
#                     'Tablets',
#                     'iPad',
#                     'Deals',
#                     'Apple'
#                 ],
#                 'dense_vs_core_rouge_eval': 0.08783783783783784,
#                 'tag_similarity_eval': 0.8685421248052222,
#                 'doc_id': '15',
#                 'clusters_score': 0
#             },
#             {
#                 'table_name': 'replicated_articles',
#                 'title': 'Intel and TSMC are reportedly launching a joint chipmaking
# venture',
#                 'author': 'Rebecca Szkutak',
#                 'published_date': 'Thu, 03 Apr 2025 20:25:46 +0000',
#                 'url_domain': 'techcrunch.com',
#                 'url':
# 'https://techcrunch.com/2025/04/03/intel-and-tsmc-are-reportedly-launching-a-join...',
#                 'summary': 'Semiconductor giants Intel and TSMC are reportedly teaming up.
# The two firms are...',
#                 'tags': [
#                     'AI',
#                     'Enterprise',
#                     'artificial intelligence',
#                     'chips',
#                     'In Brief',
#                     'Intel',
#                     'semiconductor',
#                     'TSMC'
#                 ],
#                 'html_content_length': 179258,
#                 'text_content_length': 2417,
#                 'summary_length': 350,
#                 'summary_text_ratio': 0.1448076127430699,
#                 'created_at': '2025-04-28T19:13:11.052281',
#                 'execution_time': 0,
#                 'last_updated': '2025-04-28T15:04:46.118754',
#                 'text_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'html_content_artifact': {
#                     'path':
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/artifacts/articles/2025/04/ar...',
#                     'format': 'text',
#                     'encoding': 'utf-8'
#                 },
#                 'original_doc_id': '336',
#                 'is_ai_pred_added': 'true',
#                 'dense_summary_added': 'Intel and TSMC are reportedly forming a joint
# venture where TSMC will hold a 20%...',
#                 'length_dense_summary_added': 600,
#                 'core_line_summary_added': "Intel is reportedly partnering with TSMC, with
# TSMC taking a 20% stake in Intel'...",
#                 'length_core_line_summary_added': 204,
#                 'tags_pred_added': [
#                     'Intel',
#                     'TSMC',
#                     'Semiconductor industry',
#                     'Chip manufacturing'
#                 ],
#                 'length_tags_pred_added': 4,
#                 'clusters_names_in_order_added': [
#                     'Intel',
#                     'TSMC',
#                     'Semiconductor industry',
#                     'Chip manufacturing'
#                 ],
#                 'dense_vs_core_rouge_eval': 0.23529411764705882,
#                 'tag_similarity_eval': 0.8209473118766132,
#                 'doc_id': '26',
#                 'clusters_score': 0
#             }
#         ],
#         'table_name': 'selections',
#         'created_at': '2025-05-09T15:32:55.227252'
#     }
# }

# %% [markdown]
# ### **4. Prepare Report**
#
# Generate a detailed report from replicated articles.
#
# To retrieve the report use the command :
#
# ```bash # python -m ttd.flows.article_selection.flow card get prepare_report article_selection_report_example.html```
#
# Here is an example : [article_selection_report_example.html](./images/article_selection_report_example.html)

# %% [markdown]
# ## Sandbox to try stuff

# %%
flow.config.get("db_path")
# Out:
# '/Users/mathieucrilout/Repos/train_tune_deploy/data/ttd_tinydb.json'

# %%
from ttd.storage.ttd_storage import TTDStorage

storage = TTDStorage(flow.config.get("db_path"))
storage.get_all('selected_articles')
# Out:
# [{'original_table_name': 'replicated_articles',
#   'original_doc_id': '23',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:53.942969',
#   'doc_id': '1'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '18',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.055135',
#   'doc_id': '2'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '5',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.109952',
#   'doc_id': '3'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '30',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.167469',
#   'doc_id': '4'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '2',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.236514',
#   'doc_id': '5'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '20',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.293009',
#   'doc_id': '6'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '6',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.347442',
#   'doc_id': '7'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '21',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.418206',
#   'doc_id': '8'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '35',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.473105',
#   'doc_id': '9'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '25',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.529494',
#   'doc_id': '10'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '19',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.597942',
#   'doc_id': '11'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '38',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.654944',
#   'doc_id': '12'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '28',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.711512',
#   'doc_id': '13'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '32',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.781631',
#   'doc_id': '14'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '7',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.837939',
#   'doc_id': '15'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '92',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.895513',
#   'doc_id': '16'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '3',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:54.964729',
#   'doc_id': '17'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '4',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:55.045110',
#   'doc_id': '18'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '15',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:55.101361',
#   'doc_id': '19'},
#  {'original_table_name': 'replicated_articles',
#   'original_doc_id': '26',
#   'table_name': 'selected_articles',
#   'created_at': '2025-05-09T15:32:55.171922',
#   'doc_id': '20'}]
